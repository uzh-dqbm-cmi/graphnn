# %%
# %load_ext autoreload
# %autoreload 2

# %%
import os
import sys
import numpy as np
import pandas as pd
import datetime
import seaborn as sns
import ogb
import ast
from scipy import stats

# %%
import torch
import torch.nn.functional as F
from torch_geometric.data import Data, DataLoader

# %%
cwd = os.getcwd()
print(cwd)
# Out:
# /cluster/home/skyriakos/chemprop_run/git/notebooks

# %%
pd.set_option('display.max_rows', 100)

# %%
os.chdir('..')
import deepadr
from deepadr.dataset import *
from deepadr.utilities import *
from deepadr.run_workflow import *
from deepadr.chemfeatures import *
from deepadr.hyphelper import *
from deepadr.model_gnn import GCN as testGCN
os.chdir(cwd)

# %%
from rdkit.Chem.Draw import IPythonConsole
from rdkit.Chem import Draw

# %%
from sklearn.preprocessing import StandardScaler

# %%
# from tdc.single_pred import Tox
# from tdc.multi_pred import DDI
# from tdc.multi_pred import DrugSyn
# data = DrugSyn(name = 'OncoPolyPharmacology')

# %%
rawdata_dir = '../data/raw/'
processed_dir = '../data/processed/'
up_dir = '..'

# %%
report_available_cuda_devices()
# Out:
# number of GPUs available: 1
# cuda:0, name:GeForce GTX 1080 Ti
# total memory available: 10.91650390625 GB
# total memory allocated on device: 0.0 GB
# max memory allocated on device: 0.0 GB
# total memory cached on device: 0.0 GB
# max memory cached  on device: 0.0 GB

# %%
n_gpu = torch.cuda.device_count()
n_gpu
# Out:
# 1

# %%
fdtype = torch.float32

# %%
print("torch:", torch.__version__)
print("CUDA:", torch.version.cuda)
# Out:
# torch: 1.9.1
# CUDA: 11.1

# %% [markdown]
# ### Preparing dataset

# %%
score = 'total_thresh'
score_val = 3

# %%
# TDC Tox
DSdataset_name = f'DrugComb_{score}_{score_val}' #'DrugComb'
# OncoPolyPharmacology is the MERCK dataset


#fname_suffix = ds_config["fname_suffix"]
similarity_types = ['chem']
kernel_option = 'sqeuclidean'
data_fname = 'data_v2'
# interact_matfname = ds_config["interact_matfname"]
# exp_iden = 'simtypeall'
# ddi_interaction_labels_pth = ds_config["ddi_interaction_labels_pth"]

# up_dir, processed_dir, DSdataset_name, data_fname

# %%
df_drugcomb = pd.read_csv(f'../data/drugcomb/v1_5__17_02_2022/processed_datasets/drugcomb_{score}_{score_val}.csv')
df_drugcomb
# Out:
#            Drug1_ID     Drug2_ID Cell_Line_ID  Cosmic_ID  \
# 0       dacarbazine  717906-29-1        A-673     684052
# 1          Nesbuvir  717906-29-1        A-673     684052
# 2       Avagacestat  717906-29-1        A-673     684052
# 3          AS601245  717906-29-1        A-673     684052
# 4      CHEMBL166161  717906-29-1        A-673     684052
# ...             ...          ...          ...        ...
# 25752       AZD7762      AZD2014     VM-CUB-1     909780
# 25753      AZD-4877    Onalespib     VM-CUB-1     909780
# 25754     Sapitinib   Vorinostat     VM-CUB-1     909780
# 25755   957054-30-7    Sapitinib     VM-CUB-1     909780
# 25756   957054-30-7  Selumetinib     VM-CUB-1     909780
#
#                                                    Drug1  \
# 0                              CN(C)N=NC1=C(NC=N1)C(=O)N
# 1      CNC(=O)C1=C(OC2=CC(=C(C=C21)C3CC3)N(CCO)S(=O)(...
# 2      C1=CC(=CC=C1S(=O)(=O)N(CC2=C(C=C(C=C2)C3=NOC=N...
# 3      C1=CC=C2C(=C1)N=C(S2)C(C#N)C3=NC(=NC=C3)NCCC4=...
# 4      COC1(CCN(CC1)CCC2=CNC3=C2C=C(C=C3)F)CS(=O)C4=C...
# ...                                                  ...
# 25752  C1CC(CNC1)NC(=O)C2=C(C=C(S2)C3=CC(=CC=C3)F)NC(...
# 25753  CC1=CC=C(C=C1)C(=O)N(CCCN)C(C2=NC3=C(C(=NS3)C)...
# 25754  CNC(=O)CN1CCC(CC1)OC2=C(C=C3C(=C2)C(=NC=N3)NC4...
# 25755  CS(=O)(=O)N1CCN(CC1)CC2=CC3=C(S2)C(=NC(=N3)C4=...
# 25756  CS(=O)(=O)N1CCN(CC1)CC2=CC3=C(S2)C(=NC(=N3)C4=...
#
#                                                    Drug2  Y
# 0      CN(C1=CC=CC=C1CNC2=NC(=NC=C2C(F)(F)F)NC3=CC4=C...  0
# 1      CN(C1=CC=CC=C1CNC2=NC(=NC=C2C(F)(F)F)NC3=CC4=C...  0
# 2      CN(C1=CC=CC=C1CNC2=NC(=NC=C2C(F)(F)F)NC3=CC4=C...  0
# 3      CN(C1=CC=CC=C1CNC2=NC(=NC=C2C(F)(F)F)NC3=CC4=C...  1
# 4      CN(C1=CC=CC=C1CNC2=NC(=NC=C2C(F)(F)F)NC3=CC4=C...  0
# ...                                                  ... ..
# 25752  CC1COCCN1C2=NC(=NC3=C2C=CC(=N3)C4=CC(=CC=C4)C(...  0
# 25753  CC(C)C1=C(C=C(C(=C1)C(=O)N2CC3=C(C2)C=C(C=C3)C...  0
# 25754                   C1=CC=C(C=C1)NC(=O)CCCCCCC(=O)NO  0
# 25755  CNC(=O)CN1CCC(CC1)OC2=C(C=C3C(=C2)C(=NC=N3)NC4...  1
# 25756  CN1C=NC2=C1C=C(C(=C2F)NC3=C(C=C(C=C3)Br)Cl)C(=...  1
#
# [25757 rows x 7 columns]

# %%
df_rma_landm = pd.read_csv('../data/synergxdb/RMA/df_rma_landm.tsv', sep="\t")
df_rma_landm
# Out:
#      Unnamed: 0 GENE_SYMBOLS  \
# 0             0       TSPAN6
# 1             3        SCYL3
# 2            19          BAD
# 3            20         LAP3
# 4            28        SNX11
# ..          ...          ...
# 903       17083      PLEKHM1
# 904       17400          MIF
# 905       17444        PRAF2
# 906       17575          LYN
# 907       17643        POLG2
#
#                                             GENE_title  DATA.906826  \
# 0         tetraspanin 6 [Source:HGNC Symbol;Acc:11858]     7.632023
# 1    SCY1-like 3 (S. cerevisiae) [Source:HGNC Symbo...     3.614794
# 2    BCL2-associated agonist of cell death [Source:...     7.458409
# 3    leucine aminopeptidase 3 [Source:HGNC Symbol;A...     6.453926
# 4      sorting nexin 11 [Source:HGNC Symbol;Acc:14975]     4.767457
# ..                                                 ...          ...
# 903  pleckstrin homology domain containing, family ...     6.167946
# 904  macrophage migration inhibitory factor (glycos...    11.893872
# 905  PRA1 domain family, member 2 [Source:HGNC Symb...     5.060852
# 906  v-yes-1 Yamaguchi sarcoma viral related oncoge...     5.892532
# 907  polymerase (DNA directed), gamma 2, accessory ...     6.476232
#
#      DATA.687983  DATA.910927  DATA.1240138  DATA.1240139  DATA.906792  \
# 0       7.548671     8.712338      7.797142      7.729268     7.074533
# 1       4.066887     3.956230      4.063701      4.341500     4.270903
# 2       7.479327     7.419672      7.731137      6.998981     6.550210
# 3       6.742826     5.655691      5.259367      4.611395     6.930777
# 4       5.246301     4.645800      4.558836      5.456692     5.099542
# ..           ...          ...           ...           ...          ...
# 903     5.271099     5.784561      7.587263      6.479184     5.700915
# 904    11.841300    12.272137     12.000410     11.867211    12.621575
# 905     6.515567     4.815762      4.544863      6.071288     4.777850
# 906     4.580184     6.482469      7.094195      7.932918     7.333405
# 907     6.772732     6.031281      5.349687      7.014173     6.637508
#
#      DATA.910688  ...  DATA.753584  DATA.907044  DATA.998184  DATA.908145  \
# 0       3.285198  ...     7.105637     3.236503     3.038892     8.373223
# 1       5.968168  ...     3.696835     4.624013     4.348524     3.858121
# 2       6.354063  ...     7.147962     6.478426     6.919537     6.801096
# 3       8.560707  ...     5.383810     8.591164     6.208059     6.715130
# 4       7.574348  ...     4.755084     6.761799     5.034195     4.958603
# ..           ...  ...          ...          ...          ...          ...
# 903     6.617353  ...     6.714959     6.368537     8.252268     6.436644
# 904    11.825283  ...    12.286071    12.572595    12.254136    12.588238
# 905     3.455981  ...     5.314914     2.943601     4.723601     5.769965
# 906    10.455397  ...     4.914232     9.453552     3.218797     4.073831
# 907     5.488236  ...     5.197838     6.488913     6.920288     6.644170
#
#      DATA.1659787  DATA.1298157  DATA.1480372  DATA.1298533  DATA.930299  \
# 0        6.932178      8.441628      8.422922      8.089255     3.112333
# 1        3.947561      4.425849      3.550390      4.443337     4.266828
# 2        7.153122      7.234464      7.525257      6.066356     8.185968
# 3        6.530806      5.759933      7.810126      7.182077     5.663629
# 4        4.629068      4.982202      5.037259      4.611973     4.800284
# ..            ...           ...           ...           ...          ...
# 903      6.436742      5.551436      5.634834      7.083564     5.776658
# 904     12.366026     12.153612     12.265099     11.919307    12.762295
# 905      5.070665      3.443244      3.293080      2.978125     5.125786
# 906      6.355383      8.348965      7.579339      4.456322     5.857488
# 907      7.134053      6.336357      5.884799      6.523157     6.072791
#
#      DATA.905954.1
# 0         7.153127
# 1         4.100493
# 2         4.967268
# 3         6.539451
# 4         4.967207
# ..             ...
# 903       6.306988
# 904      12.985613
# 905       4.404205
# 906       3.013612
# 907       5.248165
#
# [908 rows x 1021 columns]

# %%
targetdata_dir = create_directory(os.path.join(processed_dir, DSdataset_name, data_fname))
targetdata_dir_raw = create_directory(os.path.join(targetdata_dir, "raw"))
targetdata_dir_processed = create_directory(os.path.join(targetdata_dir, "processed"))
# ReaderWriter.dump_data(dpartitions, os.path.join(targetdata_dir, 'data_partitions.pkl'))
# Out:
# path_current_dir /cluster/home/skyriakos/chemprop_run/git/deepadr
# path_current_dir /cluster/home/skyriakos/chemprop_run/git/deepadr
# path_current_dir /cluster/home/skyriakos/chemprop_run/git/deepadr

# %%
targetdata_dir
# Out:
# '/cluster/home/skyriakos/chemprop_run/git/data/processed/DrugComb_total_thresh_4/data_v2'

# %%
# data = DDI(name = DSdataset_name).get_data(format = 'df')
# data = DrugSyn(name = DSdataset_name).get_data(format = 'df')

# %%
# from tdc.utils import get_label_map
# get_label_map(name = 'DrugBank', task = 'DDI')

# %%
# data = Tox(name = DSdataset_name).get_data(format = 'df')
# smiles, labels = data['Drug'], data['Y']

# %%
data = df_drugcomb
data
# Out:
#            Drug1_ID     Drug2_ID Cell_Line_ID  Cosmic_ID  \
# 0       dacarbazine  717906-29-1        A-673     684052
# 1          Nesbuvir  717906-29-1        A-673     684052
# 2       Avagacestat  717906-29-1        A-673     684052
# 3          AS601245  717906-29-1        A-673     684052
# 4      CHEMBL166161  717906-29-1        A-673     684052
# ...             ...          ...          ...        ...
# 25752       AZD7762      AZD2014     VM-CUB-1     909780
# 25753      AZD-4877    Onalespib     VM-CUB-1     909780
# 25754     Sapitinib   Vorinostat     VM-CUB-1     909780
# 25755   957054-30-7    Sapitinib     VM-CUB-1     909780
# 25756   957054-30-7  Selumetinib     VM-CUB-1     909780
#
#                                                    Drug1  \
# 0                              CN(C)N=NC1=C(NC=N1)C(=O)N
# 1      CNC(=O)C1=C(OC2=CC(=C(C=C21)C3CC3)N(CCO)S(=O)(...
# 2      C1=CC(=CC=C1S(=O)(=O)N(CC2=C(C=C(C=C2)C3=NOC=N...
# 3      C1=CC=C2C(=C1)N=C(S2)C(C#N)C3=NC(=NC=C3)NCCC4=...
# 4      COC1(CCN(CC1)CCC2=CNC3=C2C=C(C=C3)F)CS(=O)C4=C...
# ...                                                  ...
# 25752  C1CC(CNC1)NC(=O)C2=C(C=C(S2)C3=CC(=CC=C3)F)NC(...
# 25753  CC1=CC=C(C=C1)C(=O)N(CCCN)C(C2=NC3=C(C(=NS3)C)...
# 25754  CNC(=O)CN1CCC(CC1)OC2=C(C=C3C(=C2)C(=NC=N3)NC4...
# 25755  CS(=O)(=O)N1CCN(CC1)CC2=CC3=C(S2)C(=NC(=N3)C4=...
# 25756  CS(=O)(=O)N1CCN(CC1)CC2=CC3=C(S2)C(=NC(=N3)C4=...
#
#                                                    Drug2  Y
# 0      CN(C1=CC=CC=C1CNC2=NC(=NC=C2C(F)(F)F)NC3=CC4=C...  0
# 1      CN(C1=CC=CC=C1CNC2=NC(=NC=C2C(F)(F)F)NC3=CC4=C...  0
# 2      CN(C1=CC=CC=C1CNC2=NC(=NC=C2C(F)(F)F)NC3=CC4=C...  0
# 3      CN(C1=CC=CC=C1CNC2=NC(=NC=C2C(F)(F)F)NC3=CC4=C...  1
# 4      CN(C1=CC=CC=C1CNC2=NC(=NC=C2C(F)(F)F)NC3=CC4=C...  0
# ...                                                  ... ..
# 25752  CC1COCCN1C2=NC(=NC3=C2C=CC(=N3)C4=CC(=CC=C4)C(...  0
# 25753  CC(C)C1=C(C=C(C(=C1)C(=O)N2CC3=C(C2)C=C(C=C3)C...  0
# 25754                   C1=CC=C(C=C1)NC(=O)CCCCCCC(=O)NO  0
# 25755  CNC(=O)CN1CCC(CC1)OC2=C(C=C3C(=C2)C(=NC=N3)NC4...  1
# 25756  CN1C=NC2=C1C=C(C(=C2F)NC3=C(C=C(C=C3)Br)Cl)C(=...  1
#
# [25757 rows x 7 columns]

# %%
data
# Out:
#            Drug1_ID     Drug2_ID Cell_Line_ID  Cosmic_ID  \
# 0       dacarbazine  717906-29-1        A-673     684052
# 1          Nesbuvir  717906-29-1        A-673     684052
# 2       Avagacestat  717906-29-1        A-673     684052
# 3          AS601245  717906-29-1        A-673     684052
# 4      CHEMBL166161  717906-29-1        A-673     684052
# ...             ...          ...          ...        ...
# 25752       AZD7762      AZD2014     VM-CUB-1     909780
# 25753      AZD-4877    Onalespib     VM-CUB-1     909780
# 25754     Sapitinib   Vorinostat     VM-CUB-1     909780
# 25755   957054-30-7    Sapitinib     VM-CUB-1     909780
# 25756   957054-30-7  Selumetinib     VM-CUB-1     909780
#
#                                                    Drug1  \
# 0                              CN(C)N=NC1=C(NC=N1)C(=O)N
# 1      CNC(=O)C1=C(OC2=CC(=C(C=C21)C3CC3)N(CCO)S(=O)(...
# 2      C1=CC(=CC=C1S(=O)(=O)N(CC2=C(C=C(C=C2)C3=NOC=N...
# 3      C1=CC=C2C(=C1)N=C(S2)C(C#N)C3=NC(=NC=C3)NCCC4=...
# 4      COC1(CCN(CC1)CCC2=CNC3=C2C=C(C=C3)F)CS(=O)C4=C...
# ...                                                  ...
# 25752  C1CC(CNC1)NC(=O)C2=C(C=C(S2)C3=CC(=CC=C3)F)NC(...
# 25753  CC1=CC=C(C=C1)C(=O)N(CCCN)C(C2=NC3=C(C(=NS3)C)...
# 25754  CNC(=O)CN1CCC(CC1)OC2=C(C=C3C(=C2)C(=NC=N3)NC4...
# 25755  CS(=O)(=O)N1CCN(CC1)CC2=CC3=C(S2)C(=NC(=N3)C4=...
# 25756  CS(=O)(=O)N1CCN(CC1)CC2=CC3=C(S2)C(=NC(=N3)C4=...
#
#                                                    Drug2  Y
# 0      CN(C1=CC=CC=C1CNC2=NC(=NC=C2C(F)(F)F)NC3=CC4=C...  0
# 1      CN(C1=CC=CC=C1CNC2=NC(=NC=C2C(F)(F)F)NC3=CC4=C...  0
# 2      CN(C1=CC=CC=C1CNC2=NC(=NC=C2C(F)(F)F)NC3=CC4=C...  0
# 3      CN(C1=CC=CC=C1CNC2=NC(=NC=C2C(F)(F)F)NC3=CC4=C...  1
# 4      CN(C1=CC=CC=C1CNC2=NC(=NC=C2C(F)(F)F)NC3=CC4=C...  0
# ...                                                  ... ..
# 25752  CC1COCCN1C2=NC(=NC3=C2C=CC(=N3)C4=CC(=CC=C4)C(...  0
# 25753  CC(C)C1=C(C=C(C(=C1)C(=O)N2CC3=C(C2)C=C(C=C3)C...  0
# 25754                   C1=CC=C(C=C1)NC(=O)CCCCCCC(=O)NO  0
# 25755  CNC(=O)CN1CCC(CC1)OC2=C(C=C3C(=C2)C(=NC=N3)NC4...  1
# 25756  CN1C=NC2=C1C=C(C(=C2F)NC3=C(C=C(C=C3)Br)Cl)C(=...  1
#
# [25757 rows x 7 columns]

# %%
data[(data.Drug1.str.contains("1742"))]
# Out:
# Empty DataFrame
# Columns: [Drug1_ID, Drug2_ID, Cell_Line_ID, Cosmic_ID, Drug1, Drug2, Y]
# Index: []

# %%
data = data.drop(index=data[(data.Drug1.str.contains("Antibody")) | (data.Drug2.str.contains("Antibody"))].index)
data.index = range(len(data))
len(data)
# Out:
# 25757

# %%
# datashort = data[['Drug1_ID', 'Drug2_ID', 'Y']]
# datashort.Y = 1
# datashort = datashort[~datashort.duplicated()]
# datashort

# %%
uniq_data = ddi_dataframe_to_unique_drugs(data)
uniq_data
# Out:
#                         Drug_ID  \
# 0                   dacarbazine
# 1                      Nesbuvir
# 2                   Avagacestat
# 3                      AS601245
# 4                  CHEMBL166161
# ..                          ...
# 889              SCHEMBL3313928
# 890                     AZD8055
# 891                  33419-42-0
# 892                   NSC169534
# 893  Cobimetinib (R-enantiomer)
#
#                                                   Drug
# 0                            CN(C)N=NC1=C(NC=N1)C(=O)N
# 1    CNC(=O)C1=C(OC2=CC(=C(C=C21)C3CC3)N(CCO)S(=O)(...
# 2    C1=CC(=CC=C1S(=O)(=O)N(CC2=C(C=C(C=C2)C3=NOC=N...
# 3    C1=CC=C2C(=C1)N=C(S2)C(C#N)C3=NC(=NC=C3)NCCC4=...
# 4    COC1(CCN(CC1)CCC2=CNC3=C2C=C(C=C3)F)CS(=O)C4=C...
# ..                                                 ...
# 889  CC(C(=O)N1CCC(CC1)C2=CC(=C(C=C2)NC3=NC=C(C(=N3...
# 890  CC1COCCN1C2=NC(=NC3=C2C=CC(=N3)C4=CC(=C(C=C4)O...
# 891  CC1OCC2C(O1)C(C(C(O2)OC3C4COC(=O)C4C(C5=CC6=C(...
# 892  CC1C(C(CC(O1)OC2CC(CC3=C2C(=C4C(=C3O)C(=O)C5=C...
# 893  C1CCNC(C1)C2(CN(C2)C(=O)C3=C(C(=C(C=C3)F)F)NC4...
#
# [894 rows x 2 columns]

# %%
uniq_data.Drug = [d.split("; ")[1] if ("; " in d) else d for d in uniq_data.Drug]
uniq_data.Drug = [d.split(";")[1] if (";" in d) else d for d in uniq_data.Drug]

# %%
uniq_data['Mol'] = [smiles_to_mol(smiles) for smiles in uniq_data.Drug]

# %%
uniq_mol = uniq_data[~uniq_data.Mol.isnull()]
# uniq_mol['Data'] = [mol_to_graph_data_obj_simple(mol) for mol in uniq_mol.Mol]
uniq_mol['DataOGB'] = [smiles_to_graph_data_obj_ogb(smiles) for smiles in uniq_mol.Drug]
uniq_mol = uniq_mol.set_index("Drug_ID")
uniq_mol
# Out:
#                                                                          Drug  \
# Drug_ID
# dacarbazine                                         CN(C)N=NC1=C(NC=N1)C(=O)N
# Nesbuvir                    CNC(=O)C1=C(OC2=CC(=C(C=C21)C3CC3)N(CCO)S(=O)(...
# Avagacestat                 C1=CC(=CC=C1S(=O)(=O)N(CC2=C(C=C(C=C2)C3=NOC=N...
# AS601245                    C1=CC=C2C(=C1)N=C(S2)C(C#N)C3=NC(=NC=C3)NCCC4=...
# CHEMBL166161                COC1(CCN(CC1)CCC2=CNC3=C2C=C(C=C3)F)CS(=O)C4=C...
# ...                                                                       ...
# SCHEMBL3313928              CC(C(=O)N1CCC(CC1)C2=CC(=C(C=C2)NC3=NC=C(C(=N3...
# AZD8055                     CC1COCCN1C2=NC(=NC3=C2C=CC(=N3)C4=CC(=C(C=C4)O...
# 33419-42-0                  CC1OCC2C(O1)C(C(C(O2)OC3C4COC(=O)C4C(C5=CC6=C(...
# NSC169534                   CC1C(C(CC(O1)OC2CC(CC3=C2C(=C4C(=C3O)C(=O)C5=C...
# Cobimetinib (R-enantiomer)  C1CCNC(C1)C2(CN(C2)C(=O)C3=C(C(=C(C=C3)F)F)NC4...
#
#                                                                          Mol  \
# Drug_ID
# dacarbazine                 <rdkit.Chem.rdchem.Mol object at 0x2b235b72a2e0>
# Nesbuvir                    <rdkit.Chem.rdchem.Mol object at 0x2b235b72a400>
# Avagacestat                 <rdkit.Chem.rdchem.Mol object at 0x2b235b72a580>
# AS601245                    <rdkit.Chem.rdchem.Mol object at 0x2b235b72a280>
# CHEMBL166161                <rdkit.Chem.rdchem.Mol object at 0x2b235b72a160>
# ...                                                                      ...
# SCHEMBL3313928              <rdkit.Chem.rdchem.Mol object at 0x2b235b75fa00>
# AZD8055                     <rdkit.Chem.rdchem.Mol object at 0x2b235b75fa60>
# 33419-42-0                  <rdkit.Chem.rdchem.Mol object at 0x2b235b75fac0>
# NSC169534                   <rdkit.Chem.rdchem.Mol object at 0x2b235b75fb20>
# Cobimetinib (R-enantiomer)  <rdkit.Chem.rdchem.Mol object at 0x2b235b75fb80>
#
#                                                                       DataOGB
# Drug_ID
# dacarbazine                 [(edge_index, [tensor([ 0,  1,  1,  2,  1,  3,...
# Nesbuvir                    [(edge_index, [tensor([ 0,  1,  1,  2,  2,  3,...
# Avagacestat                 [(edge_index, [tensor([ 0,  1,  1,  2,  2,  3,...
# AS601245                    [(edge_index, [tensor([ 0,  1,  1,  2,  2,  3,...
# CHEMBL166161                [(edge_index, [tensor([ 0,  1,  1,  2,  2,  3,...
# ...                                                                       ...
# SCHEMBL3313928              [(edge_index, [tensor([ 0,  1,  1,  2,  2,  3,...
# AZD8055                     [(edge_index, [tensor([ 0,  1,  1,  2,  2,  3,...
# 33419-42-0                  [(edge_index, [tensor([ 0,  1,  1,  2,  2,  3,...
# NSC169534                   [(edge_index, [tensor([ 0,  1,  1,  2,  2,  3,...
# Cobimetinib (R-enantiomer)  [(edge_index, [tensor([ 0,  1,  1,  2,  2,  3,...
#
# [894 rows x 3 columns]

# %%
Draw.MolsToGridImage(uniq_mol.Mol.head(24), molsPerRow=6)

# %%
# num_drugs = len(uniq_mol)
# int((num_drugs * (num_drugs-1))/2)

# %%
uniq_mol.iloc[0].DataOGB
# Out:
# Data(edge_index=[2, 26], edge_attr=[26, 3], x=[13, 9])

# %%
uniq_mol['xFlat'] = [torch.mean(torch.clone(data.x).type(torch.float32), dim=0) for data in uniq_mol['DataOGB']]
uniq_mol
# Out:
#                                                                          Drug  \
# Drug_ID
# dacarbazine                                         CN(C)N=NC1=C(NC=N1)C(=O)N
# Nesbuvir                    CNC(=O)C1=C(OC2=CC(=C(C=C21)C3CC3)N(CCO)S(=O)(...
# Avagacestat                 C1=CC(=CC=C1S(=O)(=O)N(CC2=C(C=C(C=C2)C3=NOC=N...
# AS601245                    C1=CC=C2C(=C1)N=C(S2)C(C#N)C3=NC(=NC=C3)NCCC4=...
# CHEMBL166161                COC1(CCN(CC1)CCC2=CNC3=C2C=C(C=C3)F)CS(=O)C4=C...
# ...                                                                       ...
# SCHEMBL3313928              CC(C(=O)N1CCC(CC1)C2=CC(=C(C=C2)NC3=NC=C(C(=N3...
# AZD8055                     CC1COCCN1C2=NC(=NC3=C2C=CC(=N3)C4=CC(=C(C=C4)O...
# 33419-42-0                  CC1OCC2C(O1)C(C(C(O2)OC3C4COC(=O)C4C(C5=CC6=C(...
# NSC169534                   CC1C(C(CC(O1)OC2CC(CC3=C2C(=C4C(=C3O)C(=O)C5=C...
# Cobimetinib (R-enantiomer)  C1CCNC(C1)C2(CN(C2)C(=O)C3=C(C(=C(C=C3)F)F)NC4...
#
#                                                                          Mol  \
# Drug_ID
# dacarbazine                 <rdkit.Chem.rdchem.Mol object at 0x2b235b72a2e0>
# Nesbuvir                    <rdkit.Chem.rdchem.Mol object at 0x2b235b72a400>
# Avagacestat                 <rdkit.Chem.rdchem.Mol object at 0x2b235b72a580>
# AS601245                    <rdkit.Chem.rdchem.Mol object at 0x2b235b72a280>
# CHEMBL166161                <rdkit.Chem.rdchem.Mol object at 0x2b235b72a160>
# ...                                                                      ...
# SCHEMBL3313928              <rdkit.Chem.rdchem.Mol object at 0x2b235b75fa00>
# AZD8055                     <rdkit.Chem.rdchem.Mol object at 0x2b235b75fa60>
# 33419-42-0                  <rdkit.Chem.rdchem.Mol object at 0x2b235b75fac0>
# NSC169534                   <rdkit.Chem.rdchem.Mol object at 0x2b235b75fb20>
# Cobimetinib (R-enantiomer)  <rdkit.Chem.rdchem.Mol object at 0x2b235b75fb80>
#
#                                                                       DataOGB  \
# Drug_ID
# dacarbazine                 [(edge_index, [tensor([ 0,  1,  1,  2,  1,  3,...
# Nesbuvir                    [(edge_index, [tensor([ 0,  1,  1,  2,  2,  3,...
# Avagacestat                 [(edge_index, [tensor([ 0,  1,  1,  2,  2,  3,...
# AS601245                    [(edge_index, [tensor([ 0,  1,  1,  2,  2,  3,...
# CHEMBL166161                [(edge_index, [tensor([ 0,  1,  1,  2,  2,  3,...
# ...                                                                       ...
# SCHEMBL3313928              [(edge_index, [tensor([ 0,  1,  1,  2,  2,  3,...
# AZD8055                     [(edge_index, [tensor([ 0,  1,  1,  2,  2,  3,...
# 33419-42-0                  [(edge_index, [tensor([ 0,  1,  1,  2,  2,  3,...
# NSC169534                   [(edge_index, [tensor([ 0,  1,  1,  2,  2,  3,...
# Cobimetinib (R-enantiomer)  [(edge_index, [tensor([ 0,  1,  1,  2,  2,  3,...
#
#                                                                         xFlat
# Drug_ID
# dacarbazine                 [tensor(5.6154), tensor(0.), tensor(2.7692), t...
# Nesbuvir                    [tensor(5.8065), tensor(0.), tensor(2.9355), t...
# Avagacestat                 [tensor(6.3235), tensor(0.), tensor(2.6176), t...
# AS601245                    [tensor(5.5926), tensor(0.), tensor(2.8148), t...
# CHEMBL166161                [tensor(5.6552), tensor(0.), tensor(3.1379), t...
# ...                                                                       ...
# SCHEMBL3313928              [tensor(5.6389), tensor(0.), tensor(2.9722), t...
# AZD8055                     [tensor(5.3824), tensor(0.), tensor(3.1471), t...
# 33419-42-0                  [tensor(5.6190), tensor(0.), tensor(3.0476), t...
# NSC169534                   [tensor(5.5897), tensor(0.), tensor(2.9487), t...
# Cobimetinib (R-enantiomer)  [tensor(7.1000), tensor(0.), tensor(2.9000), t...
#
# [894 rows x 4 columns]

# %%
uniq_mol.iloc[0].DataOGB.x
# Out:
# tensor([[5, 0, 4, 5, 3, 0, 2, 0, 0],
#         [6, 0, 3, 5, 0, 0, 1, 0, 0],
#         [5, 0, 4, 5, 3, 0, 2, 0, 0],
#         [6, 0, 2, 5, 0, 0, 1, 0, 0],
#         [6, 0, 2, 5, 0, 0, 1, 0, 0],
#         [5, 0, 3, 5, 0, 0, 1, 1, 1],
#         [5, 0, 3, 5, 0, 0, 1, 1, 1],
#         [6, 0, 3, 5, 1, 0, 1, 1, 1],
#         [5, 0, 3, 5, 1, 0, 1, 1, 1],
#         [6, 0, 2, 5, 0, 0, 1, 1, 1],
#         [5, 0, 3, 5, 0, 0, 1, 0, 0],
#         [7, 0, 1, 5, 0, 0, 1, 0, 0],
#         [6, 0, 3, 5, 2, 0, 1, 0, 0]], dtype=torch.int32)

# %%
uniq_mol.iloc[0].xFlat
# Out:
# tensor([5.6154, 0.0000, 2.7692, 5.0000, 0.7692, 0.0000, 1.1538, 0.3846, 0.3846])

# %%
# torch.mean(x, dim=0)

# %%
# maxshape = 0

# for i, row in uniq_mol.iterrows():
#     rsh0 = row.xFlat.shape[0]
#     if rsh0 > maxshape:
#         maxshape = rsh0
        
# print(maxshape)

# %%
# for i in range(len(uniq_mol)):
#     x = uniq_mol.iloc[i].xFlat
#     x_pad_flat = F.pad(x, pad=(0, 0, 0, maxshape - x.shape[0])).reshape(-1)
#     uniq_mol.iloc[i].xFlat = x_pad_flat

# %%
# uniq_mol.iloc[0].DataOGB.x

# %%
# uniq_mol.iloc[0].xFlat[:300]

# %%
# 9 Atoms with 9 features

# %%
# 1D representation with 0-padding

# %%
# zhang_labels = pd.read_csv(rawdata_dir + '/DS1/drug_drug_matrix_wids.csv').set_index('Unnamed: 0')
# y_df = zhang_labels

# %%
# %%time

# y_df = ReaderWriter.read_or_dump_data(file_name=norm_join_paths(targetdata_dir_raw, 'y_df.pkl'),
#                                      data_gen_fun = generate_labels_df,
#                                      data_gen_params=(uniq_mol, datashort))

# %%
# y_df = generate_labels_df(uniq_mol, data)

# ReaderWriter.dump_data(y_df, os.path.join(targetdata_dir_raw, 'y_df.pkl'))

#y_df = ReaderWriter.read_data(os.path.join(targetdata_dir_raw, 'y_df.pkl'))

# %%
# y_df

# %%
# y_df[y_df > 0] = 1
# y_df

# %%
# y = get_y_from_interactionmat(y_df.to_numpy())
# len(y)

# %%
# binary_Y_threshold = 30

# %%
y = data.Y.copy()
y
# Out:
# 0        0
# 1        0
# 2        0
# 3        1
# 4        0
#         ..
# 25752    0
# 25753    0
# 25754    0
# 25755    1
# 25756    1
# Name: Y, Length: 25757, dtype: int64

# %%
# str(round((len(y[y>=binary_Y_threshold]) / len(y) *100), 2)) + "% positive labels"

# %%
# sns.boxplot(y)

# %%
# positive_labels = y>=binary_Y_threshold
# negative_labels = y<binary_Y_threshold

# %%
# y[positive_labels] = 1
# y[negative_labels] = 0
# y = y.astype(int)
# y

# %%
y.value_counts()
# Out:
# 0    14847
# 1    10910
# Name: Y, dtype: int64

# %%
ReaderWriter.dump_data(y.values, os.path.join(targetdata_dir_raw, 'y.pkl'))

# %%
y_weights = compute_class_weights(torch.tensor(y))
y_weights
# Out:
# array([0.86741429, 1.1804308 ])

# %%
ReaderWriter.dump_data(y_weights, os.path.join(targetdata_dir_raw, 'y_weights.pkl'))

# %%
expression = np.array([df_rma_landm['DATA.'+ str(c)].values for c in data["Cosmic_ID"]])
expression.shape
# Out:
# (25757, 908)

# %%
scaler = StandardScaler()
pipeline = compose(scaler.fit_transform, np.tanh, scaler.fit_transform)

# %%
expression_norm = pipeline(expression)
expression_norm
# Out:
# array([[ 0.16613301,  0.2518224 ,  1.33733722, ..., -0.40845414,
#          0.85813763,  0.89785037],
#        [ 0.16613301,  0.2518224 ,  1.33733722, ..., -0.40845414,
#          0.85813763,  0.89785037],
#        [ 0.16613301,  0.2518224 ,  1.33733722, ..., -0.40845414,
#          0.85813763,  0.89785037],
#        ...,
#        [-0.03726079, -1.43215349,  1.54107131, ..., -1.27108439,
#          1.2013354 ,  0.95369764],
#        [-0.03726079, -1.43215349,  1.54107131, ..., -1.27108439,
#          1.2013354 ,  0.95369764],
#        [-0.03726079, -1.43215349,  1.54107131, ..., -1.27108439,
#          1.2013354 ,  0.95369764]])

# %%
ReaderWriter.dump_data(expression_norm, os.path.join(targetdata_dir_raw, 'expression.pkl'))

# %%
# report_label_distrib(y)

# %%
# lasso_input_dim = 2*tp["emb_dim"]+1+expression_input_size
# lasso_out_dim = dataset.num_classes

# lassonet_model = LassoNet(lasso_input_dim, lasso_out_dim)# # pairs = list(itertools.combinations(uniq_mol.Drug_ID, 2))
# pairs = construct_sampleid_ddipairs(y_df.to_numpy())
# len(pairs)

# %%
pairs = {i:(row.Drug1_ID, row.Drug2_ID) for i, row in data.iterrows()}
len(pairs)
# Out:
# 25757

# %%
pairs
# Out:
# {0: ('dacarbazine', '717906-29-1'),
#  1: ('Nesbuvir', '717906-29-1'),
#  2: ('Avagacestat', '717906-29-1'),
#  3: ('AS601245', '717906-29-1'),
#  4: ('CHEMBL166161', '717906-29-1'),
#  5: ('NCGC00346433-01', '717906-29-1'),
#  6: ('AT7519', 'PF-3758309'),
#  7: ('ZINC34894448', 'PF-3758309'),
#  8: ('Romidepsin', 'thapsigargin'),
#  9: ('CHEMBL2141644', 'thapsigargin'),
#  10: ('Procarbazine hydrochloride', 'TOPOTECAN HYDROCHLORIDE'),
#  11: ('Antibiotic AD 32', 'Eloxatin (TN) (Sanofi Synthelab)'),
#  12: ('Vincristine sulfate', 'Lapatinib'),
#  13: ('actinomycin D', 'Tamoxifen citrate'),
#  14: ('docetaxel', 'Lapatinib'),
#  15: ('mitomycin C', 'TOPOTECAN HYDROCHLORIDE'),
#  16: ('thalidomide', 'Zanosar'),
#  17: ('Eloxatin (TN) (Sanofi Synthelab)', 'ifosfamide'),
#  18: ('Antibiotic AD 32', 'Co-V'),
#  19: ('Triethylenemelamine', 'Sorafenib'),
#  20: ('EXEMESTANE', 'amifostine'),
#  21: ('bleomycin', 'Fulvestrant'),
#  22: ('Lapatinib', '6-Mercaptopurine'),
#  23: ('thalidomide', 'TOPOTECAN HYDROCHLORIDE'),
#  24: ('Vincristine sulfate', 'Retinoic acid'),
#  25: ('Zanosar', 'TOPOTECAN HYDROCHLORIDE'),
#  26: ('temozolomide', '7-Ethyl-10-hydroxycamptothecin'),
#  27: ('thiotepa', 'Retinoic acid'),
#  28: ('CABAZITAXEL', 'Ixabepilone'),
#  29: ('Vepesid J', '6-Mercaptopurine'),
#  30: ('Melphalan hydrochloride', '6-Mercaptopurine'),
#  31: ('6-Thioguanine', '6-Mercaptopurine'),
#  32: ('teniposide', '6-Mercaptopurine'),
#  33: ('chlorambucil', 'Crizotinib'),
#  34: ('Pemetrexed', '6-Mercaptopurine'),
#  35: ('CABAZITAXEL', '6-Mercaptopurine'),
#  36: ('Axitinib', '6-Mercaptopurine'),
#  37: ('Crizotinib', '6-Mercaptopurine'),
#  38: ('Abiraterone', '6-Mercaptopurine'),
#  39: ('Navelbine ditartrate (TN)', '6-Mercaptopurine'),
#  40: ('CABAZITAXEL', 'Gefitinib'),
#  41: ('5-Fluorouracil', 'NSC-127716'),
#  42: ('altretamine', 'actinomycin D'),
#  43: ('5-Fluorouracil', 'actinomycin D'),
#  44: ('Vepesid J', 'actinomycin D'),
#  45: ('MEGESTROL ACETATE', "5-Fluoro-2'-deoxyuridine"),
#  46: ('Vismodegib', 'MITHRAMYCIN'),
#  47: ('Vemurafenib', 'MITHRAMYCIN'),
#  48: ('Navelbine ditartrate (TN)', 'actinomycin D'),
#  49: ('Gefitinib', 'actinomycin D'),
#  50: ('Pazopanib hydrochloride', 'actinomycin D'),
#  51: ('Vemurafenib', 'actinomycin D'),
#  52: ('Abiraterone', 'actinomycin D'),
#  53: ('Vismodegib', 'actinomycin D'),
#  54: ('Crizotinib', 'actinomycin D'),
#  55: ('6-Thioguanine', "5-Fluoro-2'-deoxyuridine"),
#  56: ('altretamine', "5-Fluoro-2'-deoxyuridine"),
#  57: ('CABAZITAXEL', 'Dasatinib'),
#  58: ('dacarbazine', "5-Fluoro-2'-deoxyuridine"),
#  59: ('Dexrazoxane', 'Vepesid J'),
#  60: ('Crizotinib', "5-Fluoro-2'-deoxyuridine"),
#  61: ('Gefitinib', 'Navelbine ditartrate (TN)'),
#  62: ('raloxifene', 'Navelbine ditartrate (TN)'),
#  63: ('Abiraterone', 'CABAZITAXEL'),
#  64: ('Vismodegib', 'CABAZITAXEL'),
#  65: ('mitoxantrone', 'Zoledronic acid'),
#  66: ('CABAZITAXEL', 'Trisenox'),
#  67: ('EXEMESTANE', 'Trisenox'),
#  68: ('Uramustine', 'Zoledronic acid'),
#  69: ('teniposide', 'Zoledronic acid'),
#  70: ('lomustine', 'Zoledronic acid'),
#  71: ('Vepesid J', 'Zoledronic acid'),
#  72: ('CABAZITAXEL', 'Dexrazoxane'),
#  73: ('Uramustine', 'Trisenox'),
#  74: ('mitoxantrone', 'Trisenox'),
#  75: ('teniposide', 'mitomycin C'),
#  76: ('Vandetanib', 'raloxifene'),
#  77: ('EXEMESTANE', 'Zoledronic acid'),
#  78: ('lomustine', 'mitomycin C'),
#  79: ('23541-50-6', 'mitomycin C'),
#  80: ('Uramustine', 'mitomycin C'),
#  81: ('chlorambucil', 'mitomycin C'),
#  82: ('6-Thioguanine', 'mitomycin C'),
#  83: ('5-Fluorouracil', 'mitomycin C'),
#  84: ('23541-50-6', '5-Fluorouracil'),
#  85: ('Dexrazoxane', 'mitomycin C'),
#  86: ('EXEMESTANE', 'Emcyt (Pharmacia)'),
#  87: ('Vepesid J', 'mitomycin C'),
#  88: ('Dexrazoxane', '5-Fluorouracil'),
#  89: ('CABAZITAXEL', 'NSC733504'),
#  90: ('Crizotinib', 'mitomycin C'),
#  91: ('Pemetrexed', 'mitomycin C'),
#  92: ('Gefitinib', 'mitomycin C'),
#  93: ('lomustine', 'Emcyt (Pharmacia)'),
#  94: ('chlorambucil', 'Emcyt (Pharmacia)'),
#  95: ('actinomycin D', 'NSC256439'),
#  96: ('actinomycin D', 'ADM hydrochloride'),
#  97: ('122111-05-1', 'docetaxel'),
#  98: ('docetaxel', 'IMIQUIMOD'),
#  99: ('cis-Platin', 'Trisenox'),
#  100: ('docetaxel', 'Emcyt (Pharmacia)'),
#  101: ('Lapatinib', '6-Mercaptopurine'),
#  102: ('docetaxel', 'Lapatinib'),
#  103: ('bleomycin', 'Fulvestrant'),
#  104: ('Antibiotic AY 22989', 'NSC733504'),
#  105: ('EXEMESTANE', 'amifostine'),
#  106: ('thalidomide', 'carmustine'),
#  107: ('Fulvestrant', '158798-73-3'),
#  108: ('Pralatrexate', 'pipobroman'),
#  109: ('Eloxatin (TN) (Sanofi Synthelab)', 'ifosfamide'),
#  110: ('Imatinib', 'paclitaxel'),
#  111: ('paclitaxel', 'Emcyt (Pharmacia)'),
#  112: ('Antibiotic AD 32', 'methoxsalen'),
#  113: ('Triethylenemelamine', 'Sorafenib'),
#  114: ('NSC733504', 'Fulvestrant'),
#  115: ('altretamine', 'Antibiotic AY 22989'),
#  116: ('dacarbazine', 'Antibiotic AY 22989'),
#  117: ('Uramustine', 'Antibiotic AY 22989'),
#  118: ('chlorambucil', '5-Aminolevulinic acid hydrochloride'),
#  119: ('dacarbazine', '6-Mercaptopurine'),
#  120: ('6-Thioguanine', 'Crizotinib'),
#  121: ('Uramustine', 'Crizotinib'),
#  122: ('Vismodegib', 'MITHRAMYCIN'),
#  123: ('Vandetanib', 'MITHRAMYCIN'),
#  124: ('Pazopanib hydrochloride', 'MITHRAMYCIN'),
#  125: ('Abiraterone', 'MITHRAMYCIN'),
#  126: ('Vemurafenib', 'MITHRAMYCIN'),
#  127: ('Gefitinib', 'actinomycin D'),
#  128: ('Vemurafenib', 'actinomycin D'),
#  129: ('Abiraterone', 'actinomycin D'),
#  130: ('Vismodegib', 'actinomycin D'),
#  131: ('CABAZITAXEL', 'CYTARABINE HYDROCHLORIDE'),
#  132: ('Melphalan hydrochloride', 'thalidomide'),
#  133: ('altretamine', 'thalidomide'),
#  134: ('dacarbazine', 'thalidomide'),
#  135: ('lomustine', 'thalidomide'),
#  136: ('MEGESTROL ACETATE', 'thalidomide'),
#  137: ('23541-50-6', 'Nilotinib'),
#  138: ('mitoxantrone', 'Zoledronic acid'),
#  139: ('EXEMESTANE', 'Trisenox'),
#  140: ('chlorambucil', 'Zoledronic acid'),
#  141: ('teniposide', 'Zoledronic acid'),
#  142: ('lomustine', 'Zoledronic acid'),
#  143: ('Vepesid J', 'Zoledronic acid'),
#  144: ('teniposide', 'Trisenox'),
#  145: ('Uramustine', 'Trisenox'),
#  146: ('Vepesid J', 'Trisenox'),
#  147: ('Gefitinib', '23541-50-6'),
#  148: ('mitoxantrone', 'Trisenox'),
#  149: ('Pazopanib hydrochloride', '23541-50-6'),
#  150: ('Navelbine ditartrate (TN)', 'Zoledronic acid'),
#  151: ('Navelbine ditartrate (TN)', 'Bendamustine hydrochloride'),
#  152: ('EXEMESTANE', 'Zoledronic acid'),
#  153: ('EXEMESTANE', 'Emcyt (Pharmacia)'),
#  154: ('lomustine', 'Emcyt (Pharmacia)'),
#  155: ('Antibiotic AY 22989', 'NSC256439'),
#  156: ('methotrexate', 'NSC256439'),
#  157: ('methotrexate', 'ADM hydrochloride'),
#  158: ('Antibiotic AY 22989', 'ADM hydrochloride'),
#  159: ('Akt inhibitor VIII', 'Doramapimod'),
#  160: ('Akt inhibitor VIII', 'SF1670'),
#  161: ('Doramapimod', '391210-10-9'),
#  162: ('Doramapimod', 'PI-103'),
#  163: ('Doramapimod', 'SF1670'),
#  164: ('JNK-IN-8', '10058-F4'),
#  165: ('391210-10-9', '10058-F4'),
#  166: ('PI-103', 'BI-D1870'),
#  167: ('PI-103', 'JNK-IN-8'),
#  168: ('BI605906', '301836-43-1'),
#  169: ('BI605906', 'Ruxolitinib'),
#  170: ('CHIR-99021', '10058-F4'),
#  171: ('CHIR-99021', '391210-10-9'),
#  172: ('CHIR-99021', 'Stattic'),
#  173: ('BI-D1870', 'SF1670'),
#  174: ('JNK-IN-8', 'SB-505124'),
#  175: ('391210-10-9', 'BI605906'),
#  176: ('391210-10-9', '301836-43-1'),
#  177: ('391210-10-9', 'JNK-IN-8'),
#  178: ('391210-10-9', 'SB-505124'),
#  179: ('CHIR-99021', 'SF1670'),
#  180: ('JNK-IN-8', 'SF1670'),
#  181: ('Akt inhibitor VIII', 'JNK-IN-8'),
#  182: ('PI-103', 'SF1670'),
#  183: ('SF1670', 'PRT062607'),
#  184: ('JNK-IN-8', 'PRT062607'),
#  185: ('thiotepa', 'NSC-127716'),
#  186: ('cyclophosphamide', 'Eloxatin (TN) (Sanofi Synthelab)'),
#  187: ('paclitaxel', 'NSC-127716'),
#  188: ('Antibiotic AD 32', 'Eloxatin (TN) (Sanofi Synthelab)'),
#  189: ('Imatinib', 'docetaxel'),
#  190: ('cyclophosphamide', 'TOPOTECAN HYDROCHLORIDE'),
#  191: ('CHEMBL17639', 'Pralatrexate'),
#  192: ('mitomycin C', 'Eloxatin (TN) (Sanofi Synthelab)'),
#  193: ('thalidomide', 'Eloxatin (TN) (Sanofi Synthelab)'),
#  194: ('thalidomide', 'TOPOTECAN HYDROCHLORIDE'),
#  195: ('thalidomide', 'Co-V'),
#  196: ('docetaxel', 'Lapatinib'),
#  197: ('docetaxel', 'Sorafenib'),
#  198: ('celecoxib', 'docetaxel'),
#  199: ('methotrexate', 'NSC-127716'),
#  200: ('EXEMESTANE', 'amifostine'),
#  201: ('docetaxel', 'Emcyt (Pharmacia)'),
#  202: ('Triethylenemelamine', '55-86-7'),
#  203: ('actinomycin D', 'Nilotinib'),
#  204: ('methotrexate', 'amifostine'),
#  205: ('methoxsalen', 'Eloxatin (TN) (Sanofi Synthelab)'),
#  206: ('Eloxatin (TN) (Sanofi Synthelab)', 'ifosfamide'),
#  207: ('Triethylenemelamine', 'Sorafenib'),
#  208: ('thalidomide', 'Zanosar'),
#  209: ('paclitaxel', 'Triethylenemelamine'),
#  210: ('Nilotinib', 'docetaxel'),
#  211: ('Procarbazine hydrochloride', 'TOPOTECAN HYDROCHLORIDE'),
#  212: ('mitomycin C', 'TOPOTECAN HYDROCHLORIDE'),
#  213: ('Zanosar', 'Eloxatin (TN) (Sanofi Synthelab)'),
#  214: ('methoxsalen', 'TOPOTECAN HYDROCHLORIDE'),
#  215: ('Fulvestrant', 'docetaxel'),
#  216: ('paclitaxel', 'Azacytidine, 5-'),
#  217: ('methotrexate', 'Imatinib'),
#  218: ('55-86-7', 'Emcyt (Pharmacia)'),
#  219: ('docetaxel', 'Sunitinib'),
#  220: ('actinomycin D', 'Emcyt (Pharmacia)'),
#  221: ('Tamoxifen citrate', 'docetaxel'),
#  222: ('Retinoic acid', 'mitomycin C'),
#  223: ('Zanosar', 'TOPOTECAN HYDROCHLORIDE'),
#  224: ('Retinoic acid', 'docetaxel'),
#  225: ('Axitinib', 'Romidepsin'),
#  226: ('CABAZITAXEL', 'Romidepsin'),
#  227: ('Pazopanib hydrochloride', 'Romidepsin'),
#  228: ('5-Fluorouracil', '7-Ethyl-10-hydroxycamptothecin'),
#  229: ('Gefitinib', 'mitoxantrone'),
#  230: ('6-Thioguanine', '5-Aminolevulinic acid hydrochloride'),
#  231: ('5-Fluorouracil', 'Melphalan hydrochloride'),
#  232: ('5-Fluorouracil', 'TOPOTECAN HYDROCHLORIDE'),
#  233: ('Dexrazoxane', '6-Mercaptopurine'),
#  234: ('Vepesid J', '6-Mercaptopurine'),
#  235: ('dacarbazine', '6-Mercaptopurine'),
#  236: ('Uramustine', '6-Mercaptopurine'),
#  237: ('5-Fluorouracil', '6-Mercaptopurine'),
#  238: ('altretamine', '6-Mercaptopurine'),
#  239: ('Melphalan hydrochloride', '6-Mercaptopurine'),
#  240: ('6-Thioguanine', '6-Mercaptopurine'),
#  241: ('chlorambucil', '6-Mercaptopurine'),
#  242: ('23541-50-6', '6-Mercaptopurine'),
#  243: ('MEGESTROL ACETATE', '6-Mercaptopurine'),
#  244: ('5-Fluorouracil', 'Sorafenib'),
#  245: ('EXEMESTANE', '6-Mercaptopurine'),
#  246: ('Gefitinib', '6-Mercaptopurine'),
#  247: ('Pemetrexed', '6-Mercaptopurine'),
#  248: ('Ruxolitinib', '6-Mercaptopurine'),
#  249: ('Vandetanib', '6-Mercaptopurine'),
#  250: ('Axitinib', '6-Mercaptopurine'),
#  251: ('Crizotinib', '6-Mercaptopurine'),
#  252: ('Abiraterone', '6-Mercaptopurine'),
#  253: ('Lenalidomide', '6-Mercaptopurine'),
#  254: ('Pazopanib hydrochloride', '6-Mercaptopurine'),
#  255: ('Navelbine ditartrate (TN)', '6-Mercaptopurine'),
#  256: ('6-Thioguanine', 'Sunitinib'),
#  257: ('5-Fluorouracil', 'Eloxatin (TN) (Sanofi Synthelab)'),
#  258: ('5-Fluorouracil', 'NSC-127716'),
#  259: ('MEGESTROL ACETATE', 'actinomycin D'),
#  260: ('5-Fluorouracil', 'Carboplatinum'),
#  261: ('Crizotinib', 'MITHRAMYCIN'),
#  262: ('Vismodegib', 'MITHRAMYCIN'),
#  263: ('Vandetanib', 'MITHRAMYCIN'),
#  264: ('Abiraterone', 'MITHRAMYCIN'),
#  265: ('Vemurafenib', 'MITHRAMYCIN'),
#  266: ('Gefitinib', 'MITHRAMYCIN'),
#  267: ('CABAZITAXEL', 'Retinoic acid'),
#  268: ('Gefitinib', 'actinomycin D'),
#  269: ('Vemurafenib', 'actinomycin D'),
#  270: ('Vismodegib', 'actinomycin D'),
#  271: ('6-Thioguanine', 'MITHRAMYCIN'),
#  272: ('Vepesid J', 'MITHRAMYCIN'),
#  273: ('5-Fluorouracil', 'CHEMBL277800'),
#  274: ('6-Thioguanine', 'Pralatrexate'),
#  275: ('Gefitinib', 'Navelbine ditartrate (TN)'),
#  276: ('23541-50-6', 'Pralatrexate'),
#  277: ('6-Thioguanine', 'busulfan'),
#  278: ('CABAZITAXEL', 'Vinblastine sulfate'),
#  279: ('6-Thioguanine', 'allopurinol'),
#  280: ('6-Thioguanine', 'hydroxyurea'),
#  281: ('Navelbine ditartrate (TN)', 'Trisenox'),
#  282: ('mitoxantrone', 'Zoledronic acid'),
#  283: ('5-Fluorouracil', '122111-05-1'),
#  284: ('CABAZITAXEL', 'Trisenox'),
#  285: ('5-Fluorouracil', 'chlorambucil'),
#  286: ('5-Fluorouracil', 'Vinblastine sulfate'),
#  287: ('EXEMESTANE', 'Trisenox'),
#  288: ('Melphalan hydrochloride', 'Vinblastine sulfate'),
#  289: ('Uramustine', 'Zoledronic acid'),
#  290: ('chlorambucil', 'Zoledronic acid'),
#  291: ('teniposide', 'Zoledronic acid'),
#  292: ('lomustine', 'Zoledronic acid'),
#  293: ('23541-50-6', 'Zoledronic acid'),
#  294: ('Vepesid J', 'Zoledronic acid'),
#  295: ('teniposide', 'Trisenox'),
#  296: ('5-Fluorouracil', 'Vorinostat'),
#  297: ('Uramustine', 'Trisenox'),
#  298: ('mitoxantrone', 'Trisenox'),
#  299: ('Navelbine ditartrate (TN)', 'Zoledronic acid'),
#  300: ('EXEMESTANE', 'Zoledronic acid'),
#  301: ('MEGESTROL ACETATE', 'mitomycin C'),
#  302: ('dacarbazine', 'mitomycin C'),
#  303: ('Vemurafenib', 'Pazopanib hydrochloride'),
#  304: ('Uramustine', 'mitomycin C'),
#  305: ('Vismodegib', 'Pazopanib hydrochloride'),
#  306: ('chlorambucil', 'mitomycin C'),
#  307: ('6-Thioguanine', 'mitomycin C'),
#  308: ('5-Fluorouracil', 'mitomycin C'),
#  309: ('Dexrazoxane', 'mitomycin C'),
#  310: ('EXEMESTANE', 'Emcyt (Pharmacia)'),
#  311: ('CABAZITAXEL', 'dacarbazine'),
#  312: ('lomustine', 'Emcyt (Pharmacia)'),
#  313: ('Uramustine', 'Emcyt (Pharmacia)'),
#  314: ('CABAZITAXEL', 'ADM hydrochloride'),
#  315: ('6-Thioguanine', 'ADM hydrochloride'),
#  316: ('Antibiotic AY 22989', 'ADM hydrochloride'),
#  317: ('MITHRAMYCIN', 'ADM hydrochloride'),
#  318: ("5-Fluoro-2'-deoxyuridine", 'ADM hydrochloride'),
#  319: ('mitoxantrone', 'NSC256439'),
#  320: ("5-Fluoro-2'-deoxyuridine", 'NSC256439'),
#  321: ('6-Thioguanine', 'NSC256439'),
#  322: ('actinomycin D', 'NSC256439'),
#  323: ('Antibiotic AY 22989', 'NSC256439'),
#  324: ('CABAZITAXEL', 'NSC256439'),
#  325: ('actinomycin D', 'Antibiotic AD 32'),
#  326: ('actinomycin D', 'Fulvestrant'),
#  327: ('Lapatinib', '6-Mercaptopurine'),
#  328: ('Eloxatin (TN) (Sanofi Synthelab)', 'ifosfamide'),
#  329: ('bleomycin', 'Fulvestrant'),
#  330: ('Triethylenemelamine', 'Sorafenib'),
#  331: ('actinomycin D', 'Nilotinib'),
#  332: ('lomustine', 'Antibiotic AY 22989'),
#  333: ('CABAZITAXEL', 'mitoxantrone'),
#  334: ('Vepesid J', '6-Mercaptopurine'),
#  335: ('Uramustine', '6-Mercaptopurine'),
#  336: ('6-Thioguanine', '6-Mercaptopurine'),
#  337: ('chlorambucil', '6-Mercaptopurine'),
#  338: ('teniposide', '6-Mercaptopurine'),
#  339: ('23541-50-6', '6-Mercaptopurine'),
#  340: ('lomustine', '6-Mercaptopurine'),
#  341: ('EXEMESTANE', '6-Mercaptopurine'),
#  342: ('Gefitinib', '6-Mercaptopurine'),
#  343: ('Vandetanib', '6-Mercaptopurine'),
#  344: ('Axitinib', '6-Mercaptopurine'),
#  345: ('Lenalidomide', '6-Mercaptopurine'),
#  346: ('Pazopanib hydrochloride', '6-Mercaptopurine'),
#  347: ('Navelbine ditartrate (TN)', '6-Mercaptopurine'),
#  348: ('Crizotinib', 'MITHRAMYCIN'),
#  349: ('Vismodegib', 'MITHRAMYCIN'),
#  350: ('Vandetanib', 'MITHRAMYCIN'),
#  351: ('Pazopanib hydrochloride', 'MITHRAMYCIN'),
#  352: ('Abiraterone', 'MITHRAMYCIN'),
#  353: ('Vemurafenib', 'actinomycin D'),
#  354: ('chlorambucil', "5-Fluoro-2'-deoxyuridine"),
#  355: ('mitoxantrone', 'Zoledronic acid'),
#  356: ('CABAZITAXEL', 'Trisenox'),
#  357: ('mitoxantrone', 'Trisenox'),
#  358: ('CABAZITAXEL', '23541-50-6'),
#  359: ('EXEMESTANE', 'Zoledronic acid'),
#  360: ('CABAZITAXEL', 'Zoledronic acid'),
#  361: ('EXEMESTANE', 'Emcyt (Pharmacia)'),
#  362: ('Vepesid J', '23541-50-6'),
#  363: ('mitoxantrone', 'Vepesid J'),
#  364: ('CABAZITAXEL', 'amifostine'),
#  365: ('Uramustine', 'paclitaxel'),
#  366: ('chlorambucil', 'paclitaxel'),
#  367: ('Dasatinib', 'NSC256439'),
#  368: ('Antibiotic AY 22989', 'NSC256439'),
#  369: ('Dasatinib', 'ADM hydrochloride'),
#  370: ('actinomycin D', 'NSC256439'),
#  371: ('Antibiotic AY 22989', 'ADM hydrochloride'),
#  372: ('(-)-MK 801 Maleate', 'temozolomide'),
#  373: ('1268524-70-4', 'temozolomide'),
#  374: ('32981-86-5', 'temozolomide'),
#  375: ('10058-F4', 'temozolomide'),
#  376: ('2-Methoxyestradiol', 'temozolomide'),
#  377: ('20-HYDROXYECDYSONE', 'temozolomide'),
#  378: ('3-Deazaneplanocin', 'temozolomide'),
#  379: ('3-methyladenine', 'temozolomide'),
#  380: ('14003-96-4', 'temozolomide'),
#  381: ('5-Aminolevulinic acid hydrochloride', 'temozolomide'),
#  382: ('8-AZAGUANINE', 'temozolomide'),
#  383: ('A-674563', 'temozolomide'),
#  384: ('844499-71-4', 'temozolomide'),
#  385: ('1166227-08-2', 'temozolomide'),
#  386: ('959122-11-3', 'temozolomide'),
#  387: ('Venetoclax', 'temozolomide'),
#  388: ('Navitoclax', 'temozolomide'),
#  389: ('BMS-599626', 'temozolomide'),
#  390: ('ACADESINE', 'temozolomide'),
#  391: ('Aceclidine hydrochloride', 'temozolomide'),
#  392: ('Acitretin', 'temozolomide'),
#  393: ('ADEFOVIR DIPIVOXIL', 'temozolomide'),
#  394: ('ADX-47273', 'temozolomide'),
#  395: ('497839-62-0', 'temozolomide'),
#  396: ('Afatinib', 'temozolomide'),
#  397: ('AG14361', 'temozolomide'),
#  398: ('AG-1478', 'temozolomide'),
#  399: ('Albendazole oxide', 'temozolomide'),
#  400: ('Alfuzosin Hydrochloride', 'temozolomide'),
#  401: ('Alizarin', 'temozolomide'),
#  402: ('Altrenogest', 'temozolomide'),
#  403: ('altretamine', 'temozolomide'),
#  404: ('444912-48-5', 'temozolomide'),
#  405: ('AM251', 'temozolomide'),
#  406: ('61618-27-7', 'temozolomide'),
#  407: ('AMG-458', 'temozolomide'),
#  408: ('2-AMINOTHIAZOLE', 'temozolomide'),
#  409: ('amorolfine hydrochloride', 'temozolomide'),
#  410: ('AMPICILLIN SODIUM', 'temozolomide'),
#  411: ('Amuvatinib', 'temozolomide'),
#  412: ('ANAGRELIDE HYDROCHLORIDE', 'temozolomide'),
#  413: ('Antazoline hydrochloride', 'temozolomide'),
#  414: ('AP26113', 'temozolomide'),
#  415: ('Apatinib', 'temozolomide'),
#  416: ('Apoptosis Activator 2', 'temozolomide'),
#  417: ('AR-A014418', 'temozolomide'),
#  418: ('ARN-509', 'temozolomide'),
#  419: ('Asenapine', 'temozolomide'),
#  420: ('AST-1306', 'temozolomide'),
#  421: ('Gossypol acetic acid', 'temozolomide'),
#  422: ('Atracurium besylate', 'temozolomide'),
#  423: ('Aurora A Inhibitor I', 'temozolomide'),
#  424: ('Avasimibe', 'temozolomide'),
#  425: ('AVL-292', 'temozolomide'),
#  426: ('878739-06-1', 'temozolomide'),
#  427: ('AZD1080', 'temozolomide'),
#  428: ('AZD2014', 'temozolomide'),
#  429: ('AZD2461', 'temozolomide'),
#  430: ('AZD2858', 'temozolomide'),
#  431: ('AZD4547', 'temozolomide'),
#  432: ('AZD5363', 'temozolomide'),
#  433: ('AZD6482', 'temozolomide'),
#  434: ('AZD8330', 'temozolomide'),
#  435: ('Sapitinib', 'temozolomide'),
#  436: ('AZELASTINE HYDROCHLORIDE', 'temozolomide'),
#  437: ('azithromycin', 'temozolomide'),
#  438: ('BAM7', 'temozolomide'),
#  439: ('Bardoxolone methyl', 'temozolomide'),
#  440: ('batimastat', 'temozolomide'),
#  441: ('Belinostat', 'temozolomide'),
#  442: ('bemegride', 'temozolomide'),
#  443: ('benfotiamine', 'temozolomide'),
#  444: ('benidipine hydrochloride', 'temozolomide'),
#  445: ('benzbromarone', 'temozolomide'),
#  446: ('benzethonium chloride', 'temozolomide'),
#  447: ('benzocaine', 'temozolomide'),
#  448: ('BENZTROPINE MESYLATE', 'temozolomide'),
#  449: ('BEPHENIUM HYDROXYNAPHTHOATE', 'temozolomide'),
#  450: ('Betamipron', 'temozolomide'),
#  451: ('Bethanechol chloride', 'temozolomide'),
#  452: ('Bexarotene', 'temozolomide'),
#  453: ('3-(2,6-dichloro-3,5-dimethoxy-phenyl)-1-[6-[4-(4-ethylpiperazin-1-yl)anilino]pyrimidin-4-yl]-1-methyl-urea',
#   'temozolomide'),
#  454: ('bifonazole', 'temozolomide'),
#  455: ('667463-62-9', 'temozolomide'),
#  456: ('Biperiden hydrochloride', 'temozolomide'),
#  457: ('Doramapimod', 'temozolomide'),
#  458: ('bisacodyl', 'temozolomide'),
#  459: ('1392399-03-9', 'temozolomide'),
#  460: ('BIX02188', 'temozolomide'),
#  461: ('BIX 02189', 'temozolomide'),
#  462: ('BML-190', 'temozolomide'),
#  463: ('547757-23-3', 'temozolomide'),
#  464: ('BMS-777607', 'temozolomide'),
#  465: ('1174046-72-0', 'temozolomide'),
#  466: ('BMS-833923', 'temozolomide'),
#  467: ('21102-95-4', 'temozolomide'),
#  468: ('Bosutinib', 'temozolomide'),
#  469: ('Brinzolamide', 'temozolomide'),
#  470: ('Brivanib', 'temozolomide'),
#  471: ('193611-72-2', 'temozolomide'),
#  472: ('Brompheniramine maleate', 'temozolomide'),
#  473: ('broxyquinoline', 'temozolomide'),
#  474: ('BRUCINE', 'temozolomide'),
#  475: ('BS-181 HCl', 'temozolomide'),
#  476: ('budesonide', 'temozolomide'),
#  477: ('busulfan', 'temozolomide'),
#  478: ('butein', 'temozolomide'),
#  479: ('BUTOCONAZOLE NITRATE', 'temozolomide'),
#  480: ('BX-912', 'temozolomide'),
#  481: ('alpelisib', 'temozolomide'),
#  482: ('Cabozantinib', 'temozolomide'),
#  483: ('Idelalisib', 'temozolomide'),
#  484: ('CALCIUM GLUCEPTATE', 'temozolomide'),
#  485: ('Candesartan cilexetil', 'temozolomide'),
#  486: ('Canertinib', 'temozolomide'),
#  487: ('CAPECITABINE', 'temozolomide'),
#  488: ('UNII-M2X04R2E2Y', 'temozolomide'),
#  489: ('carbazochrome sodium sulfonate', 'temozolomide'),
#  490: ('Carbenicillin disodium', 'temozolomide'),
#  491: ('Carbimazole', 'temozolomide'),
#  492: ('Caspofungin acetate', 'temozolomide'),
#  493: ('CCT128930', 'temozolomide'),
#  494: ('Cediranib', 'temozolomide'),
#  495: ('celecoxib', 'temozolomide'),
#  496: ('CEP-32496', 'temozolomide'),
#  497: ('CEP-33779', 'temozolomide'),
#  498: ('CEPHARANTHINE', 'temozolomide'),
#  499: ('Cetrimonium bromide', 'temozolomide'),
#  500: ('CFTRinh-172', 'temozolomide'),
#  501: ('CGK733', 'temozolomide'),
#  502: ('CH5132799', 'temozolomide'),
#  503: ('CHIR-98014', 'temozolomide'),
#  504: ('CHIR-99021 HCl', 'temozolomide'),
#  505: ('chlormezanone', 'temozolomide'),
#  506: ('chloroxine', 'temozolomide'),
#  507: ('Chlorpheniramine maleate', 'temozolomide'),
#  508: ('Chlorpromazine hydrochloride', 'temozolomide'),
#  509: ('chlorpropamide', 'temozolomide'),
#  510: ('CHOLINE CHLORIDE', 'temozolomide'),
#  511: ('chromocarb', 'temozolomide'),
#  512: ('CILAZAPRIL MONOHYDRATE', 'temozolomide'),
#  513: ('Cilengitide', 'temozolomide'),
#  514: ('cilnidipine', 'temozolomide'),
#  515: ('Cinacalcet hydrochloride', 'temozolomide'),
#  516: ('Cinchophen', 'temozolomide'),
#  517: ('cinoxacin', 'temozolomide'),
#  518: ('ciproxifan', 'temozolomide'),
#  519: ('CLEMASTINE FUMARATE', 'temozolomide'),
#  520: ('Clevudine', 'temozolomide'),
#  521: ('clinofibrate', 'temozolomide'),
#  522: ('clofazimine', 'temozolomide'),
#  523: ('clofibric acid', 'temozolomide'),
#  524: ('Clomifene citrate', 'temozolomide'),
#  525: ('Clomipramine hydrochloride', 'temozolomide'),
#  526: ('clotrimazole', 'temozolomide'),
#  527: ('Cloxacillin sodium', 'temozolomide'),
#  528: ('CNX-774', 'temozolomide'),
#  529: ('Rociletinib', 'temozolomide'),
#  530: ('coumarin', 'temozolomide'),
#  531: ('CP-724714', 'temozolomide'),
#  532: ('CUDC-101', 'temozolomide'),
#  533: ('Silmitasertib', 'temozolomide'),
#  534: ('cyclandelate', 'temozolomide'),
#  535: ('cyclosporin A', 'temozolomide'),
#  536: ('cyclosporine', 'temozolomide'),
#  537: ('CYPROTERONE ACETATE', 'temozolomide'),
#  538: ('Cyt387', 'temozolomide'),
#  539: ('cytidine', 'temozolomide'),
#  540: ('CZC24832', 'temozolomide'),
#  541: ('Dabrafenib', 'temozolomide'),
#  542: ('dacarbazine', 'temozolomide'),
#  543: ('Dacomitinib', 'temozolomide'),
#  544: ('daidzein', 'temozolomide'),
#  545: ('Dapivirine', 'temozolomide'),
#  546: ('Dapoxetine hydrochloride', 'temozolomide'),
#  547: ('dapt', 'temozolomide'),
#  548: ('Darunavir ethanolate', 'temozolomide'),
#  549: ('DBeQ', 'temozolomide'),
#  550: ('REBASTINIB', 'temozolomide'),
#  551: ('DECAMETHONIUM BROMIDE', 'temozolomide'),
#  552: ('Decitabine', 'temozolomide'),
#  553: ('Deferasirox', 'temozolomide'),
#  554: ('856243-80-6', 'temozolomide'),
#  555: ('Deoxyarbutin', 'temozolomide'),
#  556: ('Desloratadine', 'temozolomide'),
#  557: ('Desvenlafaxine', 'temozolomide'),
#  558: ('DETOMIDINE HYDROCHLORIDE', 'temozolomide'),
#  559: ('dexamethasone', 'temozolomide'),
#  560: ('Dicloxacillin sodium', 'temozolomide'),
#  561: ('didanosine', 'temozolomide'),
#  562: ('diethylstilbestrol', 'temozolomide'),
#  563: ('Dihydroartemisinin', 'temozolomide'),
#  564: ('Dimesna', 'temozolomide'),
#  565: ('dipyridamole', 'temozolomide'),
#  566: ('Dirithromycin', 'temozolomide'),
#  567: ('DIVALPROEX SODIUM', 'temozolomide'),
#  568: ('domiphen bromide', 'temozolomide'),
#  569: ('Dovitinib lactate', 'temozolomide'),
#  570: ('Dovitinib', 'temozolomide'),
#  571: ('Doxazosin mesylate', 'temozolomide'),
#  572: ('Doxercalciferol', 'temozolomide'),
#  573: ('DOXOFYLLINE', 'temozolomide'),
#  574: ('Doxylamine succinate', 'temozolomide'),
#  575: ('droperidol', 'temozolomide'),
#  576: ('Dyclonine hydrochloride', 'temozolomide'),
#  577: ('ebastine', 'temozolomide'),
#  578: ('EDOXABAN', 'temozolomide'),
#  579: ('Efaproxiral sodium', 'temozolomide'),
#  580: ('EHop-016', 'temozolomide'),
#  581: ('Eltrombopag', 'temozolomide'),
#  582: ('Enzalutamide', 'temozolomide'),
#  583: ('EPIANDROSTERONE', 'temozolomide'),
#  584: ('EPZ005687', 'temozolomide'),
#  585: ('ERASTIN', 'temozolomide'),
#  586: ('ERGOSTEROL', 'temozolomide'),
#  587: ('Erlotinib hydrochloride', 'temozolomide'),
#  588: ('OMEPRAZOLE SODIUM', 'temozolomide'),
#  589: ('estriol', 'temozolomide'),
#  590: ('6402-23-9', 'temozolomide'),
#  591: ('etoposide', 'temozolomide'),
#  592: ('159351-69-6', 'temozolomide'),
#  593: ('famotidine', 'temozolomide'),
#  594: ('Famprofazone', 'temozolomide'),
#  595: ('Fasudil hydrochloride', 'temozolomide'),
#  596: ('felodipine', 'temozolomide'),
#  597: ('Florfenicol', 'temozolomide'),
#  598: ('fluconazole', 'temozolomide'),
#  599: ('flumazenil', 'temozolomide'),
#  600: ('Flunarizine dihydrochloride', 'temozolomide'),
#  601: ('fluocinonide', 'temozolomide'),
#  602: ('5-Fluorouracil', 'temozolomide'),
#  603: ('FORMOTEROL FUMARATE', 'temozolomide'),
#  604: ('forskolin', 'temozolomide'),
#  605: ('FOSCARNET SODIUM', 'temozolomide'),
#  606: ('tegafur', 'temozolomide'),
#  607: ('Fulvestrant', 'temozolomide'),
#  608: ('Furaltadone hydrochloride', 'temozolomide'),
#  609: ('Galeterone', 'temozolomide'),
#  610: ('Ipatasertib', 'temozolomide'),
#  611: ('GDC-0152', 'temozolomide'),
#  612: ('GDC-0349', 'temozolomide'),
#  613: ('GDC-0879', 'temozolomide'),
#  614: ('957054-30-7', 'temozolomide'),
#  615: ('Gefitinib', 'temozolomide'),
#  616: ('geldanamycin', 'temozolomide'),
#  617: ('Genipin', 'temozolomide'),
#  618: ('GESTODENE', 'temozolomide'),
#  619: ('Gimeracil', 'temozolomide'),
#  620: ('Ginkgolide A', 'temozolomide'),
#  621: ('glafenine', 'temozolomide'),
#  622: ('glipizide', 'temozolomide'),
#  623: ('glyburide', 'temozolomide'),
#  624: ('go 6983', 'temozolomide'),
#  625: ('Golvatinib', 'temozolomide'),
#  626: ('gossypol', 'temozolomide'),
#  627: ('Granisetron HCl', 'temozolomide'),
#  628: ('GSK J4 HCl', 'temozolomide'),
#  629: ('GSK1059615', 'temozolomide'),
#  630: ('GSK1070916', 'temozolomide'),
#  631: ('GSK1904529A', 'temozolomide'),
#  632: ('GSK429286A', 'temozolomide'),
#  633: ('937174-76-0', 'temozolomide'),
#  634: ('278779-30-9', 'temozolomide'),
#  635: ('GW 441756', 'temozolomide'),
#  636: ('H-89 DIHYDROCHLORIDE', 'temozolomide'),
#  637: ('ha14-1', 'temozolomide'),
#  638: ('hydroxyurea', 'temozolomide'),
#  639: ('1260907-17-2', 'temozolomide'),
#  640: ('1300031-49-5', 'temozolomide'),
#  641: ('ibuprofen', 'temozolomide'),
#  642: ('ICG-001', 'temozolomide'),
#  643: ('Icotinib', 'temozolomide'),
#  644: ('idoxuridine', 'temozolomide'),
#  645: ('ifenprodil tartrate', 'temozolomide'),
#  646: ('ifosfamide', 'temozolomide'),
#  647: ('873225-46-8', 'temozolomide'),
#  648: ('Imatinib', 'temozolomide'),
#  649: ('Imatinib mesylate', 'temozolomide'),
#  650: ('Imipramine hydrochloride', 'temozolomide'),
#  651: ('capmatinib', 'temozolomide'),
#  652: ('indapamide', 'temozolomide'),
#  653: ('Indirubin', 'temozolomide'),
#  654: ('iOWH-032', 'temozolomide'),
#  655: ('IPA-3', 'temozolomide'),
#  656: ('Duvelisib', 'temozolomide'),
#  657: ('irinotecan', 'temozolomide'),
#  658: ('IRINOTECAN HYDROCHLORIDE Trihydrate', 'temozolomide'),
#  659: ('isoconazole nitrate', 'temozolomide'),
#  660: ('Isotretinoin', 'temozolomide'),
#  661: ('Istradefylline', 'temozolomide'),
#  662: ('314245-33-5', 'temozolomide'),
#  663: ('IWP-L6', 'temozolomide'),
#  664: ('IWR-1-endo', 'temozolomide'),
#  665: ('JIB-04', 'temozolomide'),
#  666: ('Serdemetan', 'temozolomide'),
#  667: ('JNJ-7706621', 'temozolomide'),
#  668: ('JTC-801', 'temozolomide'),
#  669: ('Ki16425', 'temozolomide'),
#  670: ('KRN-633', 'temozolomide'),
#  671: ('Ku-0063794', 'temozolomide'),
#  672: ('KU-55933', 'temozolomide'),
#  673: ('KU-60019', 'temozolomide'),
#  674: ('10030-85-0', 'temozolomide'),
#  675: ('ASCORBYL PALMITATE', 'temozolomide'),
#  676: ('lafutidine', 'temozolomide'),
#  677: ('lamivudine', 'temozolomide'),
#  678: ('Lapatinib Ditosylate', 'temozolomide'),
#  679: ('Sonidegib', 'temozolomide'),
#  680: ('ceritinib', 'temozolomide'),
#  681: ('LDN-57444', 'temozolomide'),
#  682: ('Lenvatinib', 'temozolomide'),
#  683: ('letrozole', 'temozolomide'),
#  684: ('Limonin', 'temozolomide'),
#  685: ('Linagliptin', 'temozolomide'),
#  686: ('Linifanib', 'temozolomide'),
#  687: ('Lomeguatrib', 'temozolomide'),
#  688: ('Lomerizine hydrochloride', 'temozolomide'),
#  689: ('Lornoxicam', 'temozolomide'),
#  690: ('LOSARTAN POTASSIUM', 'temozolomide'),
#  691: ('lovastatin', 'temozolomide'),
#  692: ('Loxapine succinate', 'temozolomide'),
#  693: ('luteolin', 'temozolomide'),
#  694: ('LY2228820', 'temozolomide'),
#  695: ('LY2608204', 'temozolomide'),
#  696: ('396129-53-6', 'temozolomide'),
#  697: ('m344', 'temozolomide'),
#  698: ('Magnolol', 'temozolomide'),
#  699: ('manidipine', 'temozolomide'),
#  700: ('Manidipine dihydrochloride', 'temozolomide'),
#  701: ('Marbofloxacin', 'temozolomide'),
#  702: ('Masitinib', 'temozolomide'),
#  703: ('852475-26-4', 'temozolomide'),
#  704: ('Mdivi-1', 'temozolomide'),
#  705: ('Mecarbinate', 'temozolomide'),
#  706: ('MEMANTINE HYDROCHLORIDE', 'temozolomide'),
#  707: ('menadione', 'temozolomide'),
#  708: ('MEPENZOLATE BROMIDE', 'temozolomide'),
#  709: ('meprednisone', 'temozolomide'),
#  710: ('4-Methoxyphenol', 'temozolomide'),
#  711: ('Methylhydantoin-5-(D)', 'temozolomide'),
#  712: ('methylprednisolone', 'temozolomide'),
#  713: ('metronidazole', 'temozolomide'),
#  714: ('MEZLOCILLIN SODIUM', 'temozolomide'),
#  715: ('MGCD-265', 'temozolomide'),
#  716: ('Milnacipran hydrochloride', 'temozolomide'),
#  717: ('mirtazapine', 'temozolomide'),
#  718: ('1032350-13-2', 'temozolomide'),
#  719: ('MK-2461', 'temozolomide'),
#  720: ('ENOBOSARM', 'temozolomide'),
#  721: ('MK-5108', 'temozolomide'),
#  722: ('MK-8245', 'temozolomide'),
#  723: ('1485-00-3', 'temozolomide'),
#  724: ('Monobenzone', 'temozolomide'),
#  725: ('MONTELUKAST SODIUM', 'temozolomide'),
#  726: ('Motesanib diphosphate', 'temozolomide'),
#  727: ('Moxifloxacin hydrochloride', 'temozolomide'),
#  728: ('MOXONIDINE', 'temozolomide'),
#  729: ('Mozavaptan', 'temozolomide'),
#  730: ('MPEP', 'temozolomide'),
#  731: ('MRS 2578', 'temozolomide'),
#  732: ('Myricitrin', 'temozolomide'),
#  733: ('Nanchangmycin', 'temozolomide'),
#  734: ('Neratinib', 'temozolomide'),
#  735: ('NICARDIPINE HYDROCHLORIDE', 'temozolomide'),
#  736: ('niflumic acid', 'temozolomide'),
#  737: ('Nifuroxazide', 'temozolomide'),
#  738: ('Nilotinib', 'temozolomide'),
#  739: ('nisoldipine', 'temozolomide'),
#  740: ('NMS-873', 'temozolomide'),
#  741: ('NSC 405020', 'temozolomide'),
#  742: ('NU6027', 'temozolomide'),
#  743: ('503468-95-9', 'temozolomide'),
#  744: ('Nutlin-3', 'temozolomide'),
#  745: ('NVP-ADW742', 'temozolomide'),
#  746: ('NVP-AEW541', 'temozolomide'),
#  747: ('NVP-BHG712', 'temozolomide'),
#  748: ('NVP-BSK805 2HCl', 'temozolomide'),
#  749: ('851723-84-7', 'temozolomide'),
#  750: ('Olaparib', 'temozolomide'),
#  751: ('oligomycin A', 'temozolomide'),
#  752: ('Omecamtiv mecarbil', 'temozolomide'),
#  753: ('omeprazole', 'temozolomide'),
#  754: ('orlistat', 'temozolomide'),
#  755: ('Orphenadrine citrate', 'temozolomide'),
#  756: ('OSI-027', 'temozolomide'),
#  757: ('OSI-420', 'temozolomide'),
#  758: ('Linsitinib', 'temozolomide'),
#  759: ('OSI-930', 'temozolomide'),
#  760: ('Osthole', 'temozolomide'),
#  761: ('OSU-03012', 'temozolomide'),
#  762: ('OXCARBAZEPINE', 'temozolomide'),
#  763: ('Oxethazaine', 'temozolomide'),
#  764: ('Oxfendazole', 'temozolomide'),
#  765: ('oxymetholone', 'temozolomide'),
#  766: ('1247819-59-5', 'temozolomide'),
#  767: ('PA-824', 'temozolomide'),
#  768: ('315183-21-2', 'temozolomide'),
#  769: ('Paroxetine hydrochloride', 'temozolomide'),
#  770: ('Pazopanib', 'temozolomide'),
#  771: ('391210-10-9', 'temozolomide'),
#  772: ('(+)-PD 128907 hydrochloride', 'temozolomide'),
#  773: ('PD168393', 'temozolomide'),
#  774: ('219580-11-7', 'temozolomide'),
#  775: ('212631-79-3', 'temozolomide'),
#  776: ('PD318088', 'temozolomide'),
#  777: ('Pefloxacin mesylate', 'temozolomide'),
#  778: ('Pelitinib', 'temozolomide'),
#  779: ('penciclovir', 'temozolomide'),
#  780: ('PF-04217903', 'temozolomide'),
#  781: ('1111636-35-1', 'temozolomide'),
#  782: ('PF-3845', 'temozolomide'),
#  783: ('PF-4708671', 'temozolomide'),
#  784: ('PF-477736', 'temozolomide'),
#  785: ('PF-5274857', 'temozolomide'),
#  786: ('PF-562271', 'temozolomide'),
#  787: ('869288-64-2', 'temozolomide'),
#  788: ('PFI-1', 'temozolomide'),
#  789: ('PH-797804', 'temozolomide'),
#  790: ('PHA-680632', 'temozolomide'),
#  791: ('PHA-767491', 'temozolomide'),
#  792: ('PHA-793887', 'temozolomide'),
#  793: ('PHT-427', 'temozolomide'),
#  794: ('PI-103', 'temozolomide'),
#  795: ('Pidotimod', 'temozolomide'),
#  796: ('Pifithrin-alpha', 'temozolomide'),
#  797: ('PIK-294', 'temozolomide'),
#  798: ('PIK-93', 'temozolomide'),
#  799: ('Pilocarpine hydrochloride', 'temozolomide'),
#  800: ('Pimasertib', 'temozolomide'),
#  801: ('PIPERACILLIN SODIUM', 'temozolomide'),
#  802: ('piromidic acid', 'temozolomide'),
#  803: ('piroxicam', 'temozolomide'),
#  804: ('Pitavastatin calcium', 'temozolomide'),
#  805: ('PJ34', 'temozolomide'),
#  806: ('PLX-4720', 'temozolomide'),
#  807: ('501925-31-1', 'temozolomide'),
#  808: ('Polydatin', 'temozolomide'),
#  809: ('Pomalidomide', 'temozolomide'),
#  810: ('Posaconazole', 'temozolomide'),
#  811: ('172889-26-8', 'temozolomide'),
#  812: ('172889-27-9', 'temozolomide'),
#  813: ('PP242', 'temozolomide'),
#  814: ('PQ401', 'temozolomide'),
#  815: ('Pracinostat', 'temozolomide'),
#  816: ('prednisolone', 'temozolomide'),
#  817: ('Pridinol methanesulfonate', 'temozolomide'),
#  818: ('Proadifen hydrochloride', 'temozolomide'),
#  819: ('Prochlorperazine dimaleate', 'temozolomide'),
#  820: ('Procyclidine hydrochloride', 'temozolomide'),
#  821: ('progesterone', 'temozolomide'),
#  822: ('prothionamide', 'temozolomide'),
#  823: ('1370261-97-4', 'temozolomide'),
#  824: ('Purmorphamine', 'temozolomide'),
#  825: ('PYR-41', 'temozolomide'),
#  826: ('Quetiapine fumarate', 'temozolomide'),
#  827: ('Quizartinib', 'temozolomide'),
#  828: ('R406', 'temozolomide'),
#  829: ('Ractopamine hydrochloride', 'temozolomide'),
#  830: ('Raltegravir', 'temozolomide'),
#  831: ('Ramelteon', 'temozolomide'),
#  832: ('RANOLAZINE', 'temozolomide'),
#  833: ('(-)-Rapamycin', 'temozolomide'),
#  834: ('rebamipide', 'temozolomide'),
#  835: ('Regorafenib', 'temozolomide'),
#  836: ('reserpine', 'temozolomide'),
#  837: ('Resminostat', 'temozolomide'),
#  838: ('RG108', 'temozolomide'),
#  839: ('RG2833', 'temozolomide'),
#  840: ('RGFP966', 'temozolomide'),
#  841: ('Rilpivirine', 'temozolomide'),
#  842: ('Rimonabant', 'temozolomide'),
#  843: ('ritonavir', 'temozolomide'),
#  844: ('1316214-52-4', 'temozolomide'),
#  845: ('Roflumilast', 'temozolomide'),
#  846: ('rolipram', 'temozolomide'),
#  847: ('roscovitine', 'temozolomide'),
#  848: ('Rosuvastatin calcium', 'temozolomide'),
#  849: ('roxatidine acetate hydrochloride', 'temozolomide'),
#  850: ('RS-127445', 'temozolomide'),
#  851: ('Rucaparib phosphate', 'temozolomide'),
#  852: ('Ruxolitinib', 'temozolomide'),
#  853: ('501919-59-1', 'temozolomide'),
#  854: ('salubrinal', 'temozolomide'),
#  855: ('SAR131675', 'temozolomide'),
#  856: ('Saracatinib', 'temozolomide'),
#  857: ('Salsalate', 'temozolomide'),
#  858: ('SB 202190', 'temozolomide'),
#  859: ('261901-57-9', 'temozolomide'),
#  860: ('288150-92-5', 'temozolomide'),
#  861: ('264218-23-7', 'temozolomide'),
#  862: ('301836-41-9', 'temozolomide'),
#  863: ('SB-505124', 'temozolomide'),
#  864: ('607742-69-8', 'temozolomide'),
#  865: ('Scopine hydrochloride', 'temozolomide'),
#  866: ('scriptaid', 'temozolomide'),
#  867: ('Semaxanib', 'temozolomide'),
#  868: ('Sertraline hydrochloride', 'temozolomide'),
#  869: ('SGC0946', 'temozolomide'),
#  870: ('SGI-1027', 'temozolomide'),
#  871: ('SGI-1776', 'temozolomide'),
#  872: ('SGX-523', 'temozolomide'),
#  873: ('Sildenafil citrate', 'temozolomide'),
#  874: ('simvastatin', 'temozolomide'),
#  875: ('Sirtinol', 'temozolomide'),
#  876: ('SKI II', 'temozolomide'),
#  877: ('Sodium 4-aminosalicylate', 'temozolomide'),
#  878: ('SODIUM NITRITE', 'temozolomide'),
#  879: ('14402-89-2', 'temozolomide'),
#  880: ('Sorafenib', 'temozolomide'),
#  881: ('Sorafenib tosylate', 'temozolomide'),
#  882: ('sparfloxacin', 'temozolomide'),
#  883: ('spiramycin', 'temozolomide'),
#  884: ('Stattic', 'temozolomide'),
#  885: ('Stavudine (d4T)', 'temozolomide'),
#  886: ('StemRegenin 1', 'temozolomide'),
#  887: ('STF-62247', 'temozolomide'),
#  888: ('Sucralose', 'temozolomide'),
#  889: ('SULBACTAM SODIUM', 'temozolomide'),
#  890: ('Sulfacetamide sodium', 'temozolomide'),
#  891: ('sulfamethazine', 'temozolomide'),
#  892: ('sulfamethoxazole', 'temozolomide'),
#  893: ('sulfanilamide', 'temozolomide'),
#  894: ('sulindac', 'temozolomide'),
#  895: ('SUMATRIPTAN SUCCINATE', 'temozolomide'),
#  896: ('Suplatast Tosilate', 'temozolomide'),
#  897: ('T0901317', 'temozolomide'),
#  898: ('tacrolimus', 'temozolomide'),
#  899: ('761439-42-3', 'temozolomide'),
#  900: ('TAK-285', 'temozolomide'),
#  901: ('TAK-632', 'temozolomide'),
#  902: ('TAK-715', 'temozolomide'),
#  903: ('TAK-733', 'temozolomide'),
#  904: ('Fasiglifam', 'temozolomide'),
#  905: ('Tame', 'temozolomide'),
#  906: ('Tamibarotene', 'temozolomide'),
#  907: ('Tamoxifen citrate', 'temozolomide'),
#  908: ('Tandutinib', 'temozolomide'),
#  909: ('tazarotene', 'temozolomide'),
#  910: ('Telatinib', 'temozolomide'),
#  911: ('temozolomide', 'temozolomide'),
#  912: ('Temsirolimus', 'temozolomide'),
#  913: ('terfenadine', 'temozolomide'),
#  914: ('4961-41-5', 'temozolomide'),
#  915: ('tetrandrine', 'temozolomide'),
#  916: ('TG100-115', 'temozolomide'),
#  917: ('Fedratinib', 'temozolomide'),
#  918: ('TGX-221', 'temozolomide'),
#  919: ('thiabendazole', 'temozolomide'),
#  920: ('thiamphenicol', 'temozolomide'),
#  921: ('Thiazovivin', 'temozolomide'),
#  922: ('Thioridazine hydrochloride', 'temozolomide'),
#  923: ('THONZONIUM BROMIDE', 'temozolomide'),
#  924: ('1616632-77-9', 'temozolomide'),
#  925: ('Ticagrelor', 'temozolomide'),
#  926: ('ticarcillin sodium', 'temozolomide'),
#  927: ('Tie2 kinase inhibitor', 'temozolomide'),
#  928: ('Tipifarnib', 'temozolomide'),
#  929: ('Tiratricol', 'temozolomide'),
#  930: ('Tivozanib', 'temozolomide'),
#  931: ('Tofacitinib citrate', 'temozolomide'),
#  932: ('Tofacitinib', 'temozolomide'),
#  933: ('Tolazoline hydrochloride', 'temozolomide'),
#  934: ('tolbutamide', 'temozolomide'),
#  935: ('tolnaftate', 'temozolomide'),
#  936: ('Tolperisone hydrochloride', 'temozolomide'),
#  937: ('Tolterodine tartrate', 'temozolomide'),
#  938: ('Toltrazuril', 'temozolomide'),
#  939: ('Torcetrapib', 'temozolomide'),
#  940: ('Tosedostat', 'temozolomide'),
#  941: ('TPCA-1', 'temozolomide'),
#  942: ('Trametinib', 'temozolomide'),
#  943: ('Retinoic acid', 'temozolomide'),
#  944: ('triamterene', 'temozolomide'),
#  945: ('Triciribine', 'temozolomide'),
#  946: ('Trifluridine', 'temozolomide'),
#  947: ('Tripelennamine hydrochloride', 'temozolomide'),
#  948: ('trospium chloride', 'temozolomide'),
#  949: ('TTNPB', 'temozolomide'),
#  950: ('Tubastatin A HCl', 'temozolomide'),
#  951: ('TWS119', 'temozolomide'),
#  952: ('tylosin tartrate', 'temozolomide'),
#  953: ('CBiol_001931', 'temozolomide'),
#  954: ('U0126-EtOH', 'temozolomide'),
#  955: ('UNC1999', 'temozolomide'),
#  956: ('Urapidil hydrochloride', 'temozolomide'),
#  957: ('Ursolic acid', 'temozolomide'),
#  958: ('Valganciclovir hydrochloride', 'temozolomide'),
#  959: ('Valnemulin hydrochloride', 'temozolomide'),
#  960: ('Vandetanib', 'temozolomide'),
#  961: ('vanillin', 'temozolomide'),
#  962: ('ZINGERONE', 'temozolomide'),
#  963: ('VARLITINIB', 'temozolomide'),
#  964: ('Vatalanib dihydrochloride', 'temozolomide'),
#  965: ('Veliparib', 'temozolomide'),
#  966: ('Vemurafenib', 'temozolomide'),
#  967: ('venlafaxine', 'temozolomide'),
#  968: ('Verapamil hydrochloride', 'temozolomide'),
#  969: ('l-ascorbic acid', 'temozolomide'),
#  970: ('Voriconazole', 'temozolomide'),
#  971: ('Vorinostat', 'temozolomide'),
#  972: ('VX-661', 'temozolomide'),
#  973: ('VX-702', 'temozolomide'),
#  974: ('WAY-600', 'temozolomide'),
#  975: ('WHI-P154', 'temozolomide'),
#  976: ('WP1066', 'temozolomide'),
#  977: ('WYE-354', 'temozolomide'),
#  978: ('1214265-56-1', 'temozolomide'),
#  979: ('WZ4002', 'temozolomide'),
#  980: ('WZ8040', 'temozolomide'),
#  981: ('55778-02-4', 'temozolomide'),
#  982: ('284028-89-3', 'temozolomide'),
#  983: ('XL019', 'temozolomide'),
#  984: ('371942-69-7', 'temozolomide'),
#  985: ('Zebularine', 'temozolomide'),
#  986: ('zidovudine', 'temozolomide'),
#  987: ('ZILEUTON', 'temozolomide'),
#  988: ('ZLN005', 'temozolomide'),
#  989: ('690206-97-4', 'temozolomide'),
#  990: ('Zoledronic acid', 'temozolomide'),
#  991: ('zonisamide', 'temozolomide'),
#  992: ('167465-36-3', 'temozolomide'),
#  993: ('ZSTK474', 'temozolomide'),
#  994: ('actinomycin D', 'carmustine'),
#  995: ('actinomycin D', 'Fulvestrant'),
#  996: ('Eloxatin (TN) (Sanofi Synthelab)', 'ifosfamide'),
#  997: ('Triethylenemelamine', 'Sorafenib'),
#  998: ('actinomycin D', 'Nilotinib'),
#  999: ('thalidomide', 'TOPOTECAN HYDROCHLORIDE'),
#  ...}

# %%
ReaderWriter.dump_data(pairs, os.path.join(targetdata_dir_raw, 'pairs.pkl'))

# %%
ReaderWriter.dump_data(data, os.path.join(targetdata_dir_raw, 'data_pairs.pkl'))

# %%
# pairs_sub = {k: pairs[k] for k in range(10)}
# pairs_sub

# %%
uniq_mol.loc['ZINC34894448']
# Out:
# Drug       CCC1=C2N=C(C=C(N2N=C1)NCC3=C[N+](=CC=C3)[O-])N...
# Mol         <rdkit.Chem.rdchem.Mol object at 0x2b235b72a520>
# DataOGB    [(edge_index, [tensor([ 0,  1,  1,  2,  2,  3,...
# xFlat      [tensor(5.3448), tensor(0.), tensor(3.1724), t...
# Name: ZINC34894448, dtype: object

# %%
# %%time

# X = ReaderWriter.read_or_dump_data(file_name=norm_join_paths(targetdata_dir_raw, 'X.pkl'),
#                               data_gen_fun=get_X_all_pairdata_synergy,
#                               data_gen_params=(uniq_mol, pairs, "DataOGB"))

# %%
# %%time

X = ReaderWriter.read_or_dump_data(file_name=norm_join_paths(targetdata_dir_raw, 'X_flat.pkl'),
                              data_gen_fun=get_X_all_pairdata_synergy_flat,
                              data_gen_params=(uniq_mol, pairs, "xFlat"))
# Out:
# CPU times: user 3.5 s, sys: 19.4 ms, total: 3.52 s
# Wall time: 3.53 s

# %%
# X = get_X_all_pairdata(uniq_mol, pairs)

# ReaderWriter.dump_data(X, os.path.join(targetdata_dir_raw, 'X.pkl'))

#X = ReaderWriter.read_data(os.path.join(targetdata_dir_raw, 'X.pkl'))

# %%
# X

# %%
targetdata_dir
# Out:
# '/cluster/home/skyriakos/chemprop_run/git/data/processed/DrugComb_total_thresh_4/data_v2'

# %%
targetdata_dir_processed
# Out:
# '/cluster/home/skyriakos/chemprop_run/git/data/processed/DrugComb_total_thresh_4/data_v2/processed'

# %%
# import glob

# list_generated_files = glob.glob(targetdata_dir_processed + "/*")
# print(list_generated_files)

# for file in list_generated_files:
#     os.remove(file)

# %%
# %%time

# In order to generate a new Dataset, first remove the generated files above

dataset = MoleculeDataset(root=targetdata_dir, dataset='tdcSynergy')
# Out:
# Processing...
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <timed exec> in <module>
#
# ~/chemprop_run/git/deepadr/dataset.py in __init__(self, root, transform, pre_transform, pre_filter, dataset, smiles_list, empty)
#      44 #         create_directory("processed", root)
#      45
# ---> 46         super(MoleculeDataset, self).__init__(root, transform, pre_transform,
#      47                                                  pre_filter)
#      48         self.transform, self.pre_transform, self.pre_filter = transform, pre_transform, pre_filter
#
# /opt/conda/envs/graphnn/lib/python3.9/site-packages/torch_geometric/data/in_memory_dataset.py in __init__(self, root, transform, pre_transform, pre_filter)
#      55                  pre_transform: Optional[Callable] = None,
#      56                  pre_filter: Optional[Callable] = None):
# ---> 57         super().__init__(root, transform, pre_transform, pre_filter)
#      58         self.data = None
#      59         self.slices = None
#
# /opt/conda/envs/graphnn/lib/python3.9/site-packages/torch_geometric/data/dataset.py in __init__(self, root, transform, pre_transform, pre_filter)
#      86
#      87         if 'process' in self.__class__.__dict__:
# ---> 88             self._process()
#      89
#      90     def indices(self) -> Sequence:
#
# /opt/conda/envs/graphnn/lib/python3.9/site-packages/torch_geometric/data/dataset.py in _process(self)
#     169
#     170         makedirs(self.processed_dir)
# --> 171         self.process()
#     172
#     173         path = osp.join(self.processed_dir, 'pre_transform.pt')
#
# ~/chemprop_run/git/deepadr/dataset.py in process(self)
#     138
#     139         elif self.dataset == 'tdcSynergy':
# --> 140             X = ReaderWriter.read_data(os.path.join(self.raw_dir, 'X.pkl'))
#     141             y = ReaderWriter.read_data(os.path.join(self.raw_dir, 'y.pkl'))
#     142             expression = ReaderWriter.read_data(os.path.join(self.raw_dir, 'expression.pkl'))
#
# ~/chemprop_run/git/deepadr/utilities.py in read_data(file_name, mode)
#     126                mode: specify writing options i.e. binary or unicode
#     127         """
# --> 128         with open(file_name, mode) as f:
#     129             data = pickle.load(f)
#     130         return(data)
#
# FileNotFoundError: [Errno 2] No such file or directory: '/cluster/home/skyriakos/chemprop_run/git/data/processed/DrugComb_total_thresh_4/data_v2/raw/X.pkl'

# %%
print()
print(f'Dataset: {dataset}:')
print('====================')
print(f'Number of graphs: {len(dataset)}')
print(f'Number of features: {dataset.num_features}')
print(f'Number of classes: {dataset.num_classes}')

data0 = dataset[0]  # Get the first graph object.

# print()
# print(data)
# print('=============================================================')

# # Gather some statistics about the first graph.
# print(f'Number of nodes: {data.num_nodes}')
# print(f'Number of edges: {data.num_edges}')
# print(f'Average node degree: {data.num_edges / data.num_nodes:.2f}')
# print(f'Contains isolated nodes: {data.contains_isolated_nodes()}')
# print(f'Contains self-loops: {data.contains_self_loops()}')
# print(f'Is undirected: {data.is_undirected()}')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_23243/1699795823.py in <module>
#       1 print()
# ----> 2 print(f'Dataset: {dataset}:')
#       3 print('====================')
#       4 print(f'Number of graphs: {len(dataset)}')
#       5 print(f'Number of features: {dataset.num_features}')
#
# NameError: name 'dataset' is not defined

# %%
data0

# %%
data0.expression.dtype

# %%
len(dataset)
