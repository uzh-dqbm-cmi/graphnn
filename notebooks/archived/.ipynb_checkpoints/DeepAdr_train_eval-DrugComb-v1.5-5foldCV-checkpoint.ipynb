# %%
# %load_ext autoreload
# %autoreload 2

# %%
import os
import sys
import numpy as np
import pandas as pd
import datetime
import seaborn as sns
import ogb
from tqdm import tqdm
import hiplot as hip
from copy import deepcopy
import datetime

# %%
import torch
from torch_geometric.data import Data
from torch_geometric.loader import DataLoader
from torch.utils.data import Subset, TensorDataset

# %%
cwd = os.getcwd()
print(cwd)
# Out:
# /cluster/home/skyriakos/chemprop_run/git/notebooks

# %%
os.chdir('..')
import deepadr
from deepadr.dataset import *
from deepadr.utilities import *
from deepadr.run_workflow import *
from deepadr.chemfeatures import *
from deepadr.hyphelper import *
# from deepadr.model_gnn import GCN as testGCN
from deepadr.model_gnn_ogb import GNN, DeepAdr_SiameseTrf, ExpressionNN
# from deepadr.model_attn_siamese import *
from ogb.graphproppred import Evaluator
os.chdir(cwd)

# %%
from rdkit.Chem.Draw import IPythonConsole
from rdkit.Chem import Draw

# %%
# from tdc.single_pred import Tox
# from tdc.multi_pred import DDI

# %%
rawdata_dir = '../data/raw/'
processed_dir = '../data/processed/'
up_dir = '..'

# %%
report_available_cuda_devices()
# Out:
# number of GPUs available: 8
# cuda:0, name:GeForce GTX 1080 Ti
# total memory available: 10.91650390625 GB
# total memory allocated on device: 0.0 GB
# max memory allocated on device: 0.0 GB
# total memory cached on device: 0.0 GB
# max memory cached  on device: 0.0 GB
#
# cuda:1, name:GeForce GTX 1080 Ti
# total memory available: 10.91650390625 GB
# total memory allocated on device: 0.0 GB
# max memory allocated on device: 0.0 GB
# total memory cached on device: 0.0 GB
# max memory cached  on device: 0.0 GB
#
# cuda:2, name:GeForce GTX 1080 Ti
# total memory available: 10.91650390625 GB
# total memory allocated on device: 0.0 GB
# max memory allocated on device: 0.0 GB
# total memory cached on device: 0.0 GB
# max memory cached  on device: 0.0 GB
#
# cuda:3, name:GeForce GTX 1080 Ti
# total memory available: 10.91650390625 GB
# total memory allocated on device: 0.0 GB
# max memory allocated on device: 0.0 GB
# total memory cached on device: 0.0 GB
# max memory cached  on device: 0.0 GB
#
# cuda:4, name:GeForce GTX 1080 Ti
# total memory available: 10.91650390625 GB
# total memory allocated on device: 0.0 GB
# max memory allocated on device: 0.0 GB
# total memory cached on device: 0.0 GB
# max memory cached  on device: 0.0 GB
#
# cuda:5, name:GeForce GTX 1080 Ti
# total memory available: 10.91650390625 GB
# total memory allocated on device: 0.0 GB
# max memory allocated on device: 0.0 GB
# total memory cached on device: 0.0 GB
# max memory cached  on device: 0.0 GB
#
# cuda:6, name:GeForce GTX 1080 Ti
# total memory available: 10.91650390625 GB
# total memory allocated on device: 0.0 GB
# max memory allocated on device: 0.0 GB
# total memory cached on device: 0.0 GB
# max memory cached  on device: 0.0 GB
#
# cuda:7, name:GeForce GTX 1080 Ti
# total memory available: 10.91650390625 GB
# total memory allocated on device: 0.0 GB
# max memory allocated on device: 0.0 GB
# total memory cached on device: 0.0 GB
# max memory cached  on device: 0.0 GB

# %%
n_gpu = torch.cuda.device_count()
n_gpu
# Out:
# 8

# %%
device_cpu = get_device(to_gpu=False)
# device_gpu = get_device(True, index=0)

# fdtype = torch.float32

# %%
print("torch:", torch.__version__)
print("CUDA:", torch.version.cuda)
print(sys.version)
# Out:
# torch: 1.9.1
# CUDA: 11.1
# 3.9.9 | packaged by conda-forge | (main, Dec 20 2021, 02:41:03)
# [GCC 9.4.0]

# %%
# print(torch.cuda.memory_summary(device=device_gpu))

# %% [markdown]
# ### Preparing dataset

# %%
score = 'total_thresh'
score_val = 3

# %%
# TDC Tox
# DSdataset_name = 'SynergxZloewe' #'OncoPolyPharmacology' #'DrugComb'
DSdataset_name = f'DrugComb_{score}_{score_val}' #'DrugComb'


#fname_suffix = ds_config["fname_suffix"]
# similarity_types = ['chem']
# kernel_option = 'sqeuclidean'
data_fname = 'data_v1'
# interact_matfname = ds_config["interact_matfname"]
# exp_iden = 'simtypeall'
# ddi_interaction_labels_pth = ds_config["ddi_interaction_labels_pth"]

# up_dir, processed_dir, DSdataset_name, data_fname

# %%
targetdata_dir = create_directory(os.path.join(processed_dir, DSdataset_name, data_fname))
targetdata_dir_raw = create_directory(os.path.join(targetdata_dir, "raw"))
targetdata_dir_processed = create_directory(os.path.join(targetdata_dir, "processed"))
targetdata_dir_exp = create_directory(os.path.join(targetdata_dir, "experiments"))
# # ReaderWriter.dump_data(dpartitions, os.path.join(targetdata_dir, 'data_partitions.pkl'))
print(targetdata_dir)
# Out:
# path_current_dir /cluster/home/skyriakos/chemprop_run/git/deepadr
# path_current_dir /cluster/home/skyriakos/chemprop_run/git/deepadr
# path_current_dir /cluster/home/skyriakos/chemprop_run/git/deepadr
# path_current_dir /cluster/home/skyriakos/chemprop_run/git/deepadr
# /cluster/home/skyriakos/chemprop_run/git/data/processed/DrugComb_total_thresh_3/data_v1

# %%
# %%time

# Make sure to first run the "data_generation" notebook first

dataset = MoleculeDataset(root=targetdata_dir)
# Out:
# CPU times: user 16.6 ms, sys: 485 ms, total: 502 ms
# Wall time: 1.1 s

# %%
# print()
# print(f'Dataset: {dataset}:')
# print('====================')
# print(f'Number of graphs: {len(dataset)}')
# print(f'Number of features: {dataset.num_features}')
# print(f'Number of classes: {dataset.num_classes}')

# # data0 = dataset[0]  # Get the first graph object.

# # print()
# # print(data)
# # print('=============================================================')

# # # Gather some statistics about the first graph.
# # print(f'Number of nodes: {data.num_nodes}')
# # print(f'Number of edges: {data.num_edges}')
# # print(f'Average node degree: {data.num_edges / data.num_nodes:.2f}')
# # print(f'Contains isolated nodes: {data.contains_isolated_nodes()}')
# # print(f'Contains self-loops: {data.contains_self_loops()}')
# # print(f'Is undirected: {data.is_undirected()}')

# %%
# data0

# %%
# data0.expression.shape

# %%
# data0.y

# %%
# dataset.tensors[1]

# %%
# used_dataset = dataset

# If you want to use a smaller subset of the dataset for testing
# smaller_dataset_len = int(len(dataset)/1)
# used_dataset = dataset[:smaller_dataset_len]

# %%
# type(used_dataset)

# %%
dataset.data.y
# Out:
# tensor([0, 0, 0,  ..., 1, 0, 0], dtype=torch.int32)

# %%
fold_partitions = get_stratified_partitions(dataset.data.y,
                                            num_folds=5,
                                            valid_set_portion=0.1,
                                            random_state=42)
# Out:
# fold_num: 0
# train data
# class: 0 norm count: 0.6346470333477696
# class: 1 norm count: 0.3653529666522304
# validation data
# class: 0 norm count: 0.6346453624318005
# class: 1 norm count: 0.3653546375681995
# test data
# class: 0 norm count: 0.6347053320860617
# class: 1 norm count: 0.3652946679139383
#
# -------------------------
# fold_num: 1
# train data
# class: 0 norm count: 0.6346470333477696
# class: 1 norm count: 0.3653529666522304
# validation data
# class: 0 norm count: 0.6346453624318005
# class: 1 norm count: 0.3653546375681995
# test data
# class: 0 norm count: 0.6347053320860617
# class: 1 norm count: 0.3652946679139383
#
# -------------------------
# fold_num: 2
# train data
# class: 0 norm count: 0.634668687743612
# class: 1 norm count: 0.36533131225638804
# validation data
# class: 0 norm count: 0.6346453624318005
# class: 1 norm count: 0.3653546375681995
# test data
# class: 0 norm count: 0.6346273776114749
# class: 1 norm count: 0.3653726223885251
#
# -------------------------
# fold_num: 3
# train data
# class: 0 norm count: 0.634668687743612
# class: 1 norm count: 0.36533131225638804
# validation data
# class: 0 norm count: 0.6346453624318005
# class: 1 norm count: 0.3653546375681995
# test data
# class: 0 norm count: 0.6346273776114749
# class: 1 norm count: 0.3653726223885251
#
# -------------------------
# fold_num: 4
# train data
# class: 0 norm count: 0.634668687743612
# class: 1 norm count: 0.36533131225638804
# validation data
# class: 0 norm count: 0.6346453624318005
# class: 1 norm count: 0.3653546375681995
# test data
# class: 0 norm count: 0.6346273776114749
# class: 1 norm count: 0.3653726223885251
#
# -------------------------

# %%
# train_val_test_frac = [0.7, 0.1, 0.2]
# assert sum(train_val_test_frac) == 1

# torch.manual_seed(42)
# used_dataset = used_dataset.shuffle()

# num_train = round(train_val_test_frac[0] * len(used_dataset)) 
# num_trainval = round((train_val_test_frac[0]+train_val_test_frac[1]) * len(used_dataset))

# train_dataset = used_dataset[:num_train]
# val_dataset = used_dataset[num_train:num_trainval]
# test_dataset = used_dataset[num_trainval:]

# %%
# train_dataset = Subset(used_dataset, fold_partitions[0]['train'])
# val_dataset = Subset(used_dataset, fold_partitions[0]['validation'])
# test_dataset = Subset(used_dataset, fold_partitions[0]['test'])

# %%
# print(f'Number of training graphs: {len(train_dataset)}')
# print(f'Number of val graphs: {len(val_dataset)}')
# print(f'Number of test graphs: {len(test_dataset)}')

# %%
print("Number of training graphs: "+ str(len(fold_partitions[0]['train'])))
print("Number of validation graphs: "+ str(len(fold_partitions[0]['validation'])))
print("Number of testing graphs: "+ str(len(fold_partitions[0]['test'])))
# Out:
# Number of training graphs: 46180
# Number of validation graphs: 5132
# Number of testing graphs: 12828

# %%
# print(dataset.num_classes)

# %%
# training params total_thresh 4
tp = {
    "batch_size" : 300,
    "num_epochs" : 200,
    
    "emb_dim" : 300,
    "gnn_type" : "gatv2",
    "num_layer" : 5,
    "graph_pooling" : "mean", #attention
    
    "input_embed_dim" : None,
    "gene_embed_dim": 1,
    "num_attn_heads" : 2,
    "num_transformer_units" : 1,
    "p_dropout" : 0.3,
#     "nonlin_func" : nn.ReLU(),
    "mlp_embed_factor" : 2,
    "pooling_mode" : 'attn',
    "dist_opt" : 'cosine',

    "base_lr" : 3e-5, #3e-4
    "max_lr_mul": 15,
    "l2_reg" : 1e-7,
    "loss_w" : 0.95,
    "margin_v" : 1.,

    "expression_dim" : 64,
    "expression_input_size" : 908,
    "exp_H1" : 500,
    "exp_H2" : 400
}

# %%
# # training params total_thresh 3
# tp = {
#     "batch_size" : 300,
#     "num_epochs" : 200,
    
#     "emb_dim" : 300,
#     "gnn_type" : "gatv2",
#     "num_layer" : 5,
#     "graph_pooling" : "mean", #attention
    
#     "input_embed_dim" : None,
#     "gene_embed_dim": 1,
#     "num_attn_heads" : 2,
#     "num_transformer_units" : 1,
#     "p_dropout" : 0.3,
# #     "nonlin_func" : nn.ReLU(),
#     "mlp_embed_factor" : 2,
#     "pooling_mode" : 'attn',
#     "dist_opt" : 'cosine',

#     "base_lr" : 3e-5, #3e-4
#     "max_lr_mul": 10,
#     "l2_reg" : 1e-8,
#     "loss_w" : 0.3,
#     "margin_v" : 1.,

#     "expression_dim" : 64,
#     "expression_input_size" : 908,
#     "exp_H1" : 500,
#     "exp_H2" : 400
# }

# %%
# targetdata_dir_exp = create_directory(os.path.join(targetdata_dir, "experiments"))
# targetdata_dir_exp

# %%
# device_gpu = get_device(True, index=0)
# exp_dir = create_directory(os.path.join(targetdata_dir_exp, "exp0"))
# tphp = generate_tp_hp(tp, hyperparam_space[0], hp_names)
# partition = fold_partitions[0]

# %%
# run_exp(tphp, device_gpu, exp_dir,partition=fold_partitions[0], used_dataset=used_dataset)

# %%
def spawn_q_process(q_process):
    print(">>> spawning hyperparam search process")
    q_process.start()
    
def join_q_process(q_process):
    q_process.join()
    print("<<< joined hyperparam search process")
    
def create_q_process(queue, used_dataset, gpu_num, tphp, exp_dir, partition): #
#     fold_gpu_map = {0:gpu_num}
    return mp.Process(target=deepadr.hyphelper.run_exp, args=(queue, used_dataset, gpu_num, tphp, exp_dir, partition)) #

# %%
import torch.multiprocessing as mp
mp.set_start_method("spawn", force=True)

queue = mp.Queue()
q_processes = []

# partition = fold_partitions[0]
time_stamp = datetime.datetime.now().strftime('%Y-%m-%d_%H-%M-%S')

print("Start: " + time_stamp)

for q_i in range(min(n_gpu, len(fold_partitions))):
#     device_gpu = get_device(True, index=q_i)
    partition = fold_partitions[q_i]
    exp_dir = create_directory(os.path.join(targetdata_dir_exp, "fold_"+str(q_i)+"_"+time_stamp))
    create_directory(os.path.join(exp_dir, "predictions"))

#     tphp = generate_tp_hp(tp, hyperparam_space[q_i], hp_names)
    
    q_process = create_q_process(queue, dataset, q_i, tp, exp_dir, partition)
    q_processes.append(q_process)
    spawn_q_process(q_process)

spawned_processes = n_gpu
    
# for q_i in range(len(hyperparam_space)):
for q_i in range(min(n_gpu, len(fold_partitions))):
    join_q_process(q_processes[q_i])
    released_gpu_num = queue.get()
    print("released_gpu_num:", released_gpu_num)
#     if(spawned_processes < len(hyperparam_space)):
# #         device_gpu = get_device(True, index=q_i)
#         time_stamp = datetime.datetime.now().strftime('%Y-%m-%d_%H-%M-%S')
#         exp_dir = create_directory(os.path.join(targetdata_dir_exp, "exp_"+str(q_i)+"_"+time_stamp))
#         tphp = generate_tp_hp(tp, hyperparam_space[q_i], hp_names)

#         q_process = create_q_process(queue, used_dataset, released_gpu_num, tphp, exp_dir, partition)
#         q_processes.append(q_process)
#         spawn_q_process(q_process)
#         spawned_processes = spawned_processes + 1
# Out:
# Start: 2022-02-28_22-33-42
# path_current_dir /cluster/home/skyriakos/chemprop_run/git/deepadr
# path_current_dir /cluster/home/skyriakos/chemprop_run/git/deepadr
# >>> spawning hyperparam search process
# path_current_dir /cluster/home/skyriakos/chemprop_run/git/deepadr
# path_current_dir /cluster/home/skyriakos/chemprop_run/git/deepadr
# >>> spawning hyperparam search process
# gpu: cuda:0
# GeneEmbAttention pooling, gene_embed_dim: 1
# updated
# num classes: 2
# =====Epoch 0
# Training...
# Iteration:   0%|          | 0/154 [00:00<?, ?it/s]
# path_current_dir /cluster/home/skyriakos/chemprop_run/git/deepadr
# path_current_dir /cluster/home/skyriakos/chemprop_run/git/deepadr
# >>> spawning hyperparam search process
# Iteration:   1%|          | 1/154 [00:02<05:45,  2.25s/it]
# gpu: cuda:1
# GeneEmbAttention pooling, gene_embed_dim: 1
# updated
# num classes: 2
# =====Epoch 0
# Training...
# Iteration:   0%|          | 0/154 [00:00<?, ?it/s]
# path_current_dir /cluster/home/skyriakos/chemprop_run/git/deepadr
# path_current_dir /cluster/home/skyriakos/chemprop_run/git/deepadr
# >>> spawning hyperparam search process
# Iteration:   2%|▏         | 3/154 [00:06<05:04,  2.02s/it]
# gpu: cuda:2
# GeneEmbAttention pooling, gene_embed_dim: 1
# updated
# num classes: 2
# =====Epoch 0
# Training...
# Iteration:   0%|          | 0/154 [00:00<?, ?it/s]
# path_current_dir /cluster/home/skyriakos/chemprop_run/git/deepadr
# path_current_dir /cluster/home/skyriakos/chemprop_run/git/deepadr
# >>> spawning hyperparam search process
# Iteration:   3%|▎         | 5/154 [00:10<04:57,  2.00s/it]
# gpu: cuda:3
# GeneEmbAttention pooling, gene_embed_dim: 1
# updated
# num classes: 2
# =====Epoch 0
# Training...
# Iteration:   5%|▍         | 7/154 [00:14<04:50,  1.98s/it]
# gpu: cuda:4
# GeneEmbAttention pooling, gene_embed_dim: 1
# updated
# num classes: 2
# =====Epoch 0
# Training...
# Iteration: 100%|██████████| 154/154 [00:50<00:00,  3.06it/s]
# Iteration:   1%|▏         | 2/154 [00:00<00:11, 13.16it/s]s]
# Evaluating...
# Iteration: 100%|██████████| 154/154 [00:50<00:00,  3.05it/s]
# Iteration:  77%|███████▋  | 119/154 [00:43<00:07,  4.48it/s]
# Evaluating...
# Iteration: 100%|██████████| 154/154 [00:50<00:00,  3.05it/s]
# Iteration:  88%|████████▊ | 136/154 [00:46<00:03,  4.92it/s]
# Evaluating...
# Iteration: 100%|██████████| 154/154 [00:10<00:00, 14.93it/s]
# Iteration: 100%|██████████| 154/154 [00:50<00:00,  3.05it/s]
# Iteration:  40%|████      | 62/154 [00:04<00:06, 14.79it/s]
# Evaluating...
# Iteration: 100%|██████████| 154/154 [00:10<00:00, 14.88it/s]
# Iteration: 100%|██████████| 154/154 [00:50<00:00,  3.04it/s]
# Iteration:  84%|████████▎ | 36/43 [00:03<00:00,  9.14it/s]]]
# Evaluating...
# Iteration: 100%|██████████| 43/43 [00:04<00:00,  9.38it/s]]]
# Iteration: 100%|██████████| 154/154 [00:10<00:00, 14.91it/s]
# Iteration: 100%|██████████| 43/43 [00:04<00:00,  9.30it/s]]]
# Iteration: 100%|██████████| 154/154 [00:10<00:00, 14.96it/s]
# Iteration: 100%|██████████| 43/43 [00:04<00:00,  9.27it/s]s]
# Iteration: 100%|██████████| 154/154 [00:10<00:00, 14.84it/s]
# Iteration: 100%|██████████| 43/43 [00:04<00:00,  9.28it/s]
# Iteration: 100%|██████████| 18/18 [00:01<00:00,  9.67it/s]
# Iteration:  95%|█████████▌| 41/43 [00:04<00:00,  9.70it/s]
# {'Train':  best_epoch_indx:0
#  auc:0.7043475952625062
#  apur:0.5805033272524351
#  f1:0.5678798382437896
#  precision:0.5098066949552098
#  recall:0.6408843053579896
# , 'Validation':  best_epoch_indx:0
#  auc:0.7061355439566064
#  apur:0.5873014331087827
#  f1:0.5682305310788283
#  precision:0.5133390705679862
#  recall:0.6362666666666666
# , 'Test':  best_epoch_indx:0
#  auc:0.7077636070923354
#  apur:0.5801264285356423
#  f1:0.5720729186243187
#  precision:0.5110812625923439
#  recall:0.6495945369184806
# }
# =====Epoch 1
# Training...
# Iteration: 100%|██████████| 43/43 [00:04<00:00,  9.20it/s]
# Iteration: 100%|██████████| 18/18 [00:01<00:00,  9.98it/s]]
# Iteration:   0%|          | 0/154 [00:00<?, ?it/s]
# {'Train':  best_epoch_indx:0
#  auc:0.7112853708100292
#  apur:0.5930318660323246
#  f1:0.5837616039326413
#  precision:0.4440770157925642
#  recall:0.8516477003319108
# , 'Validation':  best_epoch_indx:0
#  auc:0.7024928461774639
#  apur:0.5758503445202837
#  f1:0.5829959514170041
#  precision:0.44506883956167465
#  recall:0.8448
# , 'Test':  best_epoch_indx:0
#  auc:0.7226679752783315
#  apur:0.6081915308636383
#  f1:0.5883217040029379
#  precision:0.4485384701534326
#  recall:0.854673495518566
# }
# =====Epoch 1
# Training...
# Iteration: 100%|██████████| 18/18 [00:01<00:00, 10.16it/s]]
# Iteration:  27%|██▋       | 41/154 [00:06<00:18,  6.18it/s]
# {'Train':  best_epoch_indx:0
#  auc:0.7177811468160393
#  apur:0.5925406295954899
#  f1:0.5881270133456052
#  precision:0.5171065054174347
#  recall:0.6817616027502815
# , 'Validation':  best_epoch_indx:0
#  auc:0.71553928973493
#  apur:0.5761100047516411
#  f1:0.5875887336844516
#  precision:0.5148475120385233
#  recall:0.6842666666666667
# , 'Test':  best_epoch_indx:0
#  auc:0.7102144811836882
#  apur:0.5866289360455539
#  f1:0.5788118447673349
#  precision:0.508647163407144
#  recall:0.6714316193727331
# }
# =====Epoch 1
# Training...
# Iteration: 100%|██████████| 18/18 [00:01<00:00, 10.22it/s]]
# {'Train':  best_epoch_indx:0
#  auc:0.7100561918616004
#  apur:0.5883909671865065
#  f1:0.5668595880077899
#  precision:0.5275707137751455
#  recall:0.6124711042617509
# , 'Validation':  best_epoch_indx:0
#  auc:0.7082037867157916
#  apur:0.5893339187586752
#  f1:0.5588018659464769
#  precision:0.5177434030937216
#  recall:0.6069333333333333
# , 'Test':  best_epoch_indx:0
#  auc:0.711140461296259
#  apur:0.5849182585037849
#  f1:0.5728653125616249
#  precision:0.532538955087076
#  recall:0.6197994452741625
# }
# =====Epoch 1
# Training...
# Iteration: 100%|██████████| 18/18 [00:01<00:00, 10.42it/s]]
# Iteration:  58%|█████▊    | 89/154 [00:14<00:10,  6.20it/s]
# {'Train':  best_epoch_indx:0
#  auc:0.7073901164732762
#  apur:0.5841352180002451
#  f1:0.5719913851972476
#  precision:0.5135594019714191
#  recall:0.6454270641929939
# , 'Validation':  best_epoch_indx:0
#  auc:0.7056904718043189
#  apur:0.5757581486653194
#  f1:0.575154101469891
#  precision:0.5177123346137431
#  recall:0.6469333333333334
# , 'Test':  best_epoch_indx:0
#  auc:0.6968878367293625
#  apur:0.5725222603116084
#  f1:0.5602500947328533
#  precision:0.5038337025046856
#  recall:0.6308939620226157
# }
# =====Epoch 1
# Training...
# Iteration: 100%|██████████| 154/154 [00:24<00:00,  6.25it/s]
# Iteration:  56%|█████▋    | 87/154 [00:13<00:10,  6.49it/s]]
# Evaluating...
# Iteration: 100%|██████████| 154/154 [00:24<00:00,  6.29it/s]
# Iteration:  87%|████████▋ | 134/154 [00:21<00:03,  6.30it/s]
# Evaluating...
# Iteration: 100%|██████████| 154/154 [00:24<00:00,  6.35it/s]
# Iteration:  83%|████████▎ | 128/154 [00:20<00:04,  6.24it/s]
# Evaluating...
# Iteration: 100%|██████████| 154/154 [00:10<00:00, 14.54it/s]
# Iteration: 100%|██████████| 154/154 [00:24<00:00,  6.33it/s]
# Iteration:  71%|███████▏  | 110/154 [00:07<00:02, 15.06it/s]
# Evaluating...
# Iteration: 100%|██████████| 154/154 [00:10<00:00, 14.59it/s]
# Iteration: 100%|██████████| 43/43 [00:02<00:00, 15.27it/s]s]
# Iteration: 100%|██████████| 154/154 [00:24<00:00,  6.29it/s]
# Iteration:  36%|███▋      | 56/154 [00:03<00:06, 15.36it/s]]
# Evaluating...
# Iteration: 100%|██████████| 154/154 [00:10<00:00, 14.62it/s]
# Iteration: 100%|██████████| 43/43 [00:02<00:00, 15.38it/s]
# Iteration: 100%|██████████| 43/43 [00:02<00:00, 15.45it/s]]]
# Iteration: 100%|██████████| 154/154 [00:10<00:00, 14.72it/s]
# Iteration: 100%|██████████| 43/43 [00:02<00:00, 15.44it/s]s]
# Iteration: 100%|██████████| 154/154 [00:10<00:00, 14.70it/s]
# Iteration: 100%|██████████| 18/18 [00:01<00:00, 15.22it/s]
# Iteration:  79%|███████▉  | 34/43 [00:02<00:00, 15.33it/s]
# {'Train':  best_epoch_indx:1
#  auc:0.7416138880740336
#  apur:0.6324571813309434
#  f1:0.5832483961868218
#  precision:0.5900764284847749
#  recall:0.5765765765765766
# , 'Validation':  best_epoch_indx:1
#  auc:0.7465517142564733
#  apur:0.6376609034179707
#  f1:0.5848592511615196
#  precision:0.5997757847533632
#  recall:0.5706666666666667
# , 'Test':  best_epoch_indx:1
#  auc:0.7399904889240312
#  apur:0.6255476686872901
#  f1:0.5882227209575718
#  precision:0.5891672018839649
#  recall:0.5872812633376013
# }
# =====Epoch 2
# Training...
# Iteration: 100%|██████████| 43/43 [00:02<00:00, 15.32it/s]
# Iteration: 100%|██████████| 18/18 [00:01<00:00, 15.28it/s]]
# Iteration:  12%|█▏        | 18/154 [00:02<00:21,  6.47it/s]
# {'Train':  best_epoch_indx:1
#  auc:0.7365050684614276
#  apur:0.621273881759416
#  f1:0.6032265487178176
#  precision:0.530416797805854
#  recall:0.6992057847321005
# , 'Validation':  best_epoch_indx:1
#  auc:0.7290943403950466
#  apur:0.6002116323859119
#  f1:0.5926271581894541
#  precision:0.5267523849025301
#  recall:0.6773333333333333
# , 'Test':  best_epoch_indx:1
#  auc:0.7474088424909415
#  apur:0.6336685087012758
#  f1:0.6105635112516272
#  precision:0.5410349373764007
#  recall:0.7005975245411865
# }
# =====Epoch 2
# Training...
# Iteration: 100%|██████████| 18/18 [00:01<00:00, 15.52it/s]]
# Iteration:  14%|█▍        | 22/154 [00:03<00:20,  6.30it/s]
# {'Train':  best_epoch_indx:1
#  auc:0.7491559681181552
#  apur:0.6343117513378814
#  f1:0.6143697891123099
#  precision:0.5239449579656197
#  recall:0.7425167447098572
# , 'Validation':  best_epoch_indx:1
#  auc:0.7509578958141438
#  apur:0.6310873017851694
#  f1:0.6192045704240825
#  precision:0.5265321375186846
#  recall:0.7514666666666666
# , 'Test':  best_epoch_indx:1
#  auc:0.7374433414567292
#  apur:0.6203930196206007
#  f1:0.6062262986153981
#  precision:0.5166867107636801
#  recall:0.7333048858544912
# }
# =====Epoch 2
# Training...
# Iteration: 100%|██████████| 18/18 [00:01<00:00, 15.41it/s]]
# Iteration:  32%|███▏      | 50/154 [00:08<00:16,  6.15it/s]
# {'Train':  best_epoch_indx:1
#  auc:0.7402298848226917
#  apur:0.6236486333539316
#  f1:0.6002200574296219
#  precision:0.5484013338564143
#  recall:0.6628534171062771
# , 'Validation':  best_epoch_indx:1
#  auc:0.7385587555009723
#  apur:0.6270546036984963
#  f1:0.5946601941747572
#  precision:0.5456570155902004
#  recall:0.6533333333333333
# , 'Test':  best_epoch_indx:1
#  auc:0.7393287949977654
#  apur:0.6231425761506906
#  f1:0.60086663456909
#  precision:0.5475605475605475
#  recall:0.6656710049071901
# }
# =====Epoch 2
# Training...
# Iteration: 100%|██████████| 18/18 [00:01<00:00, 15.56it/s]]
# Iteration:   1%|          | 1/154 [00:00<00:22,  6.73it/s]]
# {'Train':  best_epoch_indx:1
#  auc:0.7449476946162179
#  apur:0.6328305424186722
#  f1:0.5735983498968686
#  precision:0.6066635816751504
#  recall:0.5439511587931954
# , 'Validation':  best_epoch_indx:1
#  auc:0.7393296898986796
#  apur:0.6242363784329987
#  f1:0.5602937023439707
#  precision:0.595438175270108
#  recall:0.5290666666666667
# , 'Test':  best_epoch_indx:1
#  auc:0.7321838294532934
#  apur:0.6153100585944032
#  f1:0.553254102999434
#  precision:0.5891996142719382
#  recall:0.5214422871772989
# }
# =====Epoch 2
# Training...
# Iteration: 100%|██████████| 154/154 [00:23<00:00,  6.67it/s]
# Iteration:   1%|▏         | 2/154 [00:00<00:11, 12.99it/s]]]
# Evaluating...
# Iteration: 100%|██████████| 154/154 [00:24<00:00,  6.36it/s]
# Iteration:  39%|███▉      | 60/154 [00:03<00:06, 15.32it/s]
# Evaluating...
# Iteration: 100%|██████████| 154/154 [00:24<00:00,  6.32it/s]
# Iteration:  82%|████████▏ | 127/154 [00:20<00:04,  6.36it/s]
# Evaluating...
# Iteration: 100%|██████████| 154/154 [00:10<00:00, 15.08it/s]
# Iteration: 100%|██████████| 154/154 [00:24<00:00,  6.31it/s]
# Iteration:  81%|████████  | 124/154 [00:08<00:01, 15.24it/s]
# Evaluating...
# Iteration: 100%|██████████| 43/43 [00:02<00:00, 15.54it/s]]]
# Iteration: 100%|██████████| 154/154 [00:10<00:00, 15.09it/s]
# Iteration: 100%|██████████| 154/154 [00:24<00:00,  6.29it/s]
# Iteration:   1%|▏         | 2/154 [00:00<00:11, 12.98it/s]]]
# Evaluating...
# Iteration: 100%|██████████| 43/43 [00:02<00:00, 15.30it/s]]]
# Iteration: 100%|██████████| 154/154 [00:10<00:00, 15.22it/s]
# Iteration: 100%|██████████| 43/43 [00:02<00:00, 15.53it/s]s]
# Iteration: 100%|██████████| 154/154 [00:10<00:00, 15.26it/s]
# Iteration: 100%|██████████| 43/43 [00:02<00:00, 15.43it/s]s]
# Iteration: 100%|██████████| 154/154 [00:10<00:00, 15.16it/s]
# Iteration: 100%|██████████| 18/18 [00:01<00:00, 15.44it/s]
# Iteration:   0%|          | 0/154 [00:00<?, ?it/s]
# {'Train':  best_epoch_indx:2
#  auc:0.7627220489886424
#  apur:0.6595895492072905
#  f1:0.6183337977152411
#  precision:0.583447260490062
#  recall:0.6576576576576577
# , 'Validation':  best_epoch_indx:2
#  auc:0.7638382970013303
#  apur:0.6581986783510962
#  f1:0.6168363546064067
#  precision:0.5771375464684015
#  recall:0.6624
# , 'Test':  best_epoch_indx:2
#  auc:0.760514472467102
#  apur:0.6556181731561697
#  f1:0.6168205739251316
#  precision:0.5767873723305478
#  recall:0.6628254374733248
# }
# =====Epoch 3
# Training...
# Iteration: 100%|██████████| 43/43 [00:02<00:00, 15.36it/s]]
# Iteration: 100%|██████████| 18/18 [00:01<00:00, 15.24it/s]]
# Iteration:  16%|█▌        | 24/154 [00:03<00:19,  6.58it/s]
# {'Train':  best_epoch_indx:2
#  auc:0.7523120266141528
#  apur:0.6481535727739207
#  f1:0.6139878226197532
#  precision:0.56282722513089
#  recall:0.6753793266951161
# , 'Validation':  best_epoch_indx:2
#  auc:0.7482819772797051
#  apur:0.6369132599313023
#  f1:0.6100940128649183
#  precision:0.5689893862482694
#  recall:0.6576
# , 'Test':  best_epoch_indx:2
#  auc:0.7643565796946288
#  apur:0.6638522944192973
#  f1:0.6250369931932523
#  precision:0.5811777655476059
#  recall:0.676056338028169
# }
# =====Epoch 3
# Training...
# Iteration: 100%|██████████| 18/18 [00:01<00:00, 15.37it/s]]
# Iteration:  31%|███       | 47/154 [00:07<00:16,  6.34it/s]
# {'Train':  best_epoch_indx:2
#  auc:0.7718331649015313
#  apur:0.6681955044377693
#  f1:0.628150380976304
#  precision:0.593575271653128
#  recall:0.6670025487522968
# , 'Validation':  best_epoch_indx:2
#  auc:0.7704317674751817
#  apur:0.6633587593794936
#  f1:0.6304728546409808
#  precision:0.5937794533459001
#  recall:0.672
# , 'Test':  best_epoch_indx:2
#  auc:0.7598747428608328
#  apur:0.6545047397138589
#  f1:0.6134538152610441
#  precision:0.5793665844870093
#  recall:0.6518028589716236
# }
# =====Epoch 3
# Training...
# Iteration: 100%|██████████| 18/18 [00:01<00:00, 15.52it/s]]
# Iteration:  32%|███▏      | 50/154 [00:08<00:16,  6.19it/s]
# {'Train':  best_epoch_indx:2
#  auc:0.7539948767467362
#  apur:0.6492044762417033
#  f1:0.5708649768221717
#  precision:0.6409272109847926
#  recall:0.5146108707249125
# , 'Validation':  best_epoch_indx:2
#  auc:0.7527556237846689
#  apur:0.6490294338232443
#  f1:0.5748148148148148
#  precision:0.6466666666666666
#  recall:0.5173333333333333
# , 'Test':  best_epoch_indx:2
#  auc:0.7541261183733979
#  apur:0.6494964634421737
#  f1:0.5811240721102864
#  precision:0.6489473684210526
#  recall:0.5261361211862599
# }
# =====Epoch 3
# Training...
# Iteration: 100%|██████████| 18/18 [00:01<00:00, 15.94it/s]]
# Iteration:   0%|          | 0/154 [00:00<?, ?it/s]6.26it/s]
# {'Train':  best_epoch_indx:2
#  auc:0.7602674414786391
#  apur:0.6546134696857052
#  f1:0.5825058792788084
#  precision:0.6487449981811568
#  recall:0.5285400983936933
# , 'Validation':  best_epoch_indx:2
#  auc:0.7543690512741786
#  apur:0.6470725963658334
#  f1:0.5760901809552061
#  precision:0.6490641711229946
#  recall:0.5178666666666667
# , 'Test':  best_epoch_indx:2
#  auc:0.747638360874859
#  apur:0.6367287090290032
#  f1:0.5668842729970327
#  precision:0.6388443017656501
#  recall:0.5094943460635801
# }
# =====Epoch 3
# Training...
# Iteration: 100%|██████████| 154/154 [00:24<00:00,  6.26it/s]
# Iteration:   1%|▏         | 2/154 [00:00<00:11, 13.03it/s]s]
# Evaluating...
# Iteration: 100%|██████████| 154/154 [00:24<00:00,  6.26it/s]
# Iteration:  39%|███▉      | 60/154 [00:04<00:06, 15.30it/s]]
# Evaluating...
# Iteration: 100%|██████████| 154/154 [00:24<00:00,  6.25it/s]
# Iteration:  83%|████████▎ | 128/154 [00:20<00:04,  6.27it/s]
# Evaluating...
# Iteration: 100%|██████████| 154/154 [00:10<00:00, 15.19it/s]
# Iteration: 100%|██████████| 154/154 [00:24<00:00,  6.29it/s]
# Iteration:  86%|████████▋ | 133/154 [00:21<00:03,  6.24it/s]
# Evaluating...
# Iteration: 100%|██████████| 43/43 [00:02<00:00, 15.52it/s]]]
# Iteration: 100%|██████████| 154/154 [00:10<00:00, 15.19it/s]
# Iteration: 100%|██████████| 154/154 [00:24<00:00,  6.27it/s]
# Iteration:  28%|██▊       | 12/43 [00:00<00:02, 15.09it/s]]
# Evaluating...
# Iteration: 100%|██████████| 43/43 [00:02<00:00, 15.39it/s]]]
# Iteration: 100%|██████████| 154/154 [00:10<00:00, 15.23it/s]
# Iteration: 100%|██████████| 43/43 [00:02<00:00, 15.45it/s]s]
# Iteration: 100%|██████████| 154/154 [00:10<00:00, 15.24it/s]
# Iteration: 100%|██████████| 43/43 [00:02<00:00, 15.19it/s]s]
# Iteration: 100%|██████████| 154/154 [00:10<00:00, 15.14it/s]
# Iteration: 100%|██████████| 18/18 [00:01<00:00, 15.48it/s]
# Iteration:  37%|███▋      | 16/43 [00:01<00:01, 15.15it/s]
# {'Train':  best_epoch_indx:3
#  auc:0.7657948253172613
#  apur:0.6644313175061488
#  f1:0.6229095998292099
#  precision:0.519280205655527
#  recall:0.7782124229492651
# , 'Validation':  best_epoch_indx:3
#  auc:0.7672810561866747
#  apur:0.6666796016593948
#  f1:0.6254015849218247
#  precision:0.5225483178239084
#  recall:0.7786666666666666
# , 'Test':  best_epoch_indx:3
#  auc:0.7629012707959121
#  apur:0.6627556647977153
#  f1:0.6183853459972863
#  precision:0.5130875316633831
#  recall:0.7780623132735809
# }
# =====Epoch 4
# Training...
# Iteration: 100%|██████████| 43/43 [00:02<00:00, 15.38it/s]
# Iteration: 100%|██████████| 18/18 [00:01<00:00, 15.49it/s]]
# Iteration:   0%|          | 0/154 [00:00<?, ?it/s]
# {'Train':  best_epoch_indx:3
#  auc:0.7650994163668312
#  apur:0.6554424955339858
#  f1:0.6254730185060391
#  precision:0.5557807461999079
#  recall:0.715149359886202
# , 'Validation':  best_epoch_indx:3
#  auc:0.7555403541090984
#  apur:0.6368005927140132
#  f1:0.6132387706855792
#  precision:0.5507430997876858
#  recall:0.6917333333333333
# , 'Test':  best_epoch_indx:3
#  auc:0.7742619192223228
#  apur:0.6679320540916186
#  f1:0.6336145606218598
#  precision:0.5700153505031553
#  recall:0.7131882202304738
# }
# =====Epoch 4
# Training...
# Iteration: 100%|██████████| 18/18 [00:01<00:00, 15.69it/s]]
# Iteration:  28%|██▊       | 43/154 [00:07<00:17,  6.29it/s]
# {'Train':  best_epoch_indx:3
#  auc:0.7758732337799119
#  apur:0.6735214029547041
#  f1:0.6249927414203589
#  precision:0.6125433953673667
#  recall:0.6379586272301583
# , 'Validation':  best_epoch_indx:3
#  auc:0.775148910039914
#  apur:0.6687154652367886
#  f1:0.6266318537859008
#  precision:0.6138107416879796
#  recall:0.64
# , 'Test':  best_epoch_indx:3
#  auc:0.763372907424501
#  apur:0.6620316793069164
#  f1:0.609125315391085
#  precision:0.6004145077720208
#  recall:0.6180925965436314
# }
# =====Epoch 4
# Training...
# Iteration: 100%|██████████| 18/18 [00:01<00:00, 15.70it/s]]
# Iteration:  45%|████▌     | 70/154 [00:11<00:13,  6.25it/s]
# {'Train':  best_epoch_indx:3
#  auc:0.7658342495612276
#  apur:0.668553474458611
#  f1:0.6168433755710714
#  precision:0.598594691055097
#  recall:0.6362397012625215
# , 'Validation':  best_epoch_indx:3
#  auc:0.7632403643434654
#  apur:0.6656350386346858
#  f1:0.6136774193548388
#  precision:0.5945
#  recall:0.6341333333333333
# , 'Test':  best_epoch_indx:3
#  auc:0.765001893368237
#  apur:0.6692517410100007
#  f1:0.6176681338929266
#  precision:0.59366391184573
#  recall:0.6436953275016002
# }
# =====Epoch 4
# Training...
# Iteration: 100%|██████████| 18/18 [00:01<00:00, 15.69it/s]]
# Iteration:   0%|          | 0/154 [00:00<?, ?it/s]6.25it/s]
# {'Train':  best_epoch_indx:3
#  auc:0.7703478274232958
#  apur:0.6687999814664246
#  f1:0.5962273935308225
#  precision:0.6577987556318386
#  recall:0.5451958982870013
# , 'Validation':  best_epoch_indx:3
#  auc:0.7677451233241224
#  apur:0.6646759617671647
#  f1:0.583751846381093
#  precision:0.6543046357615894
#  recall:0.5269333333333334
# , 'Test':  best_epoch_indx:3
#  auc:0.758657072133307
#  apur:0.6524756444676056
#  f1:0.5770909519877314
#  precision:0.6453825857519789
#  recall:0.5218689993599317
# }
# =====Epoch 4
# Training...
# Iteration: 100%|██████████| 154/154 [00:25<00:00,  6.16it/s]
# Iteration:   1%|▏         | 2/154 [00:00<00:11, 13.03it/s]s]
# Evaluating...
# Iteration: 100%|██████████| 154/154 [00:25<00:00,  6.15it/s]
# Iteration:  55%|█████▌    | 85/154 [00:13<00:10,  6.46it/s]]
# Evaluating...
# Iteration: 100%|██████████| 154/154 [00:24<00:00,  6.19it/s]
# Iteration:  71%|███████▏  | 110/154 [00:07<00:02, 15.40it/s]
# Evaluating...
# Iteration: 100%|██████████| 154/154 [00:10<00:00, 15.18it/s]
# Iteration: 100%|██████████| 154/154 [00:24<00:00,  6.21it/s]
# Iteration:   0%|          | 0/154 [00:00<?, ?it/s]
# Evaluating...
# Iteration: 100%|██████████| 43/43 [00:02<00:00, 15.51it/s]]]
# Iteration: 100%|██████████| 154/154 [00:10<00:00, 15.23it/s]
# Iteration: 100%|██████████| 154/154 [00:24<00:00,  6.16it/s]
# Iteration:  35%|███▌      | 54/154 [00:03<00:06, 15.32it/s]]
# Evaluating...
# Iteration: 100%|██████████| 43/43 [00:02<00:00, 15.41it/s]s]
# Iteration: 100%|██████████| 154/154 [00:10<00:00, 15.28it/s]
# Iteration: 100%|██████████| 43/43 [00:02<00:00, 15.52it/s]]]
# Iteration: 100%|██████████| 154/154 [00:10<00:00, 15.19it/s]
# Iteration: 100%|██████████| 43/43 [00:02<00:00, 15.47it/s]s]
# Iteration: 100%|██████████| 154/154 [00:10<00:00, 15.08it/s]
# Iteration: 100%|██████████| 18/18 [00:01<00:00, 15.52it/s]
# Iteration:   0%|          | 0/154 [00:00<?, ?it/s].13it/s]
# {'Train':  best_epoch_indx:4
#  auc:0.7683342735851078
#  apur:0.6694859061606315
#  f1:0.6276582099889696
#  precision:0.5532992628103659
#  recall:0.7251066856330014
# , 'Validation':  best_epoch_indx:4
#  auc:0.7722145942073483
#  apur:0.6711208077064439
#  f1:0.6368896088868318
#  precision:0.562551103843009
#  recall:0.7338666666666667
# , 'Test':  best_epoch_indx:4
#  auc:0.7647759786202083
#  apur:0.6679914922322374
#  f1:0.6243007794589638
#  precision:0.5473548802058209
#  recall:0.726419120785318
# }
# =====Epoch 5
# Training...
# Iteration: 100%|██████████| 43/43 [00:02<00:00, 15.38it/s]]
# Iteration: 100%|██████████| 18/18 [00:01<00:00, 15.44it/s]]
# Iteration:  14%|█▎        | 21/154 [00:03<00:21,  6.18it/s]
# {'Train':  best_epoch_indx:4
#  auc:0.7706973270689033
#  apur:0.6760688388899041
#  f1:0.6286474715702878
#  precision:0.531155450159457
#  recall:0.7699739212897108
# , 'Validation':  best_epoch_indx:4
#  auc:0.7674008392180944
#  apur:0.666030746038416
#  f1:0.628109995635094
#  precision:0.5315847801994829
#  recall:0.7674666666666666
# , 'Test':  best_epoch_indx:4
#  auc:0.7793599298537179
#  apur:0.6917122434328533
#  f1:0.6323555243281223
#  precision:0.5373134328358209
#  recall:0.7682458386683739
# }
# =====Epoch 5
# Training...
# Iteration: 100%|██████████| 18/18 [00:01<00:00, 15.55it/s]]
# Iteration:   0%|          | 0/154 [00:00<?, ?it/s]
# {'Train':  best_epoch_indx:4
#  auc:0.7766899855605414
#  apur:0.6801387862036379
#  f1:0.6354267226759203
#  precision:0.5675335570469798
#  recall:0.7217710864797582
# , 'Validation':  best_epoch_indx:4
#  auc:0.7745033261692764
#  apur:0.674702935220274
#  f1:0.6293183940242764
#  precision:0.5595682855956828
#  recall:0.7189333333333333
# , 'Test':  best_epoch_indx:4
#  auc:0.7650634943377297
#  apur:0.6669138813733708
#  f1:0.6258695243466817
#  precision:0.5594017812132415
#  recall:0.7102624279923192
# }
# =====Epoch 5
# Training...
# Iteration: 100%|██████████| 18/18 [00:01<00:00, 15.66it/s]]
# Iteration:   0%|          | 0/154 [00:00<?, ?it/s]6.22it/s]
# {'Train':  best_epoch_indx:4
#  auc:0.7723919476482375
#  apur:0.6680805694716
#  f1:0.6208618127786032
#  precision:0.6225639191846951
#  recall:0.6191689882046114
# , 'Validation':  best_epoch_indx:4
#  auc:0.7720657455736363
#  apur:0.6659519411796613
#  f1:0.6237650200267022
#  precision:0.6245989304812835
#  recall:0.6229333333333333
# , 'Test':  best_epoch_indx:4
#  auc:0.7719902946958408
#  apur:0.6690818403772023
#  f1:0.6229300706676512
#  precision:0.6159783062161035
#  recall:0.6300405376573501
# }
# =====Epoch 5
# Training...
# Iteration: 100%|██████████| 18/18 [00:01<00:00, 15.97it/s]]
# Iteration:  31%|███       | 48/154 [00:07<00:16,  6.26it/s]
# {'Train':  best_epoch_indx:4
#  auc:0.7748852448489519
#  apur:0.6807668777749444
#  f1:0.6246388232203834
#  precision:0.6152828886844526
#  recall:0.6342836820579693
# , 'Validation':  best_epoch_indx:4
#  auc:0.7752380718452564
#  apur:0.6792100787980854
#  f1:0.6274612759254398
#  precision:0.6178903826266805
#  recall:0.6373333333333333
# , 'Test':  best_epoch_indx:4
#  auc:0.7633368588673697
#  apur:0.6597725486578794
#  f1:0.6078660023322379
#  precision:0.6040876527602191
#  recall:0.6116919138041391
# }
# =====Epoch 5
# Training...
# Iteration: 100%|██████████| 154/154 [00:24<00:00,  6.24it/s]
# Iteration:  42%|████▏     | 64/154 [00:10<00:14,  6.21it/s]]
# Evaluating...
# Iteration: 100%|██████████| 154/154 [00:24<00:00,  6.24it/s]
# Iteration:   0%|          | 0/154 [00:00<?, ?it/s]
# Evaluating...
# Iteration: 100%|██████████| 154/154 [00:24<00:00,  6.27it/s]
# Iteration:  69%|██████▉   | 106/154 [00:06<00:03, 15.44it/s]
# Evaluating...
# Iteration: 100%|██████████| 154/154 [00:10<00:00, 15.22it/s]
# Iteration: 100%|██████████| 154/154 [00:24<00:00,  6.29it/s]
# Iteration:   1%|▏         | 2/154 [00:00<00:11, 12.85it/s]]]
# Evaluating...
# Iteration: 100%|██████████| 43/43 [00:02<00:00, 15.57it/s]]]
# Iteration: 100%|██████████| 154/154 [00:10<00:00, 15.29it/s]
# Iteration: 100%|██████████| 154/154 [00:24<00:00,  6.28it/s]
# Iteration:  34%|███▍      | 52/154 [00:03<00:06, 15.30it/s]
# Evaluating...
# Iteration: 100%|██████████| 43/43 [00:02<00:00, 15.47it/s]]]
# Iteration: 100%|██████████| 154/154 [00:10<00:00, 15.28it/s]
# Iteration: 100%|██████████| 43/43 [00:02<00:00, 15.54it/s]s]
# Iteration: 100%|██████████| 154/154 [00:10<00:00, 15.24it/s]
# Iteration: 100%|██████████| 43/43 [00:02<00:00, 15.49it/s]s]
# Iteration: 100%|██████████| 154/154 [00:10<00:00, 15.13it/s]
# Iteration: 100%|██████████| 18/18 [00:01<00:00, 15.43it/s]
# Iteration:  51%|█████     | 22/43 [00:01<00:01, 15.36it/s]
# {'Train':  best_epoch_indx:5
#  auc:0.7836038550169055
#  apur:0.6792646942248636
#  f1:0.639389566876177
#  precision:0.5442811341966107
#  recall:0.7747747747747747
# , 'Validation':  best_epoch_indx:5
#  auc:0.7877726333026303
#  apur:0.6780024448245946
#  f1:0.650814619110524
#  precision:0.5541807274090739
#  recall:0.7882666666666667
# , 'Test':  best_epoch_indx:5
#  auc:0.7787000675064133
#  apur:0.6778167790797924
#  f1:0.6330683902524238
#  precision:0.5358568682537336
#  recall:0.7733674775928298
# }
# =====Epoch 6
# Training...
# Iteration: 100%|██████████| 43/43 [00:02<00:00, 15.39it/s]
# Iteration: 100%|██████████| 18/18 [00:01<00:00, 15.55it/s]]
# Iteration:  13%|█▎        | 20/154 [00:03<00:21,  6.19it/s]
# {'Train':  best_epoch_indx:5
#  auc:0.7777712898774016
#  apur:0.6846040790683044
#  f1:0.6314155858552267
#  precision:0.592962731626067
#  recall:0.6752015173067805
# , 'Validation':  best_epoch_indx:5
#  auc:0.775306928666462
#  apur:0.6727845599419806
#  f1:0.6297128589263421
#  precision:0.592018779342723
#  recall:0.6725333333333333
# , 'Test':  best_epoch_indx:5
#  auc:0.7869623036597618
#  apur:0.6998546356500766
#  f1:0.6403066370788784
#  precision:0.6071155317521041
#  recall:0.677336747759283
# }
# =====Epoch 6
# Training...
# Iteration: 100%|██████████| 18/18 [00:01<00:00, 15.67it/s]]
# Iteration:   0%|          | 0/154 [00:00<?, ?it/s]6.24it/s]
# {'Train':  best_epoch_indx:5
#  auc:0.7800891133726748
#  apur:0.6775155123999379
#  f1:0.6397794939802898
#  precision:0.5699064208283147
#  recall:0.729180250133365
# , 'Validation':  best_epoch_indx:5
#  auc:0.7762758366595026
#  apur:0.6693664450464566
#  f1:0.639025532911689
#  precision:0.5697577276524645
#  recall:0.7274666666666667
# , 'Test':  best_epoch_indx:5
#  auc:0.7718560855638383
#  apur:0.6692774208334383
#  f1:0.6314699792960662
#  precision:0.5649099174945277
#  recall:0.7158096863665457
# }
# =====Epoch 6
# Training...
# Iteration: 100%|██████████| 18/18 [00:01<00:00, 15.73it/s]]
# Iteration:  17%|█▋        | 26/154 [00:04<00:19,  6.44it/s]
# {'Train':  best_epoch_indx:5
#  auc:0.7794100427567265
#  apur:0.6897773144906583
#  f1:0.6294254207777134
#  precision:0.6165785434078117
#  recall:0.6428190385869244
# , 'Validation':  best_epoch_indx:5
#  auc:0.7799040425749667
#  apur:0.6882235397647527
#  f1:0.6306684141546527
#  precision:0.6201030927835052
#  recall:0.6416
# , 'Test':  best_epoch_indx:5
#  auc:0.7782829103867464
#  apur:0.6889727893351385
#  f1:0.6269210933470861
#  precision:0.6068290734824281
#  recall:0.6483891615105611
# }
# =====Epoch 6
# Training...
# Iteration: 100%|██████████| 18/18 [00:01<00:00, 15.73it/s]]
# Iteration:  46%|████▌     | 71/154 [00:11<00:13,  6.31it/s]
# {'Train':  best_epoch_indx:5
#  auc:0.777544731392844
#  apur:0.6829064725232907
#  f1:0.6256760431459044
#  precision:0.6381116726241834
#  recall:0.6137158437555569
# , 'Validation':  best_epoch_indx:5
#  auc:0.7735406406713745
#  apur:0.6760226948186998
#  f1:0.6144943510608983
#  precision:0.6356898517673888
#  recall:0.5946666666666667
# , 'Test':  best_epoch_indx:5
#  auc:0.7663972516401831
#  apur:0.6670982850485745
#  f1:0.6097855964815833
#  precision:0.6290834845735027
#  recall:0.5916364412203968
# }
# =====Epoch 6
# Training...
# Iteration: 100%|██████████| 154/154 [00:25<00:00,  6.16it/s]
# Iteration:  44%|████▎     | 67/154 [00:10<00:13,  6.28it/s]]
# Evaluating...
# Iteration: 100%|██████████| 154/154 [00:25<00:00,  6.15it/s]
# Iteration:  71%|███████   | 109/154 [00:17<00:07,  6.30it/s]
# Evaluating...
# Iteration: 100%|██████████| 154/154 [00:24<00:00,  6.20it/s]
# Iteration:  85%|████████▌ | 131/154 [00:20<00:03,  6.23it/s]
# Evaluating...
# Iteration: 100%|██████████| 154/154 [00:10<00:00, 15.24it/s]
# Iteration: 100%|██████████| 154/154 [00:24<00:00,  6.20it/s]
# Iteration:  77%|███████▋  | 118/154 [00:07<00:02, 15.22it/s]
# Evaluating...
# Iteration: 100%|██████████| 154/154 [00:10<00:00, 15.22it/s]
# Iteration: 100%|██████████| 43/43 [00:02<00:00, 15.44it/s]]]
# Iteration: 100%|██████████| 154/154 [00:25<00:00,  6.15it/s]
# Iteration:  36%|███▋      | 56/154 [00:03<00:06, 15.44it/s]]
# Evaluating...
# Iteration: 100%|██████████| 43/43 [00:02<00:00, 15.50it/s]]]
# Iteration: 100%|██████████| 154/154 [00:10<00:00, 15.21it/s]
# Iteration: 100%|██████████| 43/43 [00:02<00:00, 15.57it/s]]]
# Iteration: 100%|██████████| 154/154 [00:10<00:00, 15.18it/s]
# Iteration: 100%|██████████| 43/43 [00:02<00:00, 15.53it/s]s]
# Iteration: 100%|██████████| 154/154 [00:10<00:00, 15.13it/s]
# Iteration: 100%|██████████| 18/18 [00:01<00:00, 15.43it/s]
# Iteration:  60%|██████    | 26/43 [00:01<00:01, 15.51it/s]
# {'Train':  best_epoch_indx:6
#  auc:0.7862641361739866
#  apur:0.6890375067259671
#  f1:0.6395015995958916
#  precision:0.6072913335465302
#  recall:0.6753200568990043
# , 'Validation':  best_epoch_indx:6
#  auc:0.7892681608842493
#  apur:0.6876513240925018
#  f1:0.6494688922610015
#  precision:0.6176046176046176
#  recall:0.6848
# , 'Test':  best_epoch_indx:6
#  auc:0.7826286807586174
#  apur:0.6894819132937637
#  f1:0.6375290198849299
#  precision:0.6048649683968589
#  recall:0.6739223218096457
# }
# =====Epoch 7
# Training...
# Iteration: 100%|██████████| 43/43 [00:02<00:00, 15.42it/s]
# Iteration: 100%|██████████| 18/18 [00:01<00:00, 15.41it/s]]
# Iteration:  12%|█▏        | 18/154 [00:02<00:22,  6.12it/s]
# {'Train':  best_epoch_indx:6
#  auc:0.7835965059504707
#  apur:0.6962960531758957
#  f1:0.6345381526104417
#  precision:0.6068376068376068
#  recall:0.6648885727833096
# , 'Validation':  best_epoch_indx:6
#  auc:0.782813877801658
#  apur:0.6896120464962527
#  f1:0.632768361581921
#  precision:0.6102030708271422
#  recall:0.6570666666666667
# , 'Test':  best_epoch_indx:6
#  auc:0.7929827612796464
#  apur:0.710673852801873
#  f1:0.6424678663239074
#  precision:0.6199642786267117
#  recall:0.6666666666666666
# }
# =====Epoch 7
# Training...
# Iteration: 100%|██████████| 18/18 [00:01<00:00, 15.69it/s]]
# Iteration:  14%|█▍        | 22/154 [00:03<00:21,  6.13it/s]
# {'Train':  best_epoch_indx:6
#  auc:0.7877406101944199
#  apur:0.6967382795402721
#  f1:0.6408615316117542
#  precision:0.6039863624442696
#  recall:0.6825321557702566
# , 'Validation':  best_epoch_indx:6
#  auc:0.7812483471497288
#  apur:0.6872760338944244
#  f1:0.6314199395770393
#  precision:0.597997138769671
#  recall:0.6688
# , 'Test':  best_epoch_indx:6
#  auc:0.7766965642121508
#  apur:0.685986731094457
#  f1:0.6317594834543987
#  precision:0.5992344497607656
#  recall:0.6680179219116705
# }
# =====Epoch 7
# Training...
# Iteration: 100%|██████████| 18/18 [00:01<00:00, 15.83it/s]]
# Iteration:  18%|█▊        | 27/154 [00:04<00:20,  6.22it/s]
# {'Train':  best_epoch_indx:6
#  auc:0.7870555008155878
#  apur:0.7008256233759156
#  f1:0.6403265022577284
#  precision:0.6257283475702891
#  recall:0.6556220733803568
# , 'Validation':  best_epoch_indx:6
#  auc:0.7870496776174393
#  apur:0.6981426815315744
#  f1:0.6424116424116424
#  precision:0.6264571718195641
#  recall:0.6592
# , 'Test':  best_epoch_indx:6
#  auc:0.7843555918781276
#  apur:0.6957687222116885
#  f1:0.6380405820864931
#  precision:0.613882863340564
#  recall:0.6641775122679753
# }
# =====Epoch 7
# Training...
# Iteration: 100%|██████████| 18/18 [00:01<00:00, 15.20it/s]]
# Iteration:   0%|          | 0/154 [00:00<?, ?it/s]6.16it/s]
# {'Train':  best_epoch_indx:6
#  auc:0.7885701897958703
#  apur:0.696968688275212
#  f1:0.6399747612355522
#  precision:0.6199711046899311
#  recall:0.6613123110663268
# , 'Validation':  best_epoch_indx:6
#  auc:0.7875103878825095
#  apur:0.6908969960409265
#  f1:0.640499090200156
#  precision:0.6247464503042597
#  recall:0.6570666666666667
# , 'Test':  best_epoch_indx:6
#  auc:0.7728258323724534
#  apur:0.6745728972021907
#  f1:0.6178742952599708
#  precision:0.6049887548558577
#  recall:0.6313206742052485
# }
# =====Epoch 7
# Training...
# Iteration: 100%|██████████| 154/154 [00:24<00:00,  6.23it/s]
# Iteration:   1%|▏         | 2/154 [00:00<00:11, 13.09it/s]]]
# Evaluating...
# Iteration: 100%|██████████| 154/154 [00:24<00:00,  6.25it/s]
# Iteration:  55%|█████▍    | 84/154 [00:13<00:11,  6.25it/s]]
# Evaluating...
# Iteration: 100%|██████████| 154/154 [00:24<00:00,  6.27it/s]
# Iteration:  61%|██████    | 94/154 [00:06<00:03, 15.43it/s]
# Evaluating...
# Iteration: 100%|██████████| 154/154 [00:10<00:00, 15.23it/s]
# Iteration: 100%|██████████| 154/154 [00:24<00:00,  6.28it/s]
# Iteration:   0%|          | 0/43 [00:00<?, ?it/s]  6.21it/s]
# Evaluating...
# Iteration: 100%|██████████| 154/154 [00:10<00:00, 15.27it/s]
# Iteration: 100%|██████████| 43/43 [00:02<00:00, 15.55it/s]s]
# Iteration: 100%|██████████| 154/154 [00:24<00:00,  6.26it/s]
# Iteration:  56%|█████▌    | 10/18 [00:00<00:00, 15.33it/s]]]
# Evaluating...
# Iteration: 100%|██████████| 18/18 [00:01<00:00, 15.93it/s]s]
# Iteration:   0%|          | 0/154 [00:00<?, ?it/s]5.48it/s]
# {'Train':  best_epoch_indx:7
#  auc:0.7907866442734102
#  apur:0.6937134104443354
#  f1:0.6481019173851501
#  precision:0.5727607696856662
#  recall:0.7462660028449503
# , 'Validation':  best_epoch_indx:7
#  auc:0.7900738102548357
#  apur:0.6886035462894766
#  f1:0.6543608675588372
#  precision:0.5766571777145181
#  recall:0.7562666666666666
# , 'Test':  best_epoch_indx:7
#  auc:0.7842957269457317
#  apur:0.6878919766468947
#  f1:0.6430281819856327
#  precision:0.5656189241736876
#  recall:0.7449850618864703
# }
# =====Epoch 8
# Training...
# Iteration: 100%|██████████| 43/43 [00:02<00:00, 15.47it/s]]]
# Iteration: 100%|██████████| 154/154 [00:10<00:00, 15.32it/s]
# Iteration: 100%|██████████| 43/43 [00:02<00:00, 15.56it/s]]]
# Iteration: 100%|██████████| 154/154 [00:10<00:00, 15.32it/s]
# Iteration: 100%|██████████| 18/18 [00:01<00:00, 16.01it/s]s]
# {'Train':  best_epoch_indx:7
#  auc:0.7873854182914845
#  apur:0.6956689116406232
#  f1:0.63404492078831
#  precision:0.6265771501331172
#  recall:0.641692845711576
# , 'Validation':  best_epoch_indx:7
#  auc:0.7807945143792856
#  apur:0.6818788194180387
#  f1:0.6256248355695869
#  precision:0.6173416407061267
#  recall:0.6341333333333333
# , 'Test':  best_epoch_indx:7
#  auc:0.7769519048825471
#  apur:0.6846492828333186
#  f1:0.6274802645615533
#  precision:0.6274802645615533
#  recall:0.6274802645615533
# }
# =====Epoch 8
# Training...
# Iteration: 100%|██████████| 43/43 [00:02<00:00, 15.59it/s]s]
# Iteration: 100%|██████████| 154/154 [00:10<00:00, 15.21it/s]
# Iteration: 100%|██████████| 43/43 [00:02<00:00, 15.48it/s]]
# Iteration: 100%|██████████| 18/18 [00:01<00:00, 15.50it/s]]
# Iteration:  34%|███▍      | 52/154 [00:08<00:16,  6.13it/s]
# {'Train':  best_epoch_indx:7
#  auc:0.790726304676488
#  apur:0.7043038387259867
#  f1:0.6448451889285073
#  precision:0.5684500927140337
#  recall:0.7449620673304884
# , 'Validation':  best_epoch_indx:7
#  auc:0.7869067239791219
#  apur:0.691759299634405
#  f1:0.6420441347270616
#  precision:0.568724279835391
#  recall:0.7370666666666666
# , 'Test':  best_epoch_indx:7
#  auc:0.7997061442368509
#  apur:0.7177895238747896
#  f1:0.6526806526806528
#  precision:0.5795661533366452
#  recall:0.7469056764831413
# }
# =====Epoch 8
# Training...
# Iteration: 100%|██████████| 18/18 [00:01<00:00, 15.69it/s]]]
# Iteration:  65%|██████▍   | 100/154 [00:16<00:08,  6.32it/s]
# {'Train':  best_epoch_indx:7
#  auc:0.7904695536344466
#  apur:0.7031846864160383
#  f1:0.6408304901875018
#  precision:0.6306968201125014
#  recall:0.6512951218066505
# , 'Validation':  best_epoch_indx:7
#  auc:0.790030252788865
#  apur:0.699308505824589
#  f1:0.6387215090385119
#  precision:0.6277033985581875
#  recall:0.6501333333333333
# , 'Test':  best_epoch_indx:7
#  auc:0.7894144715812229
#  apur:0.7008245828913768
#  f1:0.6466707895279324
#  precision:0.6255234297108674
#  recall:0.669298058459569
# }
# =====Epoch 8
# Training...
# Iteration: 100%|██████████| 154/154 [00:24<00:00,  6.19it/s]
# Iteration:   1%|▏         | 2/154 [00:00<00:11, 12.89it/s]s]
# Evaluating...
# Iteration: 100%|██████████| 18/18 [00:01<00:00, 15.73it/s]s]
# Iteration:   0%|          | 0/154 [00:00<?, ?it/s]4.17it/s]
# {'Train':  best_epoch_indx:7
#  auc:0.7917506510917898
#  apur:0.7024968308422612
#  f1:0.6367756952100943
#  precision:0.6587668715544008
#  recall:0.6162053227431687
# , 'Validation':  best_epoch_indx:7
#  auc:0.7897495855081365
#  apur:0.6925276736964914
#  f1:0.6280945757997218
#  precision:0.6563953488372093
#  recall:0.6021333333333333
# , 'Test':  best_epoch_indx:7
#  auc:0.7794736396989826
#  apur:0.6820804967617192
#  f1:0.616899832120873
#  precision:0.6487758945386064
#  recall:0.5880093876680179
# }
# =====Epoch 8
# Training...
# Iteration: 100%|██████████| 154/154 [00:24<00:00,  6.25it/s]
# Iteration:  55%|█████▍    | 84/154 [00:05<00:04, 15.44it/s]
# Evaluating...
# Iteration: 100%|██████████| 154/154 [00:10<00:00, 14.75it/s]
# Iteration: 100%|██████████| 43/43 [00:02<00:00, 15.59it/s]s]
# Iteration: 100%|██████████| 154/154 [00:24<00:00,  6.22it/s]
# Iteration:   1%|▏         | 2/154 [00:00<00:11, 12.76it/s]s]
# Evaluating...
# Iteration: 100%|██████████| 154/154 [00:10<00:00, 14.87it/s]
# Iteration: 100%|██████████| 43/43 [00:02<00:00, 15.61it/s]s]
# Iteration: 100%|██████████| 154/154 [00:24<00:00,  6.27it/s]
# Iteration:  84%|████████▍ | 130/154 [00:20<00:03,  6.23it/s]
# Evaluating...
# Iteration: 100%|██████████| 154/154 [00:10<00:00, 14.73it/s]
# Iteration: 100%|██████████| 154/154 [00:24<00:00,  6.23it/s]
# Iteration:  23%|██▎       | 10/43 [00:00<00:02, 14.86it/s]]
# Evaluating...
# Iteration: 100%|██████████| 18/18 [00:01<00:00, 15.55it/s]]
# Iteration:  65%|██████▌   | 28/43 [00:01<00:00, 15.58it/s]]
# {'Train':  best_epoch_indx:8
#  auc:0.7946968279148103
#  apur:0.700760313517504
#  f1:0.6451025056947608
#  precision:0.6207803594914512
#  recall:0.6714082503556188
# , 'Validation':  best_epoch_indx:8
#  auc:0.7954046054651519
#  apur:0.6923665856837676
#  f1:0.651507409299949
#  precision:0.6253065228052967
#  recall:0.68
# , 'Test':  best_epoch_indx:8
#  auc:0.7867939176711116
#  apur:0.6941935226865528
#  f1:0.6392572944297081
#  precision:0.6123924941360438
#  recall:0.6685872812633376
# }
# =====Epoch 9
# Training...
# Iteration: 100%|██████████| 43/43 [00:02<00:00, 15.41it/s]]
# Iteration: 100%|██████████| 18/18 [00:01<00:00, 15.91it/s]s]
# Iteration:  32%|███▏      | 50/154 [00:03<00:06, 15.16it/s]
# {'Train':  best_epoch_indx:8
#  auc:0.7908206564566334
#  apur:0.7028853266176067
#  f1:0.644005212858384
#  precision:0.594188376753507
#  recall:0.7029397818871503
# , 'Validation':  best_epoch_indx:8
#  auc:0.7838530344898169
#  apur:0.6861579796840759
#  f1:0.6403530277028684
#  precision:0.5925589836660617
#  recall:0.6965333333333333
# , 'Test':  best_epoch_indx:8
#  auc:0.7980116562052169
#  apur:0.7146997502915451
#  f1:0.6489687160761868
#  precision:0.6036350284560309
#  recall:0.7016645326504481
# }
# =====Epoch 9
# Training...
# Iteration: 100%|██████████| 154/154 [00:10<00:00, 14.78it/s]
# Iteration: 100%|██████████| 18/18 [00:01<00:00, 15.62it/s]]
# Iteration:  66%|██████▌   | 102/154 [00:07<00:03, 15.40it/s]
# {'Train':  best_epoch_indx:8
#  auc:0.7930113490175833
#  apur:0.7012668879764024
#  f1:0.641354836848331
#  precision:0.6247892074198989
#  recall:0.658822832078715
# , 'Validation':  best_epoch_indx:8
#  auc:0.7866010029679664
#  apur:0.6888428740609529
#  f1:0.6340447683498178
#  precision:0.6192170818505338
#  recall:0.6496
# , 'Test':  best_epoch_indx:8
#  auc:0.7827068191945633
#  apur:0.69162403182407
#  f1:0.6347017653818029
#  precision:0.6217765042979942
#  recall:0.6481758054192447
# }
# =====Epoch 9
# Training...
# Iteration: 100%|██████████| 43/43 [00:02<00:00, 15.75it/s]]]
# Iteration: 100%|██████████| 154/154 [00:10<00:00, 14.81it/s]
# Iteration: 100%|██████████| 43/43 [00:02<00:00, 15.60it/s]]
# Iteration: 100%|██████████| 18/18 [00:01<00:00, 15.64it/s]s]
# Iteration:  86%|████████▋ | 133/154 [00:21<00:03,  6.17it/s]
# {'Train':  best_epoch_indx:8
#  auc:0.7921733584265706
#  apur:0.7051286103671267
#  f1:0.6367521367521368
#  precision:0.6376225854383358
#  recall:0.6358840614071484
# , 'Validation':  best_epoch_indx:8
#  auc:0.793911697881486
#  apur:0.7063674139059475
#  f1:0.6401906274821287
#  precision:0.6356466876971609
#  recall:0.6448
# , 'Test':  best_epoch_indx:8
#  auc:0.7901473933905527
#  apur:0.7025546227404955
#  f1:0.6387015177065768
#  precision:0.63111851697563
#  recall:0.6464689566887135
# }
# =====Epoch 9
# Training...
# Iteration: 100%|██████████| 154/154 [00:24<00:00,  6.21it/s]
# Iteration:  14%|█▍        | 22/154 [00:03<00:21,  6.28it/s]]
# Evaluating...
# Iteration: 100%|██████████| 18/18 [00:01<00:00, 15.81it/s]]]
# Iteration:   0%|          | 0/154 [00:00<?, ?it/s] 6.33it/s]
# {'Train':  best_epoch_indx:8
#  auc:0.7955076130184152
#  apur:0.707298037320218
#  f1:0.6436163860026275
#  precision:0.6484567715540581
#  recall:0.638847726868591
# , 'Validation':  best_epoch_indx:8
#  auc:0.7934767782212669
#  apur:0.6981891168022845
#  f1:0.6413867822318526
#  precision:0.6516235553109522
#  recall:0.6314666666666666
# , 'Test':  best_epoch_indx:8
#  auc:0.7825587462408797
#  apur:0.6861787865240712
#  f1:0.6235090002168727
#  precision:0.6339581036383682
#  recall:0.6133987625346704
# }
# =====Epoch 9
# Training...
# Iteration: 100%|██████████| 154/154 [00:24<00:00,  6.22it/s]
# Iteration:   0%|          | 0/154 [00:00<?, ?it/s]
# Evaluating...
# Iteration: 100%|██████████| 154/154 [00:24<00:00,  6.25it/s]
# Iteration:  37%|███▋      | 57/154 [00:09<00:15,  6.21it/s]
# Evaluating...
# Iteration: 100%|██████████| 154/154 [00:10<00:00, 15.23it/s]
# Iteration: 100%|██████████| 154/154 [00:10<00:00, 15.23it/s]
# Iteration: 100%|██████████| 43/43 [00:02<00:00, 15.51it/s]s]
# Iteration: 100%|██████████| 154/154 [00:10<00:00, 15.34it/s]
# Iteration: 100%|██████████| 43/43 [00:02<00:00, 15.49it/s]]]
# Iteration: 100%|██████████| 43/43 [00:02<00:00, 15.54it/s]s]
# Iteration: 100%|██████████| 154/154 [00:24<00:00,  6.25it/s]
# Iteration:   0%|          | 0/154 [00:00<?, ?it/s]
# Evaluating...
# Iteration: 100%|██████████| 154/154 [00:24<00:00,  6.21it/s]
# Iteration:   0%|          | 0/154 [00:00<?, ?it/s]
# Evaluating...
# Iteration: 100%|██████████| 18/18 [00:01<00:00, 15.49it/s]]
# Iteration:  55%|█████▍    | 84/154 [00:05<00:04, 15.28it/s]
# {'Train':  best_epoch_indx:9
#  auc:0.7992104439269709
#  apur:0.7090157628827791
#  f1:0.6496156374131971
#  precision:0.6272280779206446
#  recall:0.673660502607871
# , 'Validation':  best_epoch_indx:9
#  auc:0.7979628697165081
#  apur:0.6999332362746207
#  f1:0.6494370522006141
#  precision:0.6242006886374816
#  recall:0.6768
# , 'Test':  best_epoch_indx:9
#  auc:0.7913184409300013
#  apur:0.7037678264681102
#  f1:0.6450092232014758
#  precision:0.6204652996845426
#  recall:0.6715749039692702
# }
# =====Epoch 10
# Training...
# Iteration: 100%|██████████| 18/18 [00:01<00:00, 15.51it/s]]]
# Iteration:   0%|          | 0/154 [00:00<?, ?it/s]15.39it/s]
# {'Train':  best_epoch_indx:9
#  auc:0.7939388780854512
#  apur:0.7078237579508918
#  f1:0.64834864391951
#  precision:0.60175598863175
#  recall:0.7027619724988146
# , 'Validation':  best_epoch_indx:9
#  auc:0.7873933067239791
#  apur:0.6916709331756916
#  f1:0.6450334406737677
#  precision:0.6022201665124884
#  recall:0.6944
# , 'Test':  best_epoch_indx:9
#  auc:0.8022607519348466
#  apur:0.7196768712525037
#  f1:0.6549288769521535
#  precision:0.6133780510527297
#  recall:0.7025181391378574
# }
# =====Epoch 10
# Training...
# Iteration: 100%|██████████| 154/154 [00:10<00:00, 15.24it/s]
# Iteration: 100%|██████████| 18/18 [00:01<00:00, 15.54it/s]]
# Iteration:  13%|█▎        | 20/154 [00:03<00:21,  6.17it/s]]
# {'Train':  best_epoch_indx:9
#  auc:0.7945038941819935
#  apur:0.7051565906459489
#  f1:0.6485965877820584
#  precision:0.6053212799835637
#  recall:0.6985359492620473
# , 'Validation':  best_epoch_indx:9
#  auc:0.7882138573329239
#  apur:0.692964040059523
#  f1:0.6418835192069393
#  precision:0.5995370370370371
#  recall:0.6906666666666667
# , 'Test':  best_epoch_indx:9
#  auc:0.7842139922022424
#  apur:0.6946632162766391
#  f1:0.6423708450140168
#  precision:0.6051688360686663
#  recall:0.6844463409430339
# }
# =====Epoch 10
# Training...
# Iteration: 100%|██████████| 43/43 [00:02<00:00, 15.64it/s]s]
# Iteration: 100%|██████████| 154/154 [00:10<00:00, 15.26it/s]
# Iteration: 100%|██████████| 43/43 [00:02<00:00, 15.52it/s]]
# Iteration: 100%|██████████| 18/18 [00:01<00:00, 15.82it/s]s]
# Iteration:  84%|████████▍ | 130/154 [00:20<00:03,  6.23it/s]
# {'Train':  best_epoch_indx:9
#  auc:0.7985419154222559
#  apur:0.7130882988336978
#  f1:0.6481947451577038
#  precision:0.6400300456462703
#  recall:0.6565704463280185
# , 'Validation':  best_epoch_indx:9
#  auc:0.797881486030089
#  apur:0.709368410408698
#  f1:0.6425196850393702
#  precision:0.6325581395348837
#  recall:0.6528
# , 'Test':  best_epoch_indx:9
#  auc:0.796135450533714
#  apur:0.7082893434594508
#  f1:0.6504098785929231
#  precision:0.6331313131313131
#  recall:0.6686579901856198
# }
# =====Epoch 10
# Training...
# Iteration: 100%|██████████| 154/154 [00:24<00:00,  6.23it/s]
# Iteration:  16%|█▌        | 24/154 [00:03<00:20,  6.25it/s]
# Evaluating...
# Iteration: 100%|██████████| 18/18 [00:01<00:00, 15.67it/s]s]
# Iteration:  18%|█▊        | 27/154 [00:04<00:19,  6.40it/s]]
# {'Train':  best_epoch_indx:9
#  auc:0.8055996730282916
#  apur:0.7200351443586207
#  f1:0.6509799140479747
#  precision:0.6700338812899987
#  recall:0.6329796692549345
# , 'Validation':  best_epoch_indx:9
#  auc:0.8018763279091189
#  apur:0.7087858420593546
#  f1:0.6388505111909367
#  precision:0.6628440366972477
#  recall:0.6165333333333334
# , 'Test':  best_epoch_indx:9
#  auc:0.791568041998836
#  apur:0.6983932167408834
#  f1:0.6313455996453115
#  precision:0.6569780853517878
#  recall:0.6076381480691274
# }
# =====Epoch 10
# Training...
# Iteration: 100%|██████████| 154/154 [00:24<00:00,  6.22it/s]
# Iteration:  88%|████████▊ | 135/154 [00:21<00:03,  6.27it/s]
# Evaluating...
# Iteration: 100%|██████████| 154/154 [00:24<00:00,  6.25it/s]
# Iteration:  49%|████▉     | 76/154 [00:05<00:05, 15.10it/s]
# Evaluating...
# Iteration: 100%|██████████| 154/154 [00:10<00:00, 14.74it/s]
# Iteration: 100%|██████████| 154/154 [00:10<00:00, 14.77it/s]
# Iteration: 100%|██████████| 43/43 [00:02<00:00, 15.55it/s]s]
# Iteration: 100%|██████████| 18/18 [00:01<00:00, 15.99it/s]]]
# Iteration:  95%|█████████▍| 146/154 [00:09<00:00, 15.30it/s]
# {'Train':  best_epoch_indx:10
#  auc:0.8016506332848692
#  apur:0.709060761018515
#  f1:0.6571339596200758
#  precision:0.5844797340965746
#  recall:0.7504148885727833
# , 'Validation':  best_epoch_indx:10
#  auc:0.8003260259952922
#  apur:0.697728953429881
#  f1:0.6638694638694639
#  precision:0.589648033126294
#  recall:0.7594666666666666
# , 'Test':  best_epoch_indx:10
#  auc:0.7927012268260567
#  apur:0.7013826747559706
#  f1:0.6472123811299646
#  precision:0.5746688741721855
#  recall:0.7407170294494239
# }
# =====Epoch 11
# Training...
# Iteration: 100%|██████████| 154/154 [00:10<00:00, 14.71it/s]
# Iteration: 100%|██████████| 43/43 [00:02<00:00, 15.52it/s]]
# Iteration: 100%|██████████| 43/43 [00:02<00:00, 15.57it/s]s]
# Iteration: 100%|██████████| 18/18 [00:01<00:00, 15.97it/s]s]
# Iteration:  81%|████████  | 124/154 [00:19<00:04,  6.19it/s]
# {'Train':  best_epoch_indx:10
#  auc:0.7927789496750595
#  apur:0.7033064066827484
#  f1:0.6449865996187109
#  precision:0.6040782527688645
#  recall:0.6918380653191868
# ...
# Iteration:   0%|          | 0/154 [00:00<?, ?it/s] 6.19it/s]
# Evaluating...
# {'Train':  best_epoch_indx:194
#  auc:0.8416170804721518
#  apur:0.7727977089073641
#  f1:0.6941857101533121
#  precision:0.6779479066613933
#  recall:0.7112204374370221
# , 'Validation':  best_epoch_indx:194
#  auc:0.8355739228328727
#  apur:0.7581177364876572
#  f1:0.6947314049586777
#  precision:0.6735102653980971
#  recall:0.7173333333333334
# , 'Test':  best_epoch_indx:194
#  auc:0.8352862539788709
#  apur:0.7604624876809425
#  f1:0.6915036738073063
#  precision:0.6714228295819936
#  recall:0.7128227010881161
# }
# =====Epoch 195
# Training...
# Iteration: 100%|██████████| 154/154 [00:24<00:00,  6.19it/s]
# Iteration:  43%|████▎     | 66/154 [00:04<00:06, 13.90it/s]
# Evaluating...
# Iteration: 100%|██████████| 154/154 [00:10<00:00, 15.04it/s]
# Iteration: 100%|██████████| 43/43 [00:02<00:00, 15.96it/s]s]
# Iteration: 100%|██████████| 18/18 [00:01<00:00, 16.32it/s]s]
# Iteration:   0%|          | 0/154 [00:00<?, ?it/s]6.24it/s]]
# {'Train':  best_epoch_indx:198
#  auc:0.8411526832252928
#  apur:0.7707803176316561
#  f1:0.6982345309944159
#  precision:0.6660031204605369
#  recall:0.7337442949439867
# , 'Validation':  best_epoch_indx:198
#  auc:0.8358798894688364
#  apur:0.7613790360015993
#  f1:0.6919575113808802
#  precision:0.658008658008658
#  recall:0.7296
# , 'Test':  best_epoch_indx:198
#  auc:0.8328704371876234
#  apur:0.7593032854174909
#  f1:0.6882930822758903
#  precision:0.6613569321533923
#  recall:0.717516535097077
# }
# =====Epoch 199
# Training...
# Iteration: 100%|██████████| 154/154 [00:10<00:00, 15.03it/s]
# Iteration: 100%|██████████| 154/154 [00:24<00:00,  6.24it/s]
# Iteration:   5%|▌         | 8/154 [00:01<00:23,  6.22it/s]]
# Evaluating...
# Iteration: 100%|██████████| 43/43 [00:02<00:00, 15.85it/s]]]
# Iteration: 100%|██████████| 18/18 [00:01<00:00, 16.40it/s]]]
# Iteration:  35%|███▌      | 54/154 [00:03<00:06, 15.51it/s]]
# {'Train':  best_epoch_indx:194
#  auc:0.849153024777398
#  apur:0.7853404883930278
#  f1:0.7041844798549035
#  precision:0.6255293684404345
#  recall:0.8054649991109004
# , 'Validation':  best_epoch_indx:194
#  auc:0.8340529321461467
#  apur:0.7589538218453278
#  f1:0.6875580315691736
#  precision:0.6087135224003288
#  recall:0.7898666666666667
# , 'Test':  best_epoch_indx:194
#  auc:0.8276969647429386
#  apur:0.7547704393362678
#  f1:0.6819764705882352
#  precision:0.6101380936342202
#  recall:0.7729891188393428
# }
# =====Epoch 195
# Training...
# Iteration: 100%|██████████| 154/154 [00:24<00:00,  6.25it/s]
# Iteration:  87%|████████▋ | 134/154 [00:08<00:01, 15.66it/s]
# Evaluating...
# Iteration: 100%|██████████| 154/154 [00:10<00:00, 15.01it/s]
# Iteration: 100%|██████████| 43/43 [00:02<00:00, 15.75it/s]]
# Iteration: 100%|██████████| 154/154 [00:09<00:00, 15.45it/s]
# Iteration: 100%|██████████| 43/43 [00:02<00:00, 15.80it/s]s]
# Iteration: 100%|██████████| 18/18 [00:01<00:00, 16.24it/s]s]
# {'Train':  best_epoch_indx:195
#  auc:0.8415404694823463
#  apur:0.7695773346275825
#  f1:0.6977029780345531
#  precision:0.6592995041671063
#  recall:0.7408570920514492
# , 'Validation':  best_epoch_indx:195
#  auc:0.836516221471702
#  apur:0.7553532245908886
#  f1:0.6934471503891539
#  precision:0.655123339658444
#  recall:0.7365333333333334
# , 'Test':  best_epoch_indx:195
#  auc:0.8337431896596752
#  apur:0.7550459236389889
#  f1:0.6914512922465208
#  precision:0.6473106272101247
#  recall:0.7420524855984638
# }
# =====Epoch 196
# Training...
# Evaluating...
# Iteration: 100%|██████████| 154/154 [00:24<00:00,  6.23it/s]
# Iteration: 100%|██████████| 18/18 [00:01<00:00, 15.76it/s]]]
# Iteration:  23%|██▎       | 36/154 [00:02<00:07, 15.54it/s]]
# {'Train':  best_epoch_indx:196
#  auc:0.8324000029072696
#  apur:0.758228328932296
#  f1:0.6874206546337693
#  precision:0.6432186757566367
#  recall:0.7381460407776197
# , 'Validation':  best_epoch_indx:196
#  auc:0.8268506396479377
#  apur:0.7473610012341645
#  f1:0.688598694123556
#  precision:0.6506881822496441
#  recall:0.7312
# , 'Test':  best_epoch_indx:196
#  auc:0.8396457045571704
#  apur:0.7694916772668277
#  f1:0.6939508884008785
#  precision:0.6519129782445612
#  recall:0.7417840375586855
# }
# =====Epoch 197
# Training...
# Iteration: 100%|██████████| 154/154 [00:24<00:00,  6.21it/s]
# Iteration:  20%|██        | 31/154 [00:04<00:19,  6.23it/s]
# Evaluating...
# Iteration: 100%|██████████| 154/154 [00:09<00:00, 15.46it/s]
# Iteration: 100%|██████████| 43/43 [00:02<00:00, 15.88it/s]]]
# Iteration: 100%|██████████| 154/154 [00:09<00:00, 15.46it/s]
# Iteration: 100%|██████████| 43/43 [00:02<00:00, 15.67it/s]]]
# Iteration: 100%|██████████| 18/18 [00:01<00:00, 16.20it/s]s]
# Iteration:  79%|███████▉  | 122/154 [00:19<00:05,  6.22it/s]
# {'Train':  best_epoch_indx:195
#  auc:0.8522197536795899
#  apur:0.7870063152914849
#  f1:0.7047998531994653
#  precision:0.6318386914833616
#  recall:0.7968110959634876
# , 'Validation':  best_epoch_indx:195
#  auc:0.8374409988742196
#  apur:0.7608672071084093
#  f1:0.6956931042598258
#  precision:0.6225779275484414
#  recall:0.7882666666666667
# , 'Test':  best_epoch_indx:195
#  auc:0.8297120148779511
#  apur:0.75578444378185
#  f1:0.6819653399352504
#  precision:0.6158211521926054
#  recall:0.7640281630040537
# }
# =====Epoch 196
# Training...
# Iteration: 100%|██████████| 154/154 [00:24<00:00,  6.24it/s]
# Iteration:  22%|██▏       | 4/18 [00:00<00:00, 14.72it/s]]s]
# Evaluating...
# Iteration: 100%|██████████| 18/18 [00:01<00:00, 15.93it/s]s]
# Iteration:  95%|█████████▍| 146/154 [00:23<00:01,  6.22it/s]
# {'Train':  best_epoch_indx:199
#  auc:0.8418154192505475
#  apur:0.7717963013716733
#  f1:0.6978678276400982
#  precision:0.6594061494646907
#  recall:0.7410941852883647
# , 'Validation':  best_epoch_indx:199
#  auc:0.8350844744652544
#  apur:0.7609697001254982
#  f1:0.6868889445976435
#  precision:0.6480605487228004
#  recall:0.7306666666666667
# , 'Test':  best_epoch_indx:199
#  auc:0.8338029167855946
#  apur:0.7604313470490296
#  f1:0.6933252549732403
#  precision:0.6581671779141104
#  recall:0.7324514614892255
# }
# Finished training!
# Iteration: 100%|██████████| 154/154 [00:24<00:00,  6.21it/s]
# Iteration:   1%|▏         | 2/154 [00:00<00:12, 12.65it/s]]
# Evaluating...
# Iteration: 100%|██████████| 154/154 [00:10<00:00, 15.10it/s]
# Iteration: 100%|██████████| 154/154 [00:09<00:00, 15.55it/s]
# Iteration: 100%|██████████| 43/43 [00:02<00:00, 16.19it/s]s]
# Iteration: 100%|██████████| 18/18 [00:01<00:00, 16.58it/s]s]
# Iteration:  60%|██████    | 26/43 [00:01<00:01, 16.11it/s]s]
# {'Train':  best_epoch_indx:196
#  auc:0.8446798344284469
#  apur:0.7760421449552636
#  f1:0.6969173223268412
#  precision:0.6169726865807984
#  recall:0.8006638610633632
# , 'Validation':  best_epoch_indx:196
#  auc:0.8400995599222187
#  apur:0.7622130064667989
#  f1:0.6928044280442803
#  precision:0.6103210077204388
#  recall:0.8010666666666667
# , 'Test':  best_epoch_indx:196
#  auc:0.8369969159155546
#  apur:0.7611192166847633
#  f1:0.6925632035430891
#  precision:0.610144691920013
#  recall:0.8007254107104758
# }
# =====Epoch 197
# Training...
# Iteration: 100%|██████████| 43/43 [00:02<00:00, 16.00it/s]s]
# Iteration: 100%|██████████| 18/18 [00:01<00:00, 16.58it/s]s]
# Iteration:  90%|████████▉ | 138/154 [00:22<00:02,  6.21it/s]
# {'Train':  best_epoch_indx:197
#  auc:0.8320224795039916
#  apur:0.7585283534494006
#  f1:0.6837774411074473
#  precision:0.6854267166934668
#  recall:0.6821360834518729
# , 'Validation':  best_epoch_indx:197
#  auc:0.8270660526046465
#  apur:0.7472871156992748
#  f1:0.6847913862718708
#  precision:0.691304347826087
#  recall:0.6784
# , 'Test':  best_epoch_indx:197
#  auc:0.839400287450045
#  apur:0.7693669992550014
#  f1:0.6910735436631851
#  precision:0.6974570745490111
#  recall:0.6848058045241144
# }
# =====Epoch 198
# Training...
# Iteration: 100%|██████████| 154/154 [00:24<00:00,  6.20it/s]
# Iteration:   1%|▏         | 2/154 [00:00<00:11, 12.84it/s]]
# Evaluating...
# Iteration: 100%|██████████| 154/154 [00:10<00:00, 15.25it/s]
# Iteration: 100%|██████████| 43/43 [00:02<00:00, 16.17it/s]s]
# Iteration: 100%|██████████| 18/18 [00:01<00:00, 16.70it/s]s]
# Iteration:   0%|          | 0/154 [00:00<?, ?it/s]
# {'Train':  best_epoch_indx:196
#  auc:0.8524467806264004
#  apur:0.7867066291984572
#  f1:0.7095618627721135
#  precision:0.6630104536793862
#  recall:0.7631438563214984
# , 'Validation':  best_epoch_indx:196
#  auc:0.8362905741479889
#  apur:0.7595364497644003
#  f1:0.6980992347568501
#  precision:0.6498161764705882
#  recall:0.7541333333333333
# , 'Test':  best_epoch_indx:196
#  auc:0.8309395527677887
#  apur:0.7583856405186911
#  f1:0.6827421283379833
#  precision:0.6404935501962984
#  recall:0.7309579688500106
# }
# =====Epoch 197
# Training...
# Iteration: 100%|██████████| 154/154 [00:24<00:00,  6.27it/s]
# Iteration:  90%|████████▉ | 138/154 [00:22<00:02,  6.17it/s]
# Evaluating...
# Iteration: 100%|██████████| 154/154 [00:24<00:00,  6.22it/s]
# Iteration:  26%|██▌       | 40/154 [00:02<00:07, 16.05it/s]
# Evaluating...
# Iteration: 100%|██████████| 154/154 [00:09<00:00, 15.68it/s]
# Iteration: 100%|██████████| 154/154 [00:10<00:00, 15.23it/s]
# Iteration: 100%|██████████| 43/43 [00:02<00:00, 16.15it/s]s]
# Iteration: 100%|██████████| 18/18 [00:01<00:00, 16.58it/s]s]
# Iteration:   0%|          | 0/154 [00:00<?, ?it/s].87it/s]s]
# {'Train':  best_epoch_indx:197
#  auc:0.8464126752346708
#  apur:0.7798353765986759
#  f1:0.7005324350755189
#  precision:0.6466074921017
#  recall:0.7642700491968467
# , 'Validation':  best_epoch_indx:197
#  auc:0.8401739842390747
#  apur:0.7615814791199481
#  f1:0.6954401365520604
#  precision:0.6406109613656783
#  recall:0.7605333333333333
# , 'Test':  best_epoch_indx:197
#  auc:0.8382267731782066
#  apur:0.7659586007596302
#  f1:0.6953238454835898
#  precision:0.6364764267990074
#  recall:0.7661617239172178
# }
# =====Epoch 198
# Training...
# Iteration: 100%|██████████| 43/43 [00:02<00:00, 16.10it/s]s]
# Iteration: 100%|██████████| 154/154 [00:24<00:00,  6.21it/s]
# Iteration:   1%|▏         | 2/154 [00:00<00:11, 12.77it/s]]
# Evaluating...
# Iteration: 100%|██████████| 18/18 [00:01<00:00, 15.52it/s]s]
# Iteration:  81%|████████  | 124/154 [00:08<00:01, 15.82it/s]
# {'Train':  best_epoch_indx:198
#  auc:0.8339777578825838
#  apur:0.7606503644051454
#  f1:0.6872128637059726
#  precision:0.637946791226645
#  recall:0.7447249881460408
# , 'Validation':  best_epoch_indx:198
#  auc:0.8293888445399652
#  apur:0.7515844668497574
#  f1:0.6950885066068312
#  precision:0.6526217228464419
#  recall:0.7434666666666667
# , 'Test':  best_epoch_indx:198
#  auc:0.841042905939841
#  apur:0.7712642107531315
#  f1:0.6962200672867602
#  precision:0.6490774907749077
#  recall:0.7507469056764832
# }
# =====Epoch 199
# Training...
# Iteration: 100%|██████████| 154/154 [00:09<00:00, 15.54it/s]
# Iteration: 100%|██████████| 43/43 [00:02<00:00, 16.08it/s]]]
# Iteration: 100%|██████████| 18/18 [00:01<00:00, 16.62it/s]s]
# Iteration:  26%|██▌       | 40/154 [00:06<00:18,  6.21it/s]]
# {'Train':  best_epoch_indx:197
#  auc:0.8538015313740458
#  apur:0.789912272031999
#  f1:0.7093626447578723
#  precision:0.673105576841209
#  recall:0.7497480884357773
# , 'Validation':  best_epoch_indx:197
#  auc:0.8383076450721523
#  apur:0.7636442435418735
#  f1:0.6944024205748865
#  precision:0.6585365853658537
#  recall:0.7344
# , 'Test':  best_epoch_indx:197
#  auc:0.8308314988230036
#  apur:0.7587376757632265
#  f1:0.6818412762930597
#  precision:0.6509507178890183
#  recall:0.7158096863665457
# }
# =====Epoch 198
# Training...
# Iteration: 100%|██████████| 154/154 [00:24<00:00,  6.25it/s]
# Iteration:  19%|█▉        | 30/154 [00:04<00:20,  6.15it/s]
# Evaluating...
# Iteration: 100%|██████████| 154/154 [00:10<00:00, 15.35it/s]
# Iteration: 100%|██████████| 43/43 [00:02<00:00, 16.21it/s]s]
# Iteration: 100%|██████████| 154/154 [00:24<00:00,  6.21it/s]
# Iteration:   0%|          | 0/154 [00:00<?, ?it/s]
# Evaluating...
# Iteration: 100%|██████████| 18/18 [00:01<00:00, 16.63it/s]]]
# Iteration:   8%|▊         | 12/154 [00:00<00:09, 14.35it/s]]
# {'Train':  best_epoch_indx:198
#  auc:0.8466408973954345
#  apur:0.7798923860551895
#  f1:0.700324198509241
#  precision:0.6575606202518472
#  recall:0.7490368087250311
# , 'Validation':  best_epoch_indx:198
#  auc:0.8416635349503633
#  apur:0.7649338334480013
#  f1:0.7011694451356059
#  precision:0.6571828358208955
#  recall:0.7514666666666666
# , 'Test':  best_epoch_indx:198
#  auc:0.8388383668921245
#  apur:0.7651337962616293
#  f1:0.6974034949155888
#  precision:0.6490260933480339
#  recall:0.7535737145295498
# }
# =====Epoch 199
# Training...
# Iteration: 100%|██████████| 154/154 [00:24<00:00,  6.22it/s]
# Iteration:   1%|▏         | 2/154 [00:00<00:11, 12.96it/s]]]
# Evaluating...
# Iteration: 100%|██████████| 154/154 [00:09<00:00, 15.69it/s]
# Iteration: 100%|██████████| 43/43 [00:02<00:00, 15.98it/s]]
# Iteration: 100%|██████████| 154/154 [00:10<00:00, 15.12it/s]
# Iteration: 100%|██████████| 43/43 [00:02<00:00, 15.85it/s]s]
# Iteration: 100%|██████████| 18/18 [00:01<00:00, 16.42it/s]s]
# Iteration:  82%|████████▏ | 126/154 [00:20<00:04,  6.23it/s]
# {'Train':  best_epoch_indx:198
#  auc:0.8550881043673928
#  apur:0.7909718732932788
#  f1:0.7093424679530067
#  precision:0.6466139734582358
#  recall:0.7855491672100053
# , 'Validation':  best_epoch_indx:198
#  auc:0.8400455224644356
#  apur:0.7645335810740155
#  f1:0.6978538702676634
#  precision:0.6368838028169014
#  recall:0.7717333333333334
# , 'Test':  best_epoch_indx:198
#  auc:0.8323223969095785
#  apur:0.7594322217146457
#  f1:0.6835786212238575
#  precision:0.6257755717071442
#  recall:0.753147002346917
# }
# =====Epoch 199
# Training...
# Iteration: 100%|██████████| 18/18 [00:01<00:00, 16.07it/s]s]
# Iteration:  99%|█████████▉| 153/154 [00:24<00:00,  6.30it/s]
# {'Train':  best_epoch_indx:199
#  auc:0.8351171169796001
#  apur:0.7621269856278556
#  f1:0.6900212901263584
#  precision:0.6466960352422908
#  recall:0.7395685158843054
# , 'Validation':  best_epoch_indx:199
#  auc:0.8300901852420428
#  apur:0.7516440430741991
#  f1:0.6944444444444444
#  precision:0.6594724220623501
#  recall:0.7333333333333333
# , 'Test':  best_epoch_indx:199
#  auc:0.8419359584406239
#  apur:0.7727670604299123
#  f1:0.6966786714685874
#  precision:0.6557438794726931
#  recall:0.7430644472897994
# }
# Finished training!
# Iteration: 100%|██████████| 154/154 [00:24<00:00,  6.24it/s]
# Iteration:   1%|▏         | 2/154 [00:00<00:11, 13.16it/s]
# Evaluating...
# Iteration:  32%|███▏      | 49/154 [00:07<00:15,  6.61it/s]
# <<< joined hyperparam search process
# released_gpu_num: 2
# <<< joined hyperparam search process
# released_gpu_num: 1
# Iteration: 100%|██████████| 154/154 [00:09<00:00, 16.05it/s]
# Iteration: 100%|██████████| 43/43 [00:02<00:00, 16.62it/s]s]
# Iteration: 100%|██████████| 154/154 [00:24<00:00,  6.25it/s]
# Iteration:   1%|▏         | 2/154 [00:00<00:11, 13.06it/s]
# Evaluating...
# Iteration: 100%|██████████| 18/18 [00:01<00:00, 16.43it/s]]
# Iteration:  40%|████      | 62/154 [00:03<00:05, 16.30it/s]
# {'Train':  best_epoch_indx:199
#  auc:0.8476304839897156
#  apur:0.7815238453300242
#  f1:0.7014162496006815
#  precision:0.6366404098004156
#  recall:0.7808665757809259
# , 'Validation':  best_epoch_indx:199
#  auc:0.841927827243885
#  apur:0.7663432812827426
#  f1:0.7013358778625955
#  precision:0.6344410876132931
#  recall:0.784
# , 'Test':  best_epoch_indx:199
#  auc:0.8399776375770055
#  apur:0.7679231029622072
#  f1:0.6957594156152167
#  precision:0.6264092927912538
#  recall:0.7823767868572647
# }
# Finished training!
# Iteration:  74%|███████▍  | 114/154 [00:07<00:02, 15.65it/s]
# <<< joined hyperparam search process
# released_gpu_num: 3
# Iteration: 100%|██████████| 154/154 [00:09<00:00, 15.97it/s]
# Iteration: 100%|██████████| 43/43 [00:02<00:00, 17.00it/s]
# Iteration: 100%|██████████| 18/18 [00:01<00:00, 17.06it/s]
# {'Train':  best_epoch_indx:199
#  auc:0.8556009087905355
#  apur:0.7917833887006902
#  f1:0.7104072398190044
#  precision:0.6510342103964062
#  recall:0.7816964021101298
# , 'Validation':  best_epoch_indx:199
#  auc:0.8392197318595844
#  apur:0.7643768894726551
#  f1:0.7004362578768784
#  precision:0.6419369169258108
#  recall:0.7706666666666667
# , 'Test':  best_epoch_indx:199
#  auc:0.832513699303457
#  apur:0.7607523998018304
#  f1:0.6838106370543542
#  precision:0.6291450080659616
#  recall:0.7488798805205888
# }
# Finished training!
# <<< joined hyperparam search process
# released_gpu_num: 4

# %%
print("End: " + datetime.datetime.now().strftime('%Y-%m-%d_%H-%M-%S'))
# Out:
# End: 2022-03-01_00-57-21
